# %%
import os
import json
from moviepy import VideoFileClip
import random
import warnings
warnings.filterwarnings('ignore')

def extract_event_clips_moviepy():
    """
    Extract clips for multiple events ("Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty")
    and generate random non-event clips with sliding window for "Red card" and "Penalty".
    """
    # Base directory containing season folders
    base_dir = "F:/AIM Lab/Experiment"
    clips_base_dir = os.path.join(base_dir, "sliding-window", "Clips")
    
    # Create base clips directory if it doesn't exist
    os.makedirs(clips_base_dir, exist_ok=True)
    
    # Event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty"]
    event_dirs = {event: os.path.join(clips_base_dir, event.replace(" ", "_")) for event in event_types}
    random_clips_dir = os.path.join(clips_base_dir, "no_event")
    
    # Create directories for each event and random clips
    for event_dir in event_dirs.values():
        os.makedirs(event_dir, exist_ok=True)
    os.makedirs(random_clips_dir, exist_ok=True)
    
    # Counters for clips
    event_counters = {event: 1 for event in event_types}
    random_counter = 1
    
    # Iterate through season folders (e.g., 2014-2015, 2015-2014)
    for season_folder in os.listdir(base_dir):
        season_path = os.path.join(base_dir, season_folder)
        if os.path.isdir(season_path) and season_folder.startswith("20"):
            print(f"Processing season: {season_folder}")
            
            # Iterate through match folders
            for match_folder in os.listdir(season_path):
                match_path = os.path.join(season_path, match_folder)
                if os.path.isdir(match_path):
                    print(f"  Processing match: {match_folder}")
                    
                    # Look for Labels-v2.json file
                    labels_file = os.path.join(match_path, "Labels-v2.json")
                    video_file = os.path.join(match_path, "2_720p.mkv")
                    
                    if os.path.exists(labels_file) and os.path.exists(video_file):
                        # Extract events from second half
                        event_timestamps = extract_event_timestamps(labels_file, event_types)
                        
                        # Load video once for all clips from this match
                        try:
                            video = VideoFileClip(video_file)
                            video_duration = video.duration
                            
                            # Create clips for each event
                            for event, timestamps in event_timestamps.items():
                                for timestamp in timestamps:
                                    # Create sliding window clips for "Red card" and "Penalty"
                                    if event in ["Red card", "Penalty"]:
                                        create_event_clip_moviepy(
                                            video, 
                                            timestamp, 
                                            event_dirs[event], 
                                            f"{event_counters[event]}_{match_folder}_normal",
                                            event
                                        )
                                        create_event_clip_moviepy(
                                            video, 
                                            timestamp - 2000,  # 2 seconds before
                                            event_dirs[event], 
                                            f"{event_counters[event]}_{match_folder}_before",
                                            event
                                        )
                                        create_event_clip_moviepy(
                                            video, 
                                            timestamp + 2000,  # 2 seconds after
                                            event_dirs[event], 
                                            f"{event_counters[event]}_{match_folder}_after",
                                            event
                                        )
                                    else:
                                        # Create normal clip for other events
                                        create_event_clip_moviepy(
                                            video, 
                                            timestamp, 
                                            event_dirs[event], 
                                            f"{event_counters[event]}_{match_folder}",
                                            event
                                        )
                                    event_counters[event] += 1
                            
                            # Generate random non-event clips
                            avoided_intervals = generate_avoided_intervals(event_timestamps)
                            num_random_clips = min(3, sum(len(timestamps) for timestamps in event_timestamps.values()))
                            random_start_times = generate_random_segments(video_duration, avoided_intervals, num_random_clips, 7.0)
                            
                            for start_time in random_start_times:
                                create_random_clip_moviepy(
                                    video, 
                                    start_time, 
                                    random_clips_dir, 
                                    f"ng{random_counter}_{match_folder}"
                                )
                                random_counter += 1
                            
                            # Close video to free memory
                            video.close()
                            
                        except Exception as e:
                            print(f"    Error loading video: {e}")
                    else:
                        if not os.path.exists(labels_file):
                            print(f"    Labels-v2.json not found")
                        if not os.path.exists(video_file):
                            print(f"    2_720p.mkv not found")

def extract_event_timestamps(labels_file, event_types):
    """
    Extract timestamps for specified events from the second half of the match.
    
    Args:
        labels_file (str): Path to the Labels-v2.json file
        event_types (list): List of event types to extract
        
    Returns:
        dict: Dictionary with event types as keys and lists of timestamps as values
    """
    try:
        with open(labels_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event_timestamps = {event: [] for event in event_types}
        
        for annotation in data.get('annotations', []):
            label = annotation.get('label')
            game_time = annotation.get('gameTime', '')
            
            if label in event_types and game_time.startswith('2 -'):
                position = int(annotation.get('position', 0))
                event_timestamps[label].append(position)
        
        return event_timestamps
        
    except Exception as e:
        print(f"    Error reading labels file: {e}")
        return {event: [] for event in event_types}

def create_event_clip_moviepy(video_clip, position_ms, output_dir, clip_name, event):
    """
    Create a 7-second video clip around the event time using MoviePy.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        position_ms (int): Event position in milliseconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
        event (str): Event type for logging
    """
    try:
        # Calculate start and end times (3 seconds before and after)
        start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before, but not negative
        end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after (total 7 seconds)
        
        # Make sure we don't exceed video duration
        end_seconds = min(end_seconds, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating clip {clip_name} for {event} at {start_seconds:.2f}s")
        
        # Extract the clip
        event_clip = video_clip.subclipped(start_seconds, end_seconds)
        
        # Write the clip to file
        event_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        event_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating clip {clip_name}: {e}")

def create_random_clip_moviepy(video_clip, start_time, output_dir, clip_name):
    """
    Create a random 7-second video clip.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        start_time (float): Start time in seconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
    """
    try:
        # Calculate end time
        end_time = start_time + 7.0  # 7 seconds duration
        
        # Make sure we don't exceed video duration
        end_time = min(end_time, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating random clip {clip_name}")
        
        # Extract the clip
        random_clip = video_clip.subclipped(start_time, end_time)
        
        # Write the clip to file
        random_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        random_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating random clip {clip_name}: {e}")

def generate_avoided_intervals(event_timestamps):
    """
    Generate avoided intervals for random clip generation based on event timestamps.
    
    Args:
        event_timestamps (dict): Dictionary of event timestamps
        
    Returns:
        list: List of avoided intervals (start, end) in seconds
    """
    avoided_intervals = []
    for timestamps in event_timestamps.values():
        for position_ms in timestamps:
            start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before
            end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after
            avoided_intervals.append((start_seconds, end_seconds))
    return avoided_intervals

def generate_random_segments(video_duration, avoided_intervals, num_segments, segment_duration):
    """
    Generate random segments avoiding specified intervals.
    
    Args:
        video_duration (float): Total duration of the video
        avoided_intervals (list): List of (start, end) intervals to avoid
        num_segments (int): Number of segments to generate
        segment_duration (float): Duration of each segment
        
    Returns:
        list: List of start times for random segments
    """
    random_segments = []
    max_attempts = 1000
    
    for _ in range(num_segments):
        attempts = 0
        while attempts < max_attempts:
            max_start = video_duration - segment_duration
            if max_start <= 0:
                break
            
            start_time = random.uniform(0, max_start)
            end_time = start_time + segment_duration
            
            # Check if this segment overlaps with any avoided interval
            overlap = False
            for avoid_start, avoid_end in avoided_intervals:
                if not (end_time <= avoid_start or start_time >= avoid_end):
                    overlap = True
                    break
            
            if not overlap:
                random_segments.append(start_time)
                break
            
            attempts += 1
        
        if attempts >= max_attempts:
            print(f"Warning: Could not find non-overlapping segment after {max_attempts} attempts")
    
    return random_segments

# Run the extraction
print("Multiclass Clip Extractor (MoviePy)")
print("===================================")

try:
    extract_event_clips_moviepy()
    print("\nProcessing complete!")
except ImportError:
    print("Error: MoviePy not installed. Install with: pip install moviepy")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Multiclass Clip Extractor (MoviePy)
# ===================================
# Processing season: 2014-2015
#   Processing match: 2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Goal at 2118.49s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal for Red card at 1462.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before for Red card at 1460.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after for Red card at 1464.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Yellow card at 1018.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Yellow card at 1502.67s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Direct free-kick at 618.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#   Processing match: 2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Goal at 2910.95s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Yellow card at 621.99s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Yellow card at 2344.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Direct free-kick at 1748.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng5_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng5_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#   Processing match: 2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Goal at 1624.79s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 161.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2324.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2518.73s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2561.38s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2714.45s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Direct free-kick at 2547.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#   Processing match: 2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Goal at 1666.53s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 1071.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 1919.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 2340.82s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 2742.72s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 1443.21s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 1976.67s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 6_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 2656.39s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\6_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing season: 2015-2014
#   Processing match: 2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
#     Creating clip 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Goal at 541.39s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal for Red card at 403.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
#     Creating clip 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before for Red card at 401.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
#     Creating clip 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after for Red card at 405.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
#     Creating clip 14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Yellow card at 478.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Yellow card at 2851.43s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 72.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 1237.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 9_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 2304.39s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\9_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 2359.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal for Penalty at 541.02s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
#     Creating clip 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before for Penalty at 539.02s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
#     Creating clip 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after for Penalty at 543.02s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
#     Creating random clip ng13_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng13_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#   Processing match: 2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
#     Creating clip 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 1170.28s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 2019.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 2127.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1541.16s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1622.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 827.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 871.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 962.36s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 1594.93s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#   Processing match: 2015-08-29 - 17-00 Manchester City 2 - 0 Watford
#     Creating clip 9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Goal at 85.44s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Goal at 606.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Yellow card at 1066.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 490.69s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 599.99s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 1117.37s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng19_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng19_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng20_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng20_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng21_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng21_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#   Processing match: 2015-09-12 - 14-45 Everton 3 - 1 Chelsea
#     Creating clip 11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Goal at 2212.88s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 1155.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2459.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2537.34s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2820.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2419.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2492.37s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2858.52s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng23_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng23_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#   Processing match: 2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
#     Creating clip 12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Goal at 2670.32s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 1418.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 1530.95s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 2113.80s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Direct free-kick at 1853.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Direct free-kick at 2086.52s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng27_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng27_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#   Processing match: 2015-09-19 - 19-30 Manchester City 1 - 2 West Ham
#     Creating clip 26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham for Yellow card at 485.32s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
#     Creating random clip ng28_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng28_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
#   Processing match: 2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
#     Creating clip 13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 775.58s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1207.98s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1275.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1496.60s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 502.03s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 1677.10s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 1971.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng29_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng29_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng30_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng30_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#   Processing match: 2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
#     Creating clip 17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Goal at 481.00s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 185.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 985.12s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 1713.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 2394.44s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 788.11s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 1531.66s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 1722.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng32_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng32_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng33_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng33_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng34_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng34_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#   Processing match: 2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
#     Creating clip 18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 1713.32s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 2224.80s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 755.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 1138.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 1242.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 2440.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 346.63s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 1180.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 2176.45s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng35_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng35_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng37_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng37_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#   Processing match: 2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
#     Creating clip 20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Goal at 384.77s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Goal at 2750.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal for Red card at 2702.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
#     Creating clip 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before for Red card at 2700.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
#     Creating clip 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after for Red card at 2704.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
#     Creating clip 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 861.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 900.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 1173.18s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Direct free-kick at 1597.27s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal for Penalty at 2749.53s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
#     Creating clip 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before for Penalty at 2747.53s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
#     Creating clip 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after for Penalty at 2751.53s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
#     Creating random clip ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng39_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng39_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng40_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng40_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#   Processing match: 2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
#     Creating clip 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Goal at 2137.40s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Yellow card at 91.59s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Yellow card at 2374.97s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Direct free-kick at 389.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Direct free-kick at 1176.94s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 35_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Direct free-kick at 1623.13s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\35_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating random clip ng41_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng41_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating random clip ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating random clip ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#   Processing match: 2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
#     Creating clip 40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Yellow card at 439.00s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating clip 41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Yellow card at 835.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating clip 42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Yellow card at 2938.52s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating clip 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Direct free-kick at 358.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating clip 37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Direct free-kick at 2462.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating clip 38_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea for Direct free-kick at 2698.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\38_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating random clip ng44_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng44_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating random clip ng45_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng45_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Creating random clip ng46_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng46_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#   Processing match: 2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth
#     Creating clip 23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth for Goal at 2181.96s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
#     Creating clip 43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth for Yellow card at 1028.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
#     Creating random clip ng47_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng47_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
#     Creating random clip ng48_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng48_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
#   Processing match: 2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
#     Creating clip 24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Goal at 252.44s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Goal at 415.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 159.68s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 978.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 2544.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 47_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 2600.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\47_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 412.75s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 1014.65s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 2038.51s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 42_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 2563.82s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\42_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 43_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 2634.01s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\43_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_normal for Penalty at 251.97s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_normal.mp4
#     Creating clip 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_before for Penalty at 249.97s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_before.mp4
#     Creating clip 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_after for Penalty at 253.97s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_after.mp4
#     Creating random clip ng49_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng49_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating random clip ng50_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng50_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating random clip ng51_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng51_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#   Processing match: 2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
#     Creating clip 26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland for Goal at 484.32s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating clip 27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland for Goal at 781.64s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating clip 44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland for Direct free-kick at 1636.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating clip 45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland for Direct free-kick at 2610.44s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating clip 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_normal for Penalty at 1410.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_normal.mp4
#     Creating clip 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_before for Penalty at 1408.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_before.mp4
#     Creating clip 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_after for Penalty at 1412.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_after.mp4
#     Creating random clip ng52_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng52_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating random clip ng53_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng53_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Creating random clip ng54_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng54_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#   Processing match: 2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
#     Creating clip 28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Goal at 885.68s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Goal at 1237.12s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Yellow card at 666.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Yellow card at 2053.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 441.18s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 555.25s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 1706.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 2592.14s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating random clip ng55_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng55_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating random clip ng56_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng56_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating random clip ng57_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng57_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#   Processing match: 2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
#     Creating clip 30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Goal at 1673.00s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Goal at 2395.68s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 217.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 1339.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 1439.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 2371.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 793.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 1408.65s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 1974.30s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 2638.30s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng59_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng59_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#   Processing match: 2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
#     Creating clip 32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 900.64s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 2741.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 1054.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 2016.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 2223.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2262.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2616.91s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2890.70s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng61_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng61_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng62_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng62_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng63_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng63_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#   Processing match: 2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
#     Creating clip 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 473.40s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 1715.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 2259.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 0.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 50.47s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 610.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 1820.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 191.17s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 654.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 1175.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 2502.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal for Penalty at 473.04s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.mp4
#     Creating clip 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before for Penalty at 471.04s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.mp4
#     Creating clip 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after for Penalty at 475.04s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.mp4
#     Creating random clip ng64_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng64_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng65_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng65_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng66_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng66_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#   Processing match: 2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
#     Creating clip 37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Goal at 698.96s
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Yellow card at 1318.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 1779.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 2260.96s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 2337.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\Direct_free-kick\63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng67_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng67_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng68_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng68_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng69_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\sliding-window\Clips\no_event\ng69_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#
# Processing complete!

# %%
import os
import cv2
import numpy as np

def process_video(input_path, output_path):
    """
    Process the video to:
    1. Convert to grayscale.
    2. Remove grass and audience areas while preserving the ball.
    """
    # Load video
    cap = cv2.VideoCapture(input_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Changed to mp4v for better compatibility
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height), isColor=False)
    
    print(f"Processing {total_frames} frames from {input_path}...")
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % 100 == 0:
            print(f"Processed {frame_count}/{total_frames} frames")

        # Convert to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Convert original frame to HSV for better color detection
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

        # Define green grass color range in HSV (more specific range)
        lower_green = np.array([35, 40, 40])
        upper_green = np.array([85, 255, 255])
        grass_mask = cv2.inRange(hsv, lower_green, upper_green)

        # Define ball detection (white/light colored ball)
        lower_ball_hsv = np.array([0, 0, 200])
        upper_ball_hsv = np.array([180, 30, 255])
        ball_mask_hsv = cv2.inRange(hsv, lower_ball_hsv, upper_ball_hsv)
        
        _, ball_mask_gray = cv2.threshold(gray_frame, 200, 255, cv2.THRESH_BINARY)
        ball_mask = cv2.bitwise_or(ball_mask_hsv, ball_mask_gray)
        
        kernel = np.ones((3, 3), np.uint8)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_CLOSE, kernel)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_OPEN, kernel)

        lower_audience = np.array([0, 100, 150])
        upper_audience = np.array([180, 255, 255])
        audience_mask = cv2.inRange(hsv, lower_audience, upper_audience)
        audience_mask = cv2.bitwise_and(audience_mask, cv2.bitwise_not(ball_mask))

        combined_mask = cv2.bitwise_or(grass_mask, audience_mask)
        keep_mask = cv2.bitwise_not(combined_mask)
        keep_mask = cv2.bitwise_or(keep_mask, ball_mask)

        processed_frame = cv2.bitwise_and(gray_frame, gray_frame, mask=keep_mask)
        out.write(processed_frame)
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Processed video saved as: {output_path}")

def process_all_videos(input_folder, output_folder):
    """
    Process all videos in the input folder and save them to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to the folder to save processed videos.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for video_file in os.listdir(input_folder):
        input_path = os.path.join(input_folder, video_file)
        output_path = os.path.join(output_folder, video_file)
        
        if os.path.isfile(input_path) and video_file.endswith(".mp4"):
            process_video(input_path, output_path)

def process_all_events(base_input_path, base_output_path, event_types):
    """
    Process all event folders and save processed videos to respective folders.
    
    Args:
        base_input_path (str): Path to the base input folder containing event folders.
        base_output_path (str): Path to the base output folder to save processed videos.
        event_types (list): List of event types to process.
    """
    for event in event_types:
        input_folder = os.path.join(base_input_path, event.replace(" ", "_"))
        output_folder = os.path.join(base_output_path, event.replace(" ", "_"))
        
        if os.path.exists(input_folder):
            print(f"Processing videos for event: {event}")
            process_all_videos(input_folder, output_folder)
        else:
            print(f"Input folder not found for event: {event}")

if __name__ == "__main__":
    # Define input and output base paths
    base_input_path = "F:/AIM Lab/Experiment/sliding-window/Clips"
    base_output_path = "F:/AIM Lab/Experiment/sliding-window/Features-processed"
    
    # List of event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty", "no_event"]
    
    # Process all events
    process_all_events(base_input_path, base_output_path, event_types)
# Out:
# Processing videos for event: Goal
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing videos for event: Red card
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Processing videos for event: Yellow card
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\47_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\47_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 100 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/100 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Yellow_card\9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing videos for event: Direct free-kick
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\35_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\35_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\38_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\38_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\42_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\42_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\43_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\43_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\Direct_free-kick\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# ...
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng27_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng27_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng28_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng28_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng29_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng29_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng30_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng30_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng32_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng32_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng33_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng33_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng34_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng34_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng35_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng35_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng37_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng37_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng39_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng39_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng40_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng40_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng41_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng41_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng44_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng44_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng45_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng45_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng46_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng46_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng47_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng47_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng48_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng48_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng49_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng49_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng50_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng50_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng51_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng51_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng52_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng52_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng53_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng53_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng54_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng54_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng55_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng55_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng56_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng56_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng57_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng57_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng59_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng59_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng5_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng5_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng61_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng61_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng62_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng62_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng63_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng63_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng64_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng64_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng65_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng65_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng66_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng66_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng67_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng67_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng68_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng68_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng69_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng69_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/sliding-window/Clips\no_event\ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/sliding-window/Features-processed\no_event\ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4

# %%
import os
import shutil
import random
from collections import defaultdict

def split_videos(base_path, event_types, train_ratio=0.8, test_ratio=0.2):
    """
    Split videos into train and test subfolders for each event type based on unequal sample sizes.
    For "Red card" and "Penalty", ensure all three samples of an event (normal, before, after) remain together.
    
    Args:
        base_path (str): Path to the base folder containing event folders.
        event_types (list): List of event types to process.
        train_ratio (float): Proportion of videos to place in the train folder.
        test_ratio (float): Proportion of videos to place in the test folder.
    """
    for event in event_types:
        event_folder = os.path.join(base_path, event.replace(" ", "_"))
        train_folder = os.path.join(event_folder, "train")
        test_folder = os.path.join(event_folder, "test")
        
        # Create train and test subfolders if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)
        
        # Get all video files in the event folder
        video_files = [f for f in os.listdir(event_folder) if f.endswith(".mp4")]
        
        if event in ["Red card", "Penalty"]:
            # Group files by event (normal, before, after)
            grouped_files = defaultdict(list)
            for filename in video_files:
                # Extract the base event identifier (e.g., "1_match_normal", "1_match_before", "1_match_after")
                base_event = "_".join(filename.split("_")[:2])  # First two parts of the filename
                grouped_files[base_event].append(filename)
            
            # Shuffle the grouped events to ensure randomness
            grouped_events = list(grouped_files.items())
            random.shuffle(grouped_events)
            
            # Calculate the number of train and test events
            total_events = len(grouped_events)
            num_train_events = int(total_events * train_ratio)
            num_test_events = total_events - num_train_events
            
            # Split events into train and test sets
            train_events = grouped_events[:num_train_events]
            test_events = grouped_events[num_train_events:]
            
            # Move grouped files to train folder
            for base_event, files in train_events:
                for file in files:
                    src_path = os.path.join(event_folder, file)
                    dest_path = os.path.join(train_folder, file)
                    shutil.move(src_path, dest_path)
            
            # Move grouped files to test folder
            for base_event, files in test_events:
                for file in files:
                    src_path = os.path.join(event_folder, file)
                    dest_path = os.path.join(test_folder, file)
                    shutil.move(src_path, dest_path)
            
            print(f"Event: {event}")
            print(f"  Total events: {total_events}")
            print(f"  Train events: {len(train_events)}")
            print(f"  Test events: {len(test_events)}")
        else:
            # Shuffle the video files to ensure randomness
            random.shuffle(video_files)
            
            # Calculate the number of train and test videos
            total_videos = len(video_files)
            num_train_videos = int(total_videos * train_ratio)
            num_test_videos = total_videos - num_train_videos
            
            # Split videos into train and test sets
            train_videos = video_files[:num_train_videos]
            test_videos = video_files[num_train_videos:]
            
            # Move videos to train folder
            for video in train_videos:
                src_path = os.path.join(event_folder, video)
                dest_path = os.path.join(train_folder, video)
                shutil.move(src_path, dest_path)
            
            # Move videos to test folder
            for video in test_videos:
                src_path = os.path.join(event_folder, video)
                dest_path = os.path.join(test_folder, video)
                shutil.move(src_path, dest_path)
            
            print(f"Event: {event}")
            print(f"  Total videos: {total_videos}")
            print(f"  Train videos: {len(train_videos)}")
            print(f"  Test videos: {len(test_videos)}")

if __name__ == "__main__":
    # Define base paths for Clips and Features-processed
    base_paths = [
        "F:/AIM Lab/Experiment/sliding-window/Clips",
        "F:/AIM Lab/Experiment/sliding-window/Features-processed"
    ]
    
    # List of event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct_free-kick", "Penalty", "no_event"]
    
    # Split videos in both base paths
    for base_path in base_paths:
        split_videos(base_path, event_types)
# Out:
# Event: Goal
#   Total videos: 37
#   Train videos: 29
#   Test videos: 8
# Event: Red card
#   Total events: 3
#   Train events: 2
#   Test events: 1
# Event: Yellow card
#   Total videos: 61
#   Train videos: 48
#   Test videos: 13
# Event: Direct_free-kick
#   Total videos: 63
#   Train videos: 50
#   Test videos: 13
# Event: Penalty
#   Total events: 5
#   Train events: 4
#   Test events: 1
# Event: no_event
#   Total videos: 69
#   Train videos: 55
#   Test videos: 14
# Event: Goal
#   Total videos: 37
#   Train videos: 29
#   Test videos: 8
# Event: Red card
#   Total events: 3
#   Train events: 2
#   Test events: 1
# Event: Yellow card
#   Total videos: 61
#   Train videos: 48
#   Test videos: 13
# Event: Direct_free-kick
#   Total videos: 63
#   Train videos: 50
#   Test videos: 13
# Event: Penalty
#   Total events: 5
#   Train events: 4
#   Test events: 1
# Event: no_event
#   Total videos: 69
#   Train videos: 55
#   Test videos: 14

# %%
import os
import cv2
import numpy as np
import torch
import torchvision
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# Load ResNet-50 model
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Identity()  # Remove the final classifier to get 2048-d features
model.eval()  # Set the model to evaluation mode

# Preprocessing pipeline for frames
preprocess = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),                    # H×W×C → C×H×W, [0,1]
    torchvision.transforms.Normalize(mean=[.485, .456, .406], std=[.229, .224, .225]),
    torchvision.transforms.Resize((224, 224)),
])

def embed_clip(frames: List[np.ndarray]):
    """
    Generate ResNet-50 embeddings for a list of frames.
    
    Args:
        frames (List[np.ndarray]): List of frames (H×W×C, BGR format).
    
    Returns:
        np.ndarray: N×2048 array of frame embeddings.
    """
    feats = []
    for frame in frames:
        # Convert BGR (OpenCV) to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        x = preprocess(frame_rgb).unsqueeze(0)  # 1×3×224×224
        with torch.no_grad():
            f = model(x)  # 1×2048
        feats.append(f.squeeze(0).cpu().numpy())
    return np.stack(feats, axis=0)  # N×2048

def sample_frames_from_video(video_path, num_samples=16):
    """
    Uniformly sample num_samples frames from the video at video_path.
    Returns a list of BGR frames (as numpy arrays).
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        # If fewer frames than samples, just read them all
        indices = list(range(total_frames))
    else:
        # Uniformly spaced frame indices
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    cap.release()

    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    return frames

def process_folder(input_folder, output_folder, num_samples=16):
    """
    Process videos in a folder, generate mean-pooled ResNet-50 embeddings for sampled frames,
    and save the embeddings to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to save embeddings.
        num_samples (int): Number of frames to sample per video.
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        frames = sample_frames_from_video(video_path, num_samples=num_samples)
        if frames:
            # Generate embeddings and mean-pool them
            embeddings = embed_clip(frames)
            clip_vec = np.mean(embeddings, axis=0)  # Mean-pool → (2048,)
            
            # Save the embedding as a .npy file
            output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
            np.save(output_path, clip_vec)
            print(f"Saved embedding to {output_path}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes(embeddings_base_path, event_classes):
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary of prototypes for each event class.
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_multiclass_classification(embeddings_base_path, prototypes, event_classes):
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with ResNet-50")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/sliding-window/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Red_card", "Yellow_card", "Direct_free-kick", "Penalty", "no_event"]
    
    # Step 1: Generate embeddings for all videos
    print("\nStep 1: Generating ResNet-50 embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, num_samples=16)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data
    print("\nStep 3: Evaluating classification performance...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
        print(f"\n{'='*50}")
        print("FINAL RESULTS")
        print(f"{'='*50}")
        print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
        print(f"Weighted Precision: {results['precision']:.4f}")
        print(f"Weighted Recall: {results['recall']:.4f}")
        print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
        
        print(f"\n{'='*50}")
        print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
        print(f"{'='*50}")
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Multiclass Few-Shot Learning with ResNet-50
# ==================================================
#
# Step 1: Generating ResNet-50 embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#
# Processing Red_card - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy
#
# Processing Red_card - Test...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# ...
#     Similarities: {'Goal': 0.9087087, 'Red_card': 0.9376311, 'Yellow_card': 0.9553678, 'Direct_free-kick': 0.8891465, 'Penalty': 0.9214455, 'no_event': 0.9260077}
#   File: 22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9159179, 'Red_card': 0.95255375, 'Yellow_card': 0.96695197, 'Direct_free-kick': 0.9113984, 'Penalty': 0.92826605, 'no_event': 0.9394421}
#   File: 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9287879, 'Red_card': 0.9714891, 'Yellow_card': 0.9806225, 'Direct_free-kick': 0.9107232, 'Penalty': 0.9419765, 'no_event': 0.9503584}
#   File: 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8701335, 'Red_card': 0.95701003, 'Yellow_card': 0.9584144, 'Direct_free-kick': 0.85053265, 'Penalty': 0.89452577, 'no_event': 0.8980911}
#   File: 34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.91066045, 'Red_card': 0.8901398, 'Yellow_card': 0.91817296, 'Direct_free-kick': 0.9084336, 'Penalty': 0.90871406, 'no_event': 0.9413581}
#   File: 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9072459, 'Red_card': 0.9421002, 'Yellow_card': 0.9528736, 'Direct_free-kick': 0.87499475, 'Penalty': 0.9287477, 'no_event': 0.9226477}
#   File: 40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.841436, 'Red_card': 0.9267868, 'Yellow_card': 0.9375284, 'Direct_free-kick': 0.82279956, 'Penalty': 0.8693471, 'no_event': 0.87449306}
#   File: 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.92501104, 'Red_card': 0.95018846, 'Yellow_card': 0.9685887, 'Direct_free-kick': 0.9174012, 'Penalty': 0.9342042, 'no_event': 0.94640154}
#   File: 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.92634344, 'Red_card': 0.93618745, 'Yellow_card': 0.9564688, 'Direct_free-kick': 0.9087727, 'Penalty': 0.937768, 'no_event': 0.94368094}
#   File: 5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.90062773, 'Red_card': 0.9587729, 'Yellow_card': 0.96266603, 'Direct_free-kick': 0.86963046, 'Penalty': 0.9215617, 'no_event': 0.92034656}
#   File: 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8825755, 'Red_card': 0.9395129, 'Yellow_card': 0.95192945, 'Direct_free-kick': 0.857398, 'Penalty': 0.9159268, 'no_event': 0.905297}
#
# Testing Direct_free-kick clips...
#   File: 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9491601, 'Red_card': 0.9021048, 'Yellow_card': 0.93062145, 'Direct_free-kick': 0.9464646, 'Penalty': 0.942667, 'no_event': 0.9499974}
#   File: 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.96369374, 'Red_card': 0.8916184, 'Yellow_card': 0.9205218, 'Direct_free-kick': 0.9612918, 'Penalty': 0.9537051, 'no_event': 0.9587631}
#   File: 17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9716973, 'Red_card': 0.92077166, 'Yellow_card': 0.94357985, 'Direct_free-kick': 0.9610466, 'Penalty': 0.9662932, 'no_event': 0.9684341}
#   File: 25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9596793, 'Red_card': 0.877553, 'Yellow_card': 0.9100736, 'Direct_free-kick': 0.9598968, 'Penalty': 0.9451727, 'no_event': 0.9496834}
#   File: 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.9559171, 'Red_card': 0.88696957, 'Yellow_card': 0.9200988, 'Direct_free-kick': 0.94685745, 'Penalty': 0.96002984, 'no_event': 0.9462811}
#   File: 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9668212, 'Red_card': 0.8628372, 'Yellow_card': 0.90107465, 'Direct_free-kick': 0.976948, 'Penalty': 0.9421643, 'no_event': 0.9633111}
#   File: 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9519585, 'Red_card': 0.86122674, 'Yellow_card': 0.88921356, 'Direct_free-kick': 0.95290434, 'Penalty': 0.92427576, 'no_event': 0.9445333}
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Direct_free-kick, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.94902456, 'Red_card': 0.8898836, 'Yellow_card': 0.91450375, 'Direct_free-kick': 0.92758024, 'Penalty': 0.9501871, 'no_event': 0.9315364}
#   File: 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9250771, 'Red_card': 0.7850626, 'Yellow_card': 0.8307361, 'Direct_free-kick': 0.9470481, 'Penalty': 0.89415646, 'no_event': 0.9129886}
#   File: 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.95376384, 'Red_card': 0.9134556, 'Yellow_card': 0.94075096, 'Direct_free-kick': 0.9398372, 'Penalty': 0.9569467, 'no_event': 0.9554416}
#   File: 41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9264922, 'Red_card': 0.82154155, 'Yellow_card': 0.8589641, 'Direct_free-kick': 0.9476141, 'Penalty': 0.90537274, 'no_event': 0.92804295}
#   File: 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9108784, 'Red_card': 0.81716365, 'Yellow_card': 0.847223, 'Direct_free-kick': 0.92677313, 'Penalty': 0.88531464, 'no_event': 0.91821945}
#   File: 63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9342401, 'Red_card': 0.86090785, 'Yellow_card': 0.8889422, 'Direct_free-kick': 0.93751895, 'Penalty': 0.9165982, 'no_event': 0.93127584}
#
# Testing Penalty clips...
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.95642614, 'Red_card': 0.93194324, 'Yellow_card': 0.9536521, 'Direct_free-kick': 0.93613636, 'Penalty': 0.9679843, 'no_event': 0.95412785}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy
#     True: Penalty, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.92906666, 'Red_card': 0.83097863, 'Yellow_card': 0.86401874, 'Direct_free-kick': 0.93073565, 'Penalty': 0.91587603, 'no_event': 0.9122193}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.9606744, 'Red_card': 0.909545, 'Yellow_card': 0.9360428, 'Direct_free-kick': 0.94977796, 'Penalty': 0.9626742, 'no_event': 0.9526547}
#
# Testing no_event clips...
#   File: ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.858647, 'Red_card': 0.9038323, 'Yellow_card': 0.92225903, 'Direct_free-kick': 0.8514285, 'Penalty': 0.8687679, 'no_event': 0.89227664}
#   File: ng14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.88631153, 'Red_card': 0.9365357, 'Yellow_card': 0.9398482, 'Direct_free-kick': 0.8620426, 'Penalty': 0.9040358, 'no_event': 0.90721464}
#   File: ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.95833886, 'Red_card': 0.905723, 'Yellow_card': 0.9396509, 'Direct_free-kick': 0.95739627, 'Penalty': 0.95114297, 'no_event': 0.96706533}
#   File: ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.860584, 'Red_card': 0.89751333, 'Yellow_card': 0.90348345, 'Direct_free-kick': 0.82234085, 'Penalty': 0.8842821, 'no_event': 0.87394774}
#   File: ng20_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.93917775, 'Red_card': 0.91212046, 'Yellow_card': 0.92497385, 'Direct_free-kick': 0.922395, 'Penalty': 0.9305234, 'no_event': 0.9373759}
#   File: ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.93617934, 'Red_card': 0.8260052, 'Yellow_card': 0.86436677, 'Direct_free-kick': 0.9494004, 'Penalty': 0.9080664, 'no_event': 0.93386614}
#   File: ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.95582616, 'Red_card': 0.85370654, 'Yellow_card': 0.8908787, 'Direct_free-kick': 0.9598639, 'Penalty': 0.94606936, 'no_event': 0.9480558}
#   File: ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.94155264, 'Red_card': 0.92880607, 'Yellow_card': 0.9489882, 'Direct_free-kick': 0.9221899, 'Penalty': 0.9481883, 'no_event': 0.9429128}
#   File: ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8746033, 'Red_card': 0.8082162, 'Yellow_card': 0.8453567, 'Direct_free-kick': 0.8852678, 'Penalty': 0.85409415, 'no_event': 0.90375805}
#   File: ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9437502, 'Red_card': 0.89981306, 'Yellow_card': 0.924692, 'Direct_free-kick': 0.9401667, 'Penalty': 0.93823135, 'no_event': 0.96044445}
#   File: ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.87774295, 'Red_card': 0.85641813, 'Yellow_card': 0.875237, 'Direct_free-kick': 0.8747472, 'Penalty': 0.8710606, 'no_event': 0.9071963}
#   File: ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.96673197, 'Red_card': 0.8772248, 'Yellow_card': 0.916671, 'Direct_free-kick': 0.9718454, 'Penalty': 0.95361936, 'no_event': 0.9673747}
#   File: ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.92226183, 'Red_card': 0.82244366, 'Yellow_card': 0.8680839, 'Direct_free-kick': 0.9427207, 'Penalty': 0.89423954, 'no_event': 0.93326396}
#   File: ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9235015, 'Red_card': 0.95500726, 'Yellow_card': 0.97035944, 'Direct_free-kick': 0.9047223, 'Penalty': 0.93382967, 'no_event': 0.9442293}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# Per-class Accuracy:
#   Goal: 0.5000 (4/8)
#   Red_card: 0.0000 (0/3)
#   Yellow_card: 0.9231 (12/13)
#   Direct_free-kick: 0.5385 (7/13)
#   Penalty: 0.6667 (2/3)
#   no_event: 0.2857 (4/14)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Red_card', 'Yellow_card', 'Direct_free-kick', 'Penalty', 'no_event']
# [[ 4  0  0  2  1  1]
#  [ 0  0  3  0  0  0]
#  [ 0  0 12  0  0  1]
#  [ 2  0  0  7  3  1]
#  [ 0  0  0  1  2  0]
#  [ 1  0  5  4  0  4]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.57      0.50      0.53         8
#         Red_card       0.00      0.00      0.00         3
#      Yellow_card       0.60      0.92      0.73        13
# Direct_free-kick       0.50      0.54      0.52        13
#          Penalty       0.33      0.67      0.44         3
#         no_event       0.57      0.29      0.38        14
#
#         accuracy                           0.54        54
#        macro avg       0.43      0.49      0.43        54
#     weighted avg       0.52      0.54      0.50        54
#
#
# Step 4: Additional Analysis...
# Total test samples: 54
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 2 times
#   Goal → Penalty: 1 times
#   Goal → no_event: 1 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#   Red_card → Yellow_card: 3 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#   Yellow_card → no_event: 1 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#   Direct_free-kick → Goal: 2 times
#   Direct_free-kick → Penalty: 3 times
#   Direct_free-kick → no_event: 1 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#   Penalty → Direct_free-kick: 1 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#   no_event → Goal: 1 times
#   no_event → Yellow_card: 5 times
#   no_event → Direct_free-kick: 4 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5370
# Weighted Precision: 0.5161
# Weighted Recall: 0.5370
# Weighted F₁ Score: 0.5024
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms
from torchvision.models.video import r2plus1d_18
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

class R2Plus1DFeatureExtractor:
    def __init__(self, device='cuda' if torch.cuda.is_available() else 'cpu'):
        """
        Initialize R(2+1)D model for feature extraction.
        
        Args:
            device: Device to run the model on
        """
        self.device = device
        
        # Initialize R(2+1)D model
        self.model = r2plus1d_18(pretrained=True)
        
        # Remove the final classification layer to get features
        self.model.fc = torch.nn.Identity()
        self.model.to(device)
        self.model.eval()
        
        # Preprocessing transforms
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((112, 112)),  # R(2+1)D typically uses 112x112
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.43216, 0.394666, 0.37645], 
                               std=[0.22803, 0.22145, 0.216989])  # Kinetics normalization
        ])
    
    def preprocess_frames(self, frames: List[np.ndarray], num_frames: int = 16) -> torch.Tensor:
        """
        Preprocess frames for R(2+1)D input.
        
        Args:
            frames: List of frames (H×W×C, BGR format)
            num_frames: Number of frames to use for R(2+1)D
            
        Returns:
            Preprocessed tensor of shape (1, 3, num_frames, H, W)
        """
        # Sample frames uniformly if we have more than needed
        if len(frames) > num_frames:
            indices = np.linspace(0, len(frames) - 1, num_frames, dtype=int)
            frames = [frames[i] for i in indices]
        elif len(frames) < num_frames:
            # Repeat last frame if we don't have enough
            while len(frames) < num_frames:
                frames.append(frames[-1])
        
        # Convert frames and apply transforms
        processed_frames = []
        for frame in frames:
            # Convert BGR to RGB
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Apply transforms
            frame_tensor = self.transform(frame_rgb)
            processed_frames.append(frame_tensor)
        
        # Stack frames: (num_frames, 3, H, W) -> (3, num_frames, H, W)
        video_tensor = torch.stack(processed_frames, dim=1)  # (3, num_frames, H, W)
        video_tensor = video_tensor.unsqueeze(0)  # Add batch dimension
        
        return video_tensor
    
    def extract_features(self, frames: List[np.ndarray]) -> np.ndarray:
        """
        Extract R(2+1)D features from video frames.
        
        Args:
            frames: List of video frames
            
        Returns:
            Feature vector of shape (512,) for R(2+1)D-18
        """
        # Preprocess frames
        video_tensor = self.preprocess_frames(frames)
        video_tensor = video_tensor.to(self.device)
        
        # Extract features
        with torch.no_grad():
            features = self.model(video_tensor)
            # Global average pooling if needed
            if len(features.shape) > 2:
                features = F.adaptive_avg_pool3d(features, 1).squeeze()
            else:
                features = features.squeeze()
        
        return features.cpu().numpy()

def sample_frames_from_video(video_path: str, num_samples: int = 32) -> List[np.ndarray]:
    """
    Uniformly sample frames from a video.
    
    Args:
        video_path: Path to video file
        num_samples: Number of frames to sample
        
    Returns:
        List of sampled frames
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        indices = list(range(total_frames))
    else:
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    
    cap.release()
    
    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    
    return frames

def process_folder(input_folder: str, output_folder: str, 
                  feature_extractor: R2Plus1DFeatureExtractor,
                  num_frames: int = 32):
    """
    Process all videos in a folder and generate R(2+1)D embeddings.
    
    Args:
        input_folder: Folder containing input videos
        output_folder: Folder to save embeddings
        feature_extractor: R(2+1)D feature extractor instance
        num_frames: Number of frames to use for each video
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    os.makedirs(output_folder, exist_ok=True)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        
        # Sample frames from video
        frames = sample_frames_from_video(video_path, num_samples=num_frames)
        
        if frames:
            # Extract R(2+1)D features
            try:
                features = feature_extractor.extract_features(frames)
                
                # Save the embedding as a .npy file
                output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
                np.save(output_path, features)
                print(f"Saved R(2+1)D embedding to {output_path} (shape: {features.shape})")
                
            except Exception as e:
                print(f"Error processing {fname}: {e}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec: np.ndarray) -> np.ndarray:
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec: Input vector
        
    Returns:
        L2-normalized vector
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def cosine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    """
    Compute cosine similarity between two vectors.
    
    Args:
        vec1: First vector
        vec2: Second vector
        
    Returns:
        Cosine similarity value
    """
    # Normalize vectors
    vec1_norm = l2_normalize(vec1)
    vec2_norm = l2_normalize(vec2)
    
    # Compute cosine similarity
    return np.dot(vec1_norm, vec2_norm)

def build_prototypes(embeddings_base_path: str, event_classes: List[str]) -> Dict[str, np.ndarray]:
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        event_classes: List of event class names
        
    Returns:
        Dictionary of prototypes for each event class
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding: np.ndarray, prototypes: Dict[str, np.ndarray]) -> tuple:
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding: Embedding vector of the clip
        prototypes: Dictionary of prototypes for each event class
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = cosine_similarity(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_multiclass_classification(embeddings_base_path: str, 
                                     prototypes: Dict[str, np.ndarray], 
                                     event_classes: List[str],
                                     threshold: float = 0.0) -> dict:
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        prototypes: Dictionary of prototypes for each event class
        event_classes: List of event class names
        threshold: Decision threshold (not used in multiclass, kept for compatibility)
    
    Returns:
        Dictionary containing evaluation results
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run R(2+1)D-based multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with R(2+1)D")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/sliding-window/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings"
    
    # Event classes (using underscores to match folder names)
    event_classes = ["Goal", "Red_card", "Yellow_card", "Direct_free-kick", "Penalty", "no_event"]
    
    # Initialize R(2+1)D feature extractor
    print("Initializing R(2+1)D feature extractor...")
    feature_extractor = R2Plus1DFeatureExtractor()
    
    # Step 1: Generate R(2+1)D embeddings for all videos
    print("\nStep 1: Generating R(2+1)D embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, feature_extractor, num_frames=32)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data with threshold 0.0
    print("\nStep 3: Evaluating classification performance with threshold 0.0...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes, threshold=0.0)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*50}")
    print("FINAL RESULTS")
    print(f"{'='*50}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# Multiclass Few-Shot Learning with R(2+1)D
# ==================================================
# Initializing R(2+1)D feature extractor...
#
# Step 1: Generating R(2+1)D embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#
# Processing Red_card - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy (shape: (512,))
#
# Processing Red_card - Test...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy (shape: (512,))
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/sliding-window/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy (shape: (512,))
# ...
#   File: 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.91782427, 'Red_card': 0.8221014, 'Yellow_card': 0.88957536, 'Direct_free-kick': 0.8929728, 'Penalty': 0.9418986, 'no_event': 0.9078076}
#
# Testing Red_card clips...
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy
#     True: Red_card, Predicted: Red_card, Correct: True
#     Similarities: {'Goal': 0.78342867, 'Red_card': 0.93590033, 'Yellow_card': 0.9287462, 'Direct_free-kick': 0.758586, 'Penalty': 0.84288466, 'no_event': 0.825341}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.80712163, 'Red_card': 0.85165024, 'Yellow_card': 0.8768945, 'Direct_free-kick': 0.81254697, 'Penalty': 0.8305932, 'no_event': 0.8516233}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy
#     True: Red_card, Predicted: Red_card, Correct: True
#     Similarities: {'Goal': 0.7652141, 'Red_card': 0.9021514, 'Yellow_card': 0.9015018, 'Direct_free-kick': 0.7474444, 'Penalty': 0.81417257, 'no_event': 0.81283855}
#
# Testing Yellow_card clips...
#   File: 12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.80548817, 'Red_card': 0.9329828, 'Yellow_card': 0.94184536, 'Direct_free-kick': 0.77308965, 'Penalty': 0.86656195, 'no_event': 0.84009945}
#   File: 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.73807055, 'Red_card': 0.86594296, 'Yellow_card': 0.86944044, 'Direct_free-kick': 0.7157508, 'Penalty': 0.78285795, 'no_event': 0.7798626}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.80338657, 'Red_card': 0.8752004, 'Yellow_card': 0.9142475, 'Direct_free-kick': 0.7735352, 'Penalty': 0.85270476, 'no_event': 0.8416617}
#   File: 22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.858292, 'Red_card': 0.88827, 'Yellow_card': 0.9194126, 'Direct_free-kick': 0.8387416, 'Penalty': 0.8903314, 'no_event': 0.8799786}
#   File: 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.79764, 'Red_card': 0.9303246, 'Yellow_card': 0.9347651, 'Direct_free-kick': 0.7560356, 'Penalty': 0.8498577, 'no_event': 0.8357589}
#   File: 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7827474, 'Red_card': 0.8664545, 'Yellow_card': 0.89468867, 'Direct_free-kick': 0.76872325, 'Penalty': 0.82274646, 'no_event': 0.81794083}
#   File: 34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.90913975, 'Red_card': 0.700162, 'Yellow_card': 0.79226273, 'Direct_free-kick': 0.92332375, 'Penalty': 0.8584105, 'no_event': 0.9071187}
#   File: 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.78738296, 'Red_card': 0.90210134, 'Yellow_card': 0.9113946, 'Direct_free-kick': 0.7537087, 'Penalty': 0.8648109, 'no_event': 0.825956}
#   File: 40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.74181545, 'Red_card': 0.8732859, 'Yellow_card': 0.87785274, 'Direct_free-kick': 0.7303892, 'Penalty': 0.7985179, 'no_event': 0.7858039}
#   File: 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8615154, 'Red_card': 0.85956764, 'Yellow_card': 0.907849, 'Direct_free-kick': 0.8461567, 'Penalty': 0.88047576, 'no_event': 0.8837453}
#   File: 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8389343, 'Red_card': 0.90474194, 'Yellow_card': 0.93236285, 'Direct_free-kick': 0.80678123, 'Penalty': 0.8835474, 'no_event': 0.87301433}
#   File: 5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.74612933, 'Red_card': 0.86883044, 'Yellow_card': 0.86984986, 'Direct_free-kick': 0.7170868, 'Penalty': 0.79477787, 'no_event': 0.779027}
#   File: 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.80398643, 'Red_card': 0.8964415, 'Yellow_card': 0.89682406, 'Direct_free-kick': 0.77643424, 'Penalty': 0.8604209, 'no_event': 0.8336152}
#
# Testing Direct_free-kick clips...
#   File: 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.8695252, 'Red_card': 0.7893374, 'Yellow_card': 0.85195315, 'Direct_free-kick': 0.8795001, 'Penalty': 0.8918574, 'no_event': 0.8898401}
#   File: 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9185788, 'Red_card': 0.67660785, 'Yellow_card': 0.7678126, 'Direct_free-kick': 0.93846506, 'Penalty': 0.86448455, 'no_event': 0.90562177}
#   File: 17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9243221, 'Red_card': 0.7534206, 'Yellow_card': 0.83536136, 'Direct_free-kick': 0.8995158, 'Penalty': 0.89316934, 'no_event': 0.9065416}
#   File: 25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9332628, 'Red_card': 0.7131218, 'Yellow_card': 0.80429995, 'Direct_free-kick': 0.9367481, 'Penalty': 0.8894725, 'no_event': 0.91830015}
#   File: 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.92091954, 'Red_card': 0.7271835, 'Yellow_card': 0.8110404, 'Direct_free-kick': 0.9274632, 'Penalty': 0.9036795, 'no_event': 0.91383976}
#   File: 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9119717, 'Red_card': 0.6919012, 'Yellow_card': 0.77891934, 'Direct_free-kick': 0.93552595, 'Penalty': 0.86760455, 'no_event': 0.9062315}
#   File: 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8920018, 'Red_card': 0.76624763, 'Yellow_card': 0.85738194, 'Direct_free-kick': 0.87235034, 'Penalty': 0.87771094, 'no_event': 0.9028944}
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8864031, 'Red_card': 0.75790375, 'Yellow_card': 0.83531415, 'Direct_free-kick': 0.8591187, 'Penalty': 0.8780104, 'no_event': 0.88807523}
#   File: 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9000139, 'Red_card': 0.67124367, 'Yellow_card': 0.76464903, 'Direct_free-kick': 0.9186393, 'Penalty': 0.8469846, 'no_event': 0.89275086}
#   File: 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8529978, 'Red_card': 0.77806705, 'Yellow_card': 0.83617675, 'Direct_free-kick': 0.8385533, 'Penalty': 0.85818374, 'no_event': 0.8651763}
#   File: 41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9029294, 'Red_card': 0.6337794, 'Yellow_card': 0.7341848, 'Direct_free-kick': 0.931874, 'Penalty': 0.8392327, 'no_event': 0.8895355}
#   File: 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9033522, 'Red_card': 0.6529751, 'Yellow_card': 0.7468969, 'Direct_free-kick': 0.9187672, 'Penalty': 0.82857764, 'no_event': 0.8948226}
#   File: 63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9100299, 'Red_card': 0.79190713, 'Yellow_card': 0.85058224, 'Direct_free-kick': 0.8795313, 'Penalty': 0.8824809, 'no_event': 0.9052479}
#
# Testing Penalty clips...
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.8579762, 'Red_card': 0.86153483, 'Yellow_card': 0.8928691, 'Direct_free-kick': 0.8253504, 'Penalty': 0.9166666, 'no_event': 0.8581705}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.8975008, 'Red_card': 0.7844606, 'Yellow_card': 0.8549584, 'Direct_free-kick': 0.8793342, 'Penalty': 0.90734684, 'no_event': 0.88733375}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.8792103, 'Red_card': 0.8220514, 'Yellow_card': 0.8720241, 'Direct_free-kick': 0.85423625, 'Penalty': 0.9072926, 'no_event': 0.8734125}
#
# Testing no_event clips...
#   File: ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7666236, 'Red_card': 0.86774373, 'Yellow_card': 0.8919871, 'Direct_free-kick': 0.7470233, 'Penalty': 0.81651556, 'no_event': 0.80427355}
#   File: ng14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Red_card, Correct: False
#     Similarities: {'Goal': 0.7587193, 'Red_card': 0.8941002, 'Yellow_card': 0.8822831, 'Direct_free-kick': 0.7321856, 'Penalty': 0.82211065, 'no_event': 0.7953776}
#   File: ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.89348805, 'Red_card': 0.8286234, 'Yellow_card': 0.8978436, 'Direct_free-kick': 0.8658992, 'Penalty': 0.9076667, 'no_event': 0.90559244}
#   File: ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7517388, 'Red_card': 0.8539015, 'Yellow_card': 0.86209154, 'Direct_free-kick': 0.7151815, 'Penalty': 0.8163927, 'no_event': 0.7913523}
#   File: ng20_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8710721, 'Red_card': 0.83399856, 'Yellow_card': 0.8809333, 'Direct_free-kick': 0.83483684, 'Penalty': 0.8796848, 'no_event': 0.884828}
#   File: ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9331851, 'Red_card': 0.7467488, 'Yellow_card': 0.8285246, 'Direct_free-kick': 0.9285946, 'Penalty': 0.899251, 'no_event': 0.9251561}
#   File: ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9006125, 'Red_card': 0.6108446, 'Yellow_card': 0.71460104, 'Direct_free-kick': 0.9214094, 'Penalty': 0.8207334, 'no_event': 0.8874098}
#   File: ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.86460024, 'Red_card': 0.87264466, 'Yellow_card': 0.9007617, 'Direct_free-kick': 0.8294158, 'Penalty': 0.89503706, 'no_event': 0.8736501}
#   File: ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.89104736, 'Red_card': 0.6790494, 'Yellow_card': 0.7656134, 'Direct_free-kick': 0.91086674, 'Penalty': 0.8279211, 'no_event': 0.8978523}
#   File: ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9118365, 'Red_card': 0.73331016, 'Yellow_card': 0.8253821, 'Direct_free-kick': 0.911004, 'Penalty': 0.87044877, 'no_event': 0.9184804}
#   File: ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.87993824, 'Red_card': 0.7903759, 'Yellow_card': 0.85421306, 'Direct_free-kick': 0.8629727, 'Penalty': 0.8858508, 'no_event': 0.88483846}
#   File: ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9223544, 'Red_card': 0.71960855, 'Yellow_card': 0.8045521, 'Direct_free-kick': 0.92946327, 'Penalty': 0.8920735, 'no_event': 0.9124163}
#   File: ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.91823304, 'Red_card': 0.6939975, 'Yellow_card': 0.7851472, 'Direct_free-kick': 0.9426651, 'Penalty': 0.86842525, 'no_event': 0.9175626}
#   File: ng9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8398738, 'Red_card': 0.8726971, 'Yellow_card': 0.9135153, 'Direct_free-kick': 0.8101089, 'Penalty': 0.8742068, 'no_event': 0.8692951}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5926
# Weighted Precision: 0.5707
# Weighted Recall: 0.5926
# Weighted F₁ Score: 0.5539
#
# Per-class Accuracy:
#   Goal: 0.7500 (6/8)
#   Red_card: 0.6667 (2/3)
#   Yellow_card: 0.9231 (12/13)
#   Direct_free-kick: 0.5385 (7/13)
#   Penalty: 1.0000 (3/3)
#   no_event: 0.1429 (2/14)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Red_card', 'Yellow_card', 'Direct_free-kick', 'Penalty', 'no_event']
# [[ 6  0  0  0  2  0]
#  [ 0  2  1  0  0  0]
#  [ 0  0 12  1  0  0]
#  [ 2  0  0  7  1  3]
#  [ 0  0  0  0  3  0]
#  [ 1  1  4  4  2  2]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.67      0.75      0.71         8
#         Red_card       0.67      0.67      0.67         3
#      Yellow_card       0.71      0.92      0.80        13
# Direct_free-kick       0.58      0.54      0.56        13
#          Penalty       0.38      1.00      0.55         3
#         no_event       0.40      0.14      0.21        14
#
#         accuracy                           0.59        54
#        macro avg       0.57      0.67      0.58        54
#     weighted avg       0.57      0.59      0.55        54
#
#
# Step 4: Additional Analysis...
# Total test samples: 54
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Penalty: 2 times
#   Red_card → Yellow_card: 1 times
#   Yellow_card → Direct_free-kick: 1 times
#   Direct_free-kick → Goal: 2 times
#   Direct_free-kick → Penalty: 1 times
#   Direct_free-kick → no_event: 3 times
#   no_event → Goal: 1 times
#   no_event → Red_card: 1 times
#   no_event → Yellow_card: 4 times
#   no_event → Direct_free-kick: 4 times
#   no_event → Penalty: 2 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5926
# Weighted Precision: 0.5707
# Weighted Recall: 0.5926
# Weighted F₁ Score: 0.5539
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %% [markdown]
# ## 7(maximum) random samples for prototype and 12(maximum) random samples for evaluation

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, max_prototype_samples=7):
    """
    Build prototypes for each event class from test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        max_prototype_samples (int): Maximum number of samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) <= max_prototype_samples:
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, max_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, max_eval_samples=12):
    """
    Evaluate classification performance on training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        max_eval_samples (int): Maximum number of samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON UP TO {max_eval_samples} TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) <= max_eval_samples:
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, max_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from up to 7 test samples,
    and evaluates on up to 12 training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/sliding-window/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event", "Red_card", "Penalty"]
    
    # Maximum number of test samples to use for prototype creation
    max_prototype_samples = 7
    
    # Maximum number of training samples to evaluate per class
    max_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from test embeddings
    print(f"\nStep 1: Building prototypes from up to {max_prototype_samples} test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, max_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on training samples
    print(f"\nStep 2: Evaluating classification performance on up to {max_eval_samples} training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, max_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 29 embeddings in Goal/Train
#   Found 8 embeddings in Goal/Test
#   Found 50 embeddings in Direct_free-kick/Train
#   Found 13 embeddings in Direct_free-kick/Test
#   Found 48 embeddings in Yellow_card/Train
#   Found 13 embeddings in Yellow_card/Test
#   Found 55 embeddings in no_event/Train
#   Found 14 embeddings in no_event/Test
#   Found 6 embeddings in Red_card/Train
#   Found 3 embeddings in Red_card/Test
#   Found 12 embeddings in Penalty/Train
#   Found 3 embeddings in Penalty/Test
#
# Step 1: Building prototypes from up to 7 test samples per class...
# Loading 7 test embeddings for Goal prototype...
#   Selected 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy for prototype (shape: (2048,))
#   Selected 29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (2048,))
#   Selected 14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (2048,))
#   Selected 31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
#   Selected 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
# Built prototype for Goal from 7 test samples
# Loading 7 test embeddings for Direct_free-kick prototype...
#   Selected 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (2048,))
#   Selected 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (2048,))
#   Selected 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
#   Selected 41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy for prototype (shape: (2048,))
#   Selected 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (2048,))
#   Selected 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
# Built prototype for Direct_free-kick from 7 test samples
# Loading 7 test embeddings for Yellow_card prototype...
#   Selected 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
#   Selected 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (2048,))
#   Selected 40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy for prototype (shape: (2048,))
#   Selected 22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (2048,))
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy for prototype (shape: (2048,))
#   Selected 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
# Built prototype for Yellow_card from 7 test samples
# Loading 7 test embeddings for no_event prototype...
#   Selected ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
#   Selected ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
#   Selected ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (2048,))
#   Selected ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
#   Selected ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (2048,))
#   Selected ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (2048,))
#   Selected ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (2048,))
# Built prototype for no_event from 7 test samples
# Loading 3 test embeddings for Red_card prototype...
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy for prototype (shape: (2048,))
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy for prototype (shape: (2048,))
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy for prototype (shape: (2048,))
# Built prototype for Red_card from 3 test samples
# Loading 3 test embeddings for Penalty prototype...
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy for prototype (shape: (2048,))
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy for prototype (shape: (2048,))
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy for prototype (shape: (2048,))
# Built prototype for Penalty from 3 test samples
#
# Successfully built prototypes for 6 classes:
#   Goal: shape (2048,)
#   Direct_free-kick: shape (2048,)
#   Yellow_card: shape (2048,)
#   no_event: shape (2048,)
#   Red_card: shape (2048,)
#   Penalty: shape (2048,)
#
# Files used for prototype creation:
#   Goal: ['34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy', '29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', '22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy']
#   Direct_free-kick: ['29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy', '13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '41_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy', '28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy', '30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy']
#   Yellow_card: ['50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', '28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy', '34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy', '22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy', '1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy', '38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy']
#   no_event: ['ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', 'ng58_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', 'ng31_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', 'ng43_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', 'ng15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy', 'ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy', 'ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy']
#   Red_card: ['1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy', '1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy', '1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy']
#   Penalty: ['5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy', '5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy', '5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy']
#
# Step 2: Evaluating classification performance on up to 12 training samples per class...
#
# ============================================================
# EVALUATING ON UP TO 12 TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9459977, 'Direct_free-kick': 0.9272096, 'Yellow_card': 0.8746841, 'no_event': 0.91902745, 'Red_card': 0.82706594, 'Penalty': 0.90707666}
#   File: 11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.966609, 'Direct_free-kick': 0.9602792, 'Yellow_card': 0.9172189, 'no_event': 0.955623, 'Red_card': 0.85683674, 'Penalty': 0.935168}
#   File: 32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.96540105, 'Direct_free-kick': 0.9536383, 'Yellow_card': 0.92043674, 'no_event': 0.96182656, 'Red_card': 0.9054901, 'Penalty': 0.93142474}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.96733904, 'Direct_free-kick': 0.95071256, 'Yellow_card': 0.94511664, 'no_event': 0.95904565, 'Red_card': 0.9041677, 'Penalty': 0.93952984}
#   File: 16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.95267797, 'Direct_free-kick': 0.9404641, 'Yellow_card': 0.8961376, 'no_event': 0.9289456, 'Red_card': 0.8177836, 'Penalty': 0.9052186}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9399191, 'Direct_free-kick': 0.9373119, 'Yellow_card': 0.85448444, 'no_event': 0.9303392, 'Red_card': 0.8005367, 'Penalty': 0.8780128}
#   File: 18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9696288, 'Direct_free-kick': 0.9684428, 'Yellow_card': 0.9180837, 'no_event': 0.9695089, 'Red_card': 0.8725176, 'Penalty': 0.9280915}
#   File: 37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9428384, 'Direct_free-kick': 0.9378491, 'Yellow_card': 0.8965562, 'no_event': 0.93296, 'Red_card': 0.81900877, 'Penalty': 0.9098201}
#   File: 33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.96737516, 'Direct_free-kick': 0.94074047, 'Yellow_card': 0.9063801, 'no_event': 0.94181824, 'Red_card': 0.87367475, 'Penalty': 0.9340613}
#   File: 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9623669, 'Direct_free-kick': 0.96090126, 'Yellow_card': 0.89171505, 'no_event': 0.9462311, 'Red_card': 0.86354005, 'Penalty': 0.9344189}
#   File: 26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.956434, 'Direct_free-kick': 0.9545721, 'Yellow_card': 0.9274517, 'no_event': 0.967669, 'Red_card': 0.85512733, 'Penalty': 0.9453471}
#   File: 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9729545, 'Direct_free-kick': 0.96148694, 'Yellow_card': 0.92957854, 'no_event': 0.95980394, 'Red_card': 0.9107433, 'Penalty': 0.9380356}
#
# Testing Direct_free-kick training clips...
#   File: 35_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9404507, 'Direct_free-kick': 0.94265294, 'Yellow_card': 0.8706279, 'no_event': 0.9512007, 'Red_card': 0.80609095, 'Penalty': 0.9429145}
#   File: 46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.96254265, 'Direct_free-kick': 0.953513, 'Yellow_card': 0.8746679, 'no_event': 0.9502096, 'Red_card': 0.82069933, 'Penalty': 0.9112073}
#   File: 11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.94618917, 'Direct_free-kick': 0.963096, 'Yellow_card': 0.8892795, 'no_event': 0.93614775, 'Red_card': 0.8381501, 'Penalty': 0.90786606}
#   File: 54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9555311, 'Direct_free-kick': 0.9471761, 'Yellow_card': 0.88631904, 'no_event': 0.94604707, 'Red_card': 0.8619994, 'Penalty': 0.90773785}
#   File: 39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9459945, 'Direct_free-kick': 0.9520394, 'Yellow_card': 0.87015694, 'no_event': 0.942923, 'Red_card': 0.83832633, 'Penalty': 0.9231874}
#   File: 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.954825, 'Direct_free-kick': 0.94763327, 'Yellow_card': 0.9299052, 'no_event': 0.9503218, 'Red_card': 0.88764465, 'Penalty': 0.9239179}
#   File: 40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9538258, 'Direct_free-kick': 0.9651489, 'Yellow_card': 0.91772884, 'no_event': 0.96104544, 'Red_card': 0.8881244, 'Penalty': 0.9228083}
#   File: 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.941749, 'Direct_free-kick': 0.9595177, 'Yellow_card': 0.8859028, 'no_event': 0.94965744, 'Red_card': 0.8291079, 'Penalty': 0.9086493}
#   File: 14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.95778215, 'Direct_free-kick': 0.9607598, 'Yellow_card': 0.91735893, 'no_event': 0.9464235, 'Red_card': 0.8690851, 'Penalty': 0.91833436}
#   File: 47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9464778, 'Direct_free-kick': 0.9529653, 'Yellow_card': 0.8676946, 'no_event': 0.9585401, 'Red_card': 0.8168974, 'Penalty': 0.8955411}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9385539, 'Direct_free-kick': 0.94795954, 'Yellow_card': 0.8301615, 'no_event': 0.9361735, 'Red_card': 0.81133175, 'Penalty': 0.8880068}
#   File: 43_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9388023, 'Direct_free-kick': 0.95234287, 'Yellow_card': 0.8884701, 'no_event': 0.93531346, 'Red_card': 0.8180283, 'Penalty': 0.9100889}
#
# Testing Yellow_card training clips...
#   File: 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8923622, 'Direct_free-kick': 0.8752927, 'Yellow_card': 0.9264797, 'no_event': 0.8947865, 'Red_card': 0.84533536, 'Penalty': 0.8818344}
#   File: 2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.87310946, 'Direct_free-kick': 0.8363747, 'Yellow_card': 0.94132435, 'no_event': 0.86545384, 'Red_card': 0.8895534, 'Penalty': 0.86427176}
#   File: 24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9222364, 'Direct_free-kick': 0.9021563, 'Yellow_card': 0.95437306, 'no_event': 0.9297881, 'Red_card': 0.89483124, 'Penalty': 0.90838265}
#   File: 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.96200836, 'Direct_free-kick': 0.9391977, 'Yellow_card': 0.95015824, 'no_event': 0.9589016, 'Red_card': 0.8968844, 'Penalty': 0.92107415}
#   File: 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9232546, 'Direct_free-kick': 0.9128623, 'Yellow_card': 0.95016754, 'no_event': 0.9424769, 'Red_card': 0.893534, 'Penalty': 0.9054178}
#   File: 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9444098, 'Direct_free-kick': 0.9222344, 'Yellow_card': 0.9662464, 'no_event': 0.93993425, 'Red_card': 0.92020917, 'Penalty': 0.91102123}
#   File: 23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9393387, 'Direct_free-kick': 0.92101043, 'Yellow_card': 0.93791366, 'no_event': 0.94177103, 'Red_card': 0.9067723, 'Penalty': 0.90161073}
#   File: 16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8717375, 'Direct_free-kick': 0.8407675, 'Yellow_card': 0.94592595, 'no_event': 0.86579657, 'Red_card': 0.89560956, 'Penalty': 0.85435045}
#   File: 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8842088, 'Direct_free-kick': 0.86050403, 'Yellow_card': 0.9609593, 'no_event': 0.88583595, 'Red_card': 0.89414823, 'Penalty': 0.8623763}
#   File: 37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.90913653, 'Direct_free-kick': 0.8813131, 'Yellow_card': 0.9620087, 'no_event': 0.9009285, 'Red_card': 0.9088088, 'Penalty': 0.88271713}
#   File: 41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.92958134, 'Direct_free-kick': 0.9138112, 'Yellow_card': 0.9754282, 'no_event': 0.9358326, 'Red_card': 0.9064226, 'Penalty': 0.9160361}
#   File: 8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.90398693, 'Direct_free-kick': 0.8645015, 'Yellow_card': 0.9492545, 'no_event': 0.8876564, 'Red_card': 0.89788985, 'Penalty': 0.889068}
#
# Testing no_event training clips...
#   File: ng32_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9382497, 'Direct_free-kick': 0.9285221, 'Yellow_card': 0.9318765, 'no_event': 0.945115, 'Red_card': 0.87747586, 'Penalty': 0.88922244}
#   File: ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8762981, 'Direct_free-kick': 0.8419889, 'Yellow_card': 0.92764235, 'no_event': 0.86151975, 'Red_card': 0.889505, 'Penalty': 0.8555329}
#   File: ng57_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9344562, 'Direct_free-kick': 0.9374844, 'Yellow_card': 0.86658216, 'no_event': 0.9557566, 'Red_card': 0.8251866, 'Penalty': 0.8966888}
#   File: ng5_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.92814076, 'Direct_free-kick': 0.9168191, 'Yellow_card': 0.8848642, 'no_event': 0.9192318, 'Red_card': 0.8509258, 'Penalty': 0.88496447}
#   File: ng8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.94802755, 'Direct_free-kick': 0.9560939, 'Yellow_card': 0.86800814, 'no_event': 0.95987904, 'Red_card': 0.8302071, 'Penalty': 0.90467155}
#   File: ng11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9474201, 'Direct_free-kick': 0.9476787, 'Yellow_card': 0.93634075, 'no_event': 0.9545429, 'Red_card': 0.8554172, 'Penalty': 0.9187924}
#   File: ng13_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.95840764, 'Direct_free-kick': 0.9730437, 'Yellow_card': 0.9014861, 'no_event': 0.96552956, 'Red_card': 0.8645721, 'Penalty': 0.9271225}
#   File: ng51_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.92785585, 'Direct_free-kick': 0.9320035, 'Yellow_card': 0.8778894, 'no_event': 0.9499915, 'Red_card': 0.8516603, 'Penalty': 0.87826604}
#   File: ng61_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.95279413, 'Direct_free-kick': 0.9389595, 'Yellow_card': 0.93704295, 'no_event': 0.9417758, 'Red_card': 0.8668591, 'Penalty': 0.9125586}
#   File: ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.92167133, 'Direct_free-kick': 0.9280906, 'Yellow_card': 0.8854563, 'no_event': 0.9468363, 'Red_card': 0.803122, 'Penalty': 0.87829036}
#   File: ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9343245, 'Direct_free-kick': 0.94614464, 'Yellow_card': 0.8873713, 'no_event': 0.9458226, 'Red_card': 0.8190472, 'Penalty': 0.8997284}
#   File: ng62_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9523887, 'Direct_free-kick': 0.945049, 'Yellow_card': 0.8927933, 'no_event': 0.95660317, 'Red_card': 0.86143565, 'Penalty': 0.90254295}
#
# Testing Red_card training clips...
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9186811, 'Direct_free-kick': 0.8953749, 'Yellow_card': 0.9681744, 'no_event': 0.91788554, 'Red_card': 0.9157106, 'Penalty': 0.8969009}
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9109402, 'Direct_free-kick': 0.87377334, 'Yellow_card': 0.9635184, 'no_event': 0.9011749, 'Red_card': 0.9113642, 'Penalty': 0.8978254}
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.91018474, 'Direct_free-kick': 0.8792576, 'Yellow_card': 0.9667012, 'no_event': 0.9070635, 'Red_card': 0.91324526, 'Penalty': 0.89455825}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.90079445, 'Direct_free-kick': 0.87321615, 'Yellow_card': 0.94610417, 'no_event': 0.8899669, 'Red_card': 0.8971108, 'Penalty': 0.8754044}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.87682194, 'Direct_free-kick': 0.85640526, 'Yellow_card': 0.93250567, 'no_event': 0.88106114, 'Red_card': 0.8876145, 'Penalty': 0.8506321}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8888357, 'Direct_free-kick': 0.8636912, 'Yellow_card': 0.9435224, 'no_event': 0.884911, 'Red_card': 0.9007198, 'Penalty': 0.86210203}
#
# Testing Penalty training clips...
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9558965, 'Direct_free-kick': 0.9360539, 'Yellow_card': 0.94614375, 'no_event': 0.94591707, 'Red_card': 0.9007979, 'Penalty': 0.92511356}
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.93475974, 'Direct_free-kick': 0.9094776, 'Yellow_card': 0.92313445, 'no_event': 0.92064023, 'Red_card': 0.87749505, 'Penalty': 0.9110917}
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9597467, 'Direct_free-kick': 0.9414923, 'Yellow_card': 0.9462713, 'no_event': 0.95281076, 'Red_card': 0.9001884, 'Penalty': 0.932253}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9672812, 'Direct_free-kick': 0.9409454, 'Yellow_card': 0.92157817, 'no_event': 0.94753, 'Red_card': 0.8872519, 'Penalty': 0.9260371}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9680055, 'Direct_free-kick': 0.9484496, 'Yellow_card': 0.9048574, 'no_event': 0.9545482, 'Red_card': 0.85052466, 'Penalty': 0.92743087}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.97170246, 'Direct_free-kick': 0.9484519, 'Yellow_card': 0.914435, 'no_event': 0.9525083, 'Red_card': 0.87481236, 'Penalty': 0.9345175}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_after.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9591887, 'Direct_free-kick': 0.9450955, 'Yellow_card': 0.9407424, 'no_event': 0.94735205, 'Red_card': 0.88720155, 'Penalty': 0.930411}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_before.npy
#     True: Penalty, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.93414295, 'Direct_free-kick': 0.9440167, 'Yellow_card': 0.87333614, 'no_event': 0.9265778, 'Red_card': 0.82902557, 'Penalty': 0.90465677}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9583918, 'Direct_free-kick': 0.9562939, 'Yellow_card': 0.9133007, 'no_event': 0.9484379, 'Red_card': 0.86747706, 'Penalty': 0.925557}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_after.npy
#     True: Penalty, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.94838834, 'Direct_free-kick': 0.9232445, 'Yellow_card': 0.9523534, 'no_event': 0.9442299, 'Red_card': 0.8872665, 'Penalty': 0.9424151}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_before.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.95961124, 'Direct_free-kick': 0.9402482, 'Yellow_card': 0.9135244, 'no_event': 0.9456059, 'Red_card': 0.87131476, 'Penalty': 0.955328}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.96116656, 'Direct_free-kick': 0.93782526, 'Yellow_card': 0.93088466, 'no_event': 0.9498435, 'Red_card': 0.8836177, 'Penalty': 0.95713973}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5303
# Weighted Precision: 0.4181
# Weighted Recall: 0.5303
# Weighted F₁ Score: 0.4502
#
# Per-class Accuracy:
#   Goal: 0.9167 (11/12)
#   Direct_free-kick: 0.5833 (7/12)
#   Yellow_card: 0.8333 (10/12)
#   no_event: 0.5833 (7/12)
#   Red_card: 0.0000 (0/6)
#   Penalty: 0.0000 (0/12)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event', 'Red_card', 'Penalty']
# [[11  0  0  1  0  0]
#  [ 3  7  0  2  0  0]
#  [ 1  0 10  1  0  0]
#  [ 2  2  1  7  0  0]
#  [ 0  0  6  0  0  0]
#  [10  1  1  0  0  0]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.41      0.92      0.56        12
# Direct_free-kick       0.70      0.58      0.64        12
#      Yellow_card       0.56      0.83      0.67        12
#         no_event       0.64      0.58      0.61        12
#         Red_card       0.00      0.00      0.00         6
#          Penalty       0.00      0.00      0.00        12
#
#         accuracy                           0.53        66
#        macro avg       0.38      0.49      0.41        66
#     weighted avg       0.42      0.53      0.45        66
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 66
# Training samples: 66
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → no_event: 1 times
#   Direct_free-kick → Goal: 3 times
#   Direct_free-kick → no_event: 2 times
#   Yellow_card → Goal: 1 times
#   Yellow_card → no_event: 1 times
#   no_event → Goal: 2 times
#   no_event → Direct_free-kick: 2 times
#   no_event → Yellow_card: 1 times
#   Red_card → Yellow_card: 6 times
#   Penalty → Goal: 10 times
#   Penalty → Direct_free-kick: 1 times
#   Penalty → Yellow_card: 1 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.5303
# Training Set Accuracy: 0.5303
# Weighted Precision: 0.4181
# Weighted Recall: 0.5303
# Weighted F₁ Score: 0.4502
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, num_prototype_samples=5):
    """
    Build prototypes for each event class from randomly selected test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        num_prototype_samples (int): Number of random samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_prototype_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for prototype")
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, num_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} random test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples=12):
    """
    Evaluate classification performance on a random subset of training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        num_eval_samples (int): Number of random samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON {num_eval_samples} RANDOM TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_eval_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for evaluation")
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, num_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from random 5 test samples,
    and evaluates on 12 random training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Random Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/sliding-window/R(2+1)D embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event", "Red_card", "Penalty"]
    
    # Number of test samples to use for prototype creation
    num_prototype_samples = 7
    
    # Number of training samples to evaluate per class
    num_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from random subset of test embeddings
    print(f"\nStep 1: Building prototypes from {num_prototype_samples} random test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, num_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on random training samples
    print(f"\nStep 2: Evaluating classification performance on {num_eval_samples} random training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Random Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 29 embeddings in Goal/Train
#   Found 8 embeddings in Goal/Test
#   Found 50 embeddings in Direct_free-kick/Train
#   Found 13 embeddings in Direct_free-kick/Test
#   Found 48 embeddings in Yellow_card/Train
#   Found 13 embeddings in Yellow_card/Test
#   Found 55 embeddings in no_event/Train
#   Found 14 embeddings in no_event/Test
#   Found 6 embeddings in Red_card/Train
#   Found 3 embeddings in Red_card/Test
#   Found 12 embeddings in Penalty/Train
#   Found 3 embeddings in Penalty/Test
#
# Step 1: Building prototypes from 7 random test samples per class...
# Loading 7 random test embeddings for Goal prototype...
#   Selected 28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (512,))
#   Selected 31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
#   Selected 30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
#   Selected 14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
#   Selected 29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (512,))
#   Selected 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
#   Selected 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy for prototype (shape: (512,))
# Built prototype for Goal from 7 test samples
# Loading 7 random test embeddings for Direct_free-kick prototype...
#   Selected 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (512,))
#   Selected 25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
#   Selected 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (512,))
#   Selected 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (512,))
#   Selected 63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy for prototype (shape: (512,))
# Built prototype for Direct_free-kick from 7 test samples
# Loading 7 random test embeddings for Yellow_card prototype...
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy for prototype (shape: (512,))
#   Selected 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy for prototype (shape: (512,))
#   Selected 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (512,))
#   Selected 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (512,))
#   Selected 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (512,))
#   Selected 5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (512,))
#   Selected 40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy for prototype (shape: (512,))
# Built prototype for Yellow_card from 7 test samples
# Loading 7 random test embeddings for no_event prototype...
#   Selected ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (512,))
#   Selected ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (512,))
#   Selected ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (512,))
#   Selected ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
#   Selected ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (512,))
#   Selected ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (512,))
# Built prototype for no_event from 7 test samples
# Warning: Only 3 files available for Red_card, using all of them for prototype
# Loading 3 random test embeddings for Red_card prototype...
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy for prototype (shape: (512,))
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy for prototype (shape: (512,))
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy for prototype (shape: (512,))
# Built prototype for Red_card from 3 test samples
# Warning: Only 3 files available for Penalty, using all of them for prototype
# Loading 3 random test embeddings for Penalty prototype...
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy for prototype (shape: (512,))
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy for prototype (shape: (512,))
#   Selected 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy for prototype (shape: (512,))
# Built prototype for Penalty from 3 test samples
#
# Successfully built prototypes for 6 classes:
#   Goal: shape (512,)
#   Direct_free-kick: shape (512,)
#   Yellow_card: shape (512,)
#   no_event: shape (512,)
#   Red_card: shape (512,)
#   Penalty: shape (512,)
#
# Files used for prototype creation:
#   Goal: ['28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', '30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', '14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy']
#   Direct_free-kick: ['13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy', '25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy', '30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy']
#   Yellow_card: ['1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy', '60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy', '25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy', '19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy', '38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', '5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy', '40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy']
#   no_event: ['ng26_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy', 'ng42_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', 'ng18_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', 'ng12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', 'ng60_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', 'ng24_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy', 'ng36_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy']
#   Red_card: ['1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_after.npy', '1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_before.npy', '1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley_normal.npy']
#   Penalty: ['5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_after.npy', '5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_before.npy', '5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham_normal.npy']
#
# Step 2: Evaluating classification performance on 12 random training samples per class...
#
# ============================================================
# EVALUATING ON 12 RANDOM TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.907285, 'Direct_free-kick': 0.9183936, 'Yellow_card': 0.8440217, 'no_event': 0.92179954, 'Red_card': 0.8231869, 'Penalty': 0.8681332}
#   File: 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.92503643, 'Direct_free-kick': 0.8957764, 'Yellow_card': 0.8803499, 'no_event': 0.90281075, 'Red_card': 0.80218613, 'Penalty': 0.88853455}
#   File: 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8830435, 'Direct_free-kick': 0.9017277, 'Yellow_card': 0.7300364, 'no_event': 0.8797984, 'Red_card': 0.70297, 'Penalty': 0.78200316}
#   File: 13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8555465, 'Direct_free-kick': 0.87222636, 'Yellow_card': 0.641714, 'no_event': 0.8471689, 'Red_card': 0.6092645, 'Penalty': 0.7170975}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Goal, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.82514966, 'Direct_free-kick': 0.80597985, 'Yellow_card': 0.9240533, 'no_event': 0.84251, 'Red_card': 0.84003377, 'Penalty': 0.85093206}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.90765196, 'Direct_free-kick': 0.9216771, 'Yellow_card': 0.7803117, 'no_event': 0.9084406, 'Red_card': 0.7390708, 'Penalty': 0.8477553}
#   File: 9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.90204144, 'Direct_free-kick': 0.9308002, 'Yellow_card': 0.7427338, 'no_event': 0.91559255, 'Red_card': 0.71959794, 'Penalty': 0.81710345}
#   File: 36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.9157384, 'Direct_free-kick': 0.89387566, 'Yellow_card': 0.79014754, 'no_event': 0.8912912, 'Red_card': 0.73907954, 'Penalty': 0.9187367}
#   File: 19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9133712, 'Direct_free-kick': 0.9111364, 'Yellow_card': 0.806353, 'no_event': 0.9273516, 'Red_card': 0.74553806, 'Penalty': 0.8095449}
#   File: 26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9064869, 'Direct_free-kick': 0.91847825, 'Yellow_card': 0.7852466, 'no_event': 0.9226825, 'Red_card': 0.7908471, 'Penalty': 0.8362644}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.93450356, 'Direct_free-kick': 0.9116842, 'Yellow_card': 0.7959273, 'no_event': 0.90309834, 'Red_card': 0.72188985, 'Penalty': 0.8618349}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9434724, 'Direct_free-kick': 0.9350877, 'Yellow_card': 0.825354, 'no_event': 0.9332502, 'Red_card': 0.7800056, 'Penalty': 0.87634206}
#
# Testing Direct_free-kick training clips...
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.83981746, 'Direct_free-kick': 0.8802678, 'Yellow_card': 0.63934565, 'no_event': 0.8526658, 'Red_card': 0.6209122, 'Penalty': 0.7200458}
#   File: 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8960748, 'Direct_free-kick': 0.9285449, 'Yellow_card': 0.7823131, 'no_event': 0.9010689, 'Red_card': 0.73985004, 'Penalty': 0.8652303}
#   File: 18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8485059, 'Direct_free-kick': 0.9114842, 'Yellow_card': 0.6983905, 'no_event': 0.8960399, 'Red_card': 0.68091583, 'Penalty': 0.7434031}
#   File: 34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.84756917, 'Direct_free-kick': 0.8991469, 'Yellow_card': 0.7484732, 'no_event': 0.8734626, 'Red_card': 0.8017973, 'Penalty': 0.7894906}
#   File: 21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9151361, 'Direct_free-kick': 0.9325216, 'Yellow_card': 0.72702634, 'no_event': 0.9098562, 'Red_card': 0.6932037, 'Penalty': 0.8022562}
#   File: 10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9138614, 'Direct_free-kick': 0.9209749, 'Yellow_card': 0.85328394, 'no_event': 0.92055327, 'Red_card': 0.79210544, 'Penalty': 0.8309705}
#   File: 7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8873078, 'Direct_free-kick': 0.92490613, 'Yellow_card': 0.74281573, 'no_event': 0.8961754, 'Red_card': 0.7056776, 'Penalty': 0.79945517}
#   File: 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9049799, 'Direct_free-kick': 0.91543084, 'Yellow_card': 0.84562373, 'no_event': 0.9046563, 'Red_card': 0.8466613, 'Penalty': 0.8494414}
#   File: 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.89439666, 'Direct_free-kick': 0.904772, 'Yellow_card': 0.7105057, 'no_event': 0.9016705, 'Red_card': 0.6752913, 'Penalty': 0.7909893}
#   File: 15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.85185623, 'Direct_free-kick': 0.88149095, 'Yellow_card': 0.8248353, 'no_event': 0.8961015, 'Red_card': 0.83454585, 'Penalty': 0.81113034}
#   File: 37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.87566984, 'Direct_free-kick': 0.88398653, 'Yellow_card': 0.7678611, 'no_event': 0.8710644, 'Red_card': 0.73703027, 'Penalty': 0.8039688}
#   File: 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.82328385, 'Direct_free-kick': 0.8707994, 'Yellow_card': 0.679973, 'no_event': 0.8505701, 'Red_card': 0.6735742, 'Penalty': 0.7552599}
#
# Testing Yellow_card training clips...
#   File: 37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.81457555, 'Direct_free-kick': 0.7806702, 'Yellow_card': 0.90812945, 'no_event': 0.8264271, 'Red_card': 0.87028027, 'Penalty': 0.8051609}
#   File: 18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7749293, 'Direct_free-kick': 0.7598702, 'Yellow_card': 0.9192158, 'no_event': 0.8268652, 'Red_card': 0.9053285, 'Penalty': 0.777315}
#   File: 47_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Red_card, Correct: False
#     Similarities: {'Goal': 0.7399845, 'Direct_free-kick': 0.7318057, 'Yellow_card': 0.8741485, 'no_event': 0.77892435, 'Red_card': 0.8971336, 'Penalty': 0.7523327}
#   File: 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8077735, 'Direct_free-kick': 0.7792417, 'Yellow_card': 0.88692284, 'no_event': 0.8164849, 'Red_card': 0.81197727, 'Penalty': 0.80810976}
#   File: 6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.77740693, 'Direct_free-kick': 0.7807238, 'Yellow_card': 0.8345192, 'no_event': 0.8111519, 'Red_card': 0.8253628, 'Penalty': 0.7334703}
#   File: 44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8947555, 'Direct_free-kick': 0.8843283, 'Yellow_card': 0.86645836, 'no_event': 0.88701594, 'Red_card': 0.78750336, 'Penalty': 0.87002325}
#   File: 30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.786144, 'Direct_free-kick': 0.75212216, 'Yellow_card': 0.8520069, 'no_event': 0.7869018, 'Red_card': 0.7948096, 'Penalty': 0.76387596}
#   File: 29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.82232416, 'Direct_free-kick': 0.8774628, 'Yellow_card': 0.6874416, 'no_event': 0.8609248, 'Red_card': 0.66646826, 'Penalty': 0.7612389}
#   File: 4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.79263556, 'Direct_free-kick': 0.7502754, 'Yellow_card': 0.92985255, 'no_event': 0.8018372, 'Red_card': 0.8569559, 'Penalty': 0.85030615}
#   File: 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91434205, 'Direct_free-kick': 0.8788433, 'Yellow_card': 0.81365025, 'no_event': 0.87515175, 'Red_card': 0.7156371, 'Penalty': 0.87368155}
#   File: 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.76075006, 'Direct_free-kick': 0.7180878, 'Yellow_card': 0.8666756, 'no_event': 0.7786162, 'Red_card': 0.81819004, 'Penalty': 0.74772644}
#   File: 43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8065865, 'Direct_free-kick': 0.76869154, 'Yellow_card': 0.9180777, 'no_event': 0.818551, 'Red_card': 0.8401742, 'Penalty': 0.8191229}
#
# Testing no_event training clips...
#   File: ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.90791214, 'Direct_free-kick': 0.90970796, 'Yellow_card': 0.7005682, 'no_event': 0.89441264, 'Red_card': 0.6594099, 'Penalty': 0.7968833}
#   File: ng34_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8612492, 'Direct_free-kick': 0.9123172, 'Yellow_card': 0.748201, 'no_event': 0.8962598, 'Red_card': 0.7551263, 'Penalty': 0.7676035}
#   File: ng41_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: Red_card, Correct: False
#     Similarities: {'Goal': 0.74892366, 'Direct_free-kick': 0.75459576, 'Yellow_card': 0.8392069, 'no_event': 0.786915, 'Red_card': 0.85700715, 'Penalty': 0.73842597}
#   File: ng64_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.867048, 'Direct_free-kick': 0.85479254, 'Yellow_card': 0.8672317, 'no_event': 0.88522947, 'Red_card': 0.8358979, 'Penalty': 0.82338506}
#   File: ng50_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.83984303, 'Direct_free-kick': 0.865751, 'Yellow_card': 0.6836641, 'no_event': 0.8755389, 'Red_card': 0.67219, 'Penalty': 0.75739545}
#   File: ng67_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8550128, 'Direct_free-kick': 0.9001242, 'Yellow_card': 0.6681868, 'no_event': 0.8775431, 'Red_card': 0.6708025, 'Penalty': 0.7632358}
#   File: ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.89803416, 'Direct_free-kick': 0.9236006, 'Yellow_card': 0.7168056, 'no_event': 0.90005517, 'Red_card': 0.6686512, 'Penalty': 0.79641205}
#   File: ng66_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.89485615, 'Direct_free-kick': 0.88760877, 'Yellow_card': 0.8315645, 'no_event': 0.8942731, 'Red_card': 0.8265045, 'Penalty': 0.86968076}
#   File: ng13_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9178852, 'Direct_free-kick': 0.93475354, 'Yellow_card': 0.8055428, 'no_event': 0.9129346, 'Red_card': 0.7638644, 'Penalty': 0.82838726}
#   File: ng63_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.85493875, 'Direct_free-kick': 0.8181822, 'Yellow_card': 0.83823806, 'no_event': 0.82155466, 'Red_card': 0.75206035, 'Penalty': 0.85208297}
#   File: ng38_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8035595, 'Direct_free-kick': 0.8373928, 'Yellow_card': 0.6332478, 'no_event': 0.83284706, 'Red_card': 0.6421722, 'Penalty': 0.69393414}
#   File: ng59_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.78636783, 'Direct_free-kick': 0.753711, 'Yellow_card': 0.9184778, 'no_event': 0.80897844, 'Red_card': 0.83177024, 'Penalty': 0.7865557}
#
# Testing Red_card training clips...
# Warning: Only 6 files available for Red_card, using all of them for evaluation
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7869359, 'Direct_free-kick': 0.74853766, 'Yellow_card': 0.92804617, 'no_event': 0.8068259, 'Red_card': 0.88595283, 'Penalty': 0.8192589}
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.76383716, 'Direct_free-kick': 0.7153825, 'Yellow_card': 0.93015194, 'no_event': 0.7814424, 'Red_card': 0.87034404, 'Penalty': 0.8252832}
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.78464615, 'Direct_free-kick': 0.7411447, 'Yellow_card': 0.9309499, 'no_event': 0.8059206, 'Red_card': 0.87735355, 'Penalty': 0.830971}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.779173, 'Direct_free-kick': 0.7501131, 'Yellow_card': 0.9167746, 'no_event': 0.7948741, 'Red_card': 0.8490978, 'Penalty': 0.7697269}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.785025, 'Direct_free-kick': 0.7726065, 'Yellow_card': 0.8621256, 'no_event': 0.7900428, 'Red_card': 0.8135845, 'Penalty': 0.7671198}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7878561, 'Direct_free-kick': 0.7676002, 'Yellow_card': 0.9173035, 'no_event': 0.8163749, 'Red_card': 0.8880228, 'Penalty': 0.7765658}
#
# Testing Penalty training clips...
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_after.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91979337, 'Direct_free-kick': 0.9005028, 'Yellow_card': 0.8347364, 'no_event': 0.895499, 'Red_card': 0.7770543, 'Penalty': 0.8790885}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_before.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.92234063, 'Direct_free-kick': 0.8963609, 'Yellow_card': 0.80734307, 'no_event': 0.8784714, 'Red_card': 0.725394, 'Penalty': 0.8480247}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8933685, 'Direct_free-kick': 0.8813915, 'Yellow_card': 0.80036855, 'no_event': 0.88312113, 'Red_card': 0.7669828, 'Penalty': 0.86141694}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_before.npy
#     True: Penalty, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.91066855, 'Direct_free-kick': 0.9161139, 'Yellow_card': 0.7794044, 'no_event': 0.910509, 'Red_card': 0.75879514, 'Penalty': 0.8601874}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_after.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9280527, 'Direct_free-kick': 0.89578795, 'Yellow_card': 0.87530947, 'no_event': 0.9076795, 'Red_card': 0.81908643, 'Penalty': 0.9211467}
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_normal.npy
#     True: Penalty, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8341707, 'Direct_free-kick': 0.80341566, 'Yellow_card': 0.9207047, 'no_event': 0.83655447, 'Red_card': 0.84638053, 'Penalty': 0.8618161}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_before.npy
#     True: Penalty, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8888663, 'Direct_free-kick': 0.91274345, 'Yellow_card': 0.7322475, 'no_event': 0.8926019, 'Red_card': 0.70458245, 'Penalty': 0.8173479}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8783052, 'Direct_free-kick': 0.84377533, 'Yellow_card': 0.8261012, 'no_event': 0.8517969, 'Red_card': 0.738375, 'Penalty': 0.81832623}
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_before.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8759147, 'Direct_free-kick': 0.8576, 'Yellow_card': 0.86128366, 'no_event': 0.85439825, 'Red_card': 0.7908154, 'Penalty': 0.86666733}
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea_after.npy
#     True: Penalty, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.85277337, 'Direct_free-kick': 0.8552618, 'Yellow_card': 0.8655361, 'no_event': 0.8635286, 'Red_card': 0.79340315, 'Penalty': 0.8517013}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland_normal.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.911446, 'Direct_free-kick': 0.9018599, 'Yellow_card': 0.8026918, 'no_event': 0.89804065, 'Red_card': 0.7744837, 'Penalty': 0.8867607}
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland_after.npy
#     True: Penalty, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8642154, 'Direct_free-kick': 0.8288919, 'Yellow_card': 0.88711226, 'no_event': 0.85743785, 'Red_card': 0.84684706, 'Penalty': 0.86142534}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.3636
# Weighted Precision: 0.2595
# Weighted Recall: 0.3636
# Weighted F₁ Score: 0.2873
#
# Per-class Accuracy:
#   Goal: 0.2500 (3/12)
#   Direct_free-kick: 0.9167 (11/12)
#   Yellow_card: 0.6667 (8/12)
#   no_event: 0.1667 (2/12)
#   Red_card: 0.0000 (0/6)
#   Penalty: 0.0000 (0/12)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event', 'Red_card', 'Penalty']
# [[ 3  4  1  3  0  1]
#  [ 0 11  0  1  0  0]
#  [ 2  1  8  0  1  0]
#  [ 2  6  1  2  1  0]
#  [ 0  0  6  0  0  0]
#  [ 7  2  3  0  0  0]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.21      0.25      0.23        12
# Direct_free-kick       0.46      0.92      0.61        12
#      Yellow_card       0.42      0.67      0.52        12
#         no_event       0.33      0.17      0.22        12
#         Red_card       0.00      0.00      0.00         6
#          Penalty       0.00      0.00      0.00        12
#
#         accuracy                           0.36        66
#        macro avg       0.24      0.33      0.26        66
#     weighted avg       0.26      0.36      0.29        66
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 66
# Training samples: 66
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 4 times
#   Goal → Yellow_card: 1 times
#   Goal → no_event: 3 times
#   Goal → Penalty: 1 times
#   Direct_free-kick → no_event: 1 times
#   Yellow_card → Goal: 2 times
#   Yellow_card → Direct_free-kick: 1 times
#   Yellow_card → Red_card: 1 times
#   no_event → Goal: 2 times
#   no_event → Direct_free-kick: 6 times
#   no_event → Yellow_card: 1 times
#   no_event → Red_card: 1 times
#   Red_card → Yellow_card: 6 times
#   Penalty → Goal: 7 times
#   Penalty → Direct_free-kick: 2 times
#   Penalty → Yellow_card: 3 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.3636
# Training Set Accuracy: 0.3636
# Weighted Precision: 0.2595
# Weighted Recall: 0.3636
# Weighted F₁ Score: 0.2873
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================
