# %%
import os
import json
from moviepy import VideoFileClip
import random
import warnings
warnings.filterwarnings('ignore')

def extract_event_clips_moviepy():
    """
    Extract clips for multiple events ("Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty")
    and generate random non-event clips without enforcing min_clips per match.
    """
    # Base directory containing season folders
    base_dir = "F:/AIM Lab/Experiment"
    clips_base_dir = os.path.join(base_dir, "Multiclass-unequal samples", "Clips")
    
    # Create base clips directory if it doesn't exist
    os.makedirs(clips_base_dir, exist_ok=True)
    
    # Event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty"]
    event_dirs = {event: os.path.join(clips_base_dir, event.replace(" ", "_")) for event in event_types}
    random_clips_dir = os.path.join(clips_base_dir, "no_event")
    
    # Create directories for each event and random clips
    for event_dir in event_dirs.values():
        os.makedirs(event_dir, exist_ok=True)
    os.makedirs(random_clips_dir, exist_ok=True)
    
    # Counters for clips
    event_counters = {event: 1 for event in event_types}
    random_counter = 1
    
    # Iterate through season folders (e.g., 2014-2015, 2015-2014)
    for season_folder in os.listdir(base_dir):
        season_path = os.path.join(base_dir, season_folder)
        if os.path.isdir(season_path) and season_folder.startswith("20"):
            print(f"Processing season: {season_folder}")
            
            # Iterate through match folders
            for match_folder in os.listdir(season_path):
                match_path = os.path.join(season_path, match_folder)
                if os.path.isdir(match_path):
                    print(f"  Processing match: {match_folder}")
                    
                    # Look for Labels-v2.json file
                    labels_file = os.path.join(match_path, "Labels-v2.json")
                    video_file = os.path.join(match_path, "2_720p.mkv")
                    
                    if os.path.exists(labels_file) and os.path.exists(video_file):
                        # Extract events from second half
                        event_timestamps = extract_event_timestamps(labels_file, event_types)
                        
                        # Load video once for all clips from this match
                        try:
                            video = VideoFileClip(video_file)
                            video_duration = video.duration
                            
                            # Create clips for each event
                            for event, timestamps in event_timestamps.items():
                                for timestamp in timestamps:
                                    create_event_clip_moviepy(
                                        video, 
                                        timestamp, 
                                        event_dirs[event], 
                                        f"{event_counters[event]}_{match_folder}",
                                        event
                                    )
                                    event_counters[event] += 1
                            
                            # Generate random non-event clips
                            avoided_intervals = generate_avoided_intervals(event_timestamps)
                            num_random_clips = sum(len(timestamps) for timestamps in event_timestamps.values())
                            random_start_times = generate_random_segments(video_duration, avoided_intervals, num_random_clips, 7.0)
                            
                            for start_time in random_start_times:
                                create_random_clip_moviepy(
                                    video, 
                                    start_time, 
                                    random_clips_dir, 
                                    f"ng{random_counter}_{match_folder}"
                                )
                                random_counter += 1
                            
                            # Close video to free memory
                            video.close()
                            
                        except Exception as e:
                            print(f"    Error loading video: {e}")
                    else:
                        if not os.path.exists(labels_file):
                            print(f"    Labels-v2.json not found")
                        if not os.path.exists(video_file):
                            print(f"    2_720p.mkv not found")

def extract_event_timestamps(labels_file, event_types):
    """
    Extract timestamps for specified events from the second half of the match.
    
    Args:
        labels_file (str): Path to the Labels-v2.json file
        event_types (list): List of event types to extract
        
    Returns:
        dict: Dictionary with event types as keys and lists of timestamps as values
    """
    try:
        with open(labels_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event_timestamps = {event: [] for event in event_types}
        
        for annotation in data.get('annotations', []):
            label = annotation.get('label')
            game_time = annotation.get('gameTime', '')
            
            if label in event_types and game_time.startswith('2 -'):
                position = int(annotation.get('position', 0))
                event_timestamps[label].append(position)
        
        return event_timestamps
        
    except Exception as e:
        print(f"    Error reading labels file: {e}")
        return {event: [] for event in event_types}

def create_event_clip_moviepy(video_clip, position_ms, output_dir, clip_name, event):
    """
    Create a 7-second video clip around the event time using MoviePy.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        position_ms (int): Event position in milliseconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
        event (str): Event type for logging
    """
    try:
        # Calculate start and end times (3 seconds before and after)
        start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before, but not negative
        end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after (total 7 seconds)
        
        # Make sure we don't exceed video duration
        end_seconds = min(end_seconds, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating clip {clip_name} for {event} at {start_seconds:.2f}s")
        
        # Extract the clip
        event_clip = video_clip.subclipped(start_seconds, end_seconds)
        
        # Write the clip to file
        event_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        event_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating clip {clip_name}: {e}")

def create_random_clip_moviepy(video_clip, start_time, output_dir, clip_name):
    """
    Create a random 7-second video clip.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        start_time (float): Start time in seconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
    """
    try:
        # Calculate end time
        end_time = start_time + 7.0  # 7 seconds duration
        
        # Make sure we don't exceed video duration
        end_time = min(end_time, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating random clip {clip_name}")
        
        # Extract the clip
        random_clip = video_clip.subclipped(start_time, end_time)
        
        # Write the clip to file
        random_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        random_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating random clip {clip_name}: {e}")

def generate_avoided_intervals(event_timestamps):
    """
    Generate avoided intervals for random clip generation based on event timestamps.
    
    Args:
        event_timestamps (dict): Dictionary of event timestamps
        
    Returns:
        list: List of avoided intervals (start, end) in seconds
    """
    avoided_intervals = []
    for timestamps in event_timestamps.values():
        for position_ms in timestamps:
            start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before
            end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after
            avoided_intervals.append((start_seconds, end_seconds))
    return avoided_intervals

def generate_random_segments(video_duration, avoided_intervals, num_segments, segment_duration):
    """
    Generate random segments avoiding specified intervals.
    
    Args:
        video_duration (float): Total duration of the video
        avoided_intervals (list): List of (start, end) intervals to avoid
        num_segments (int): Number of segments to generate
        segment_duration (float): Duration of each segment
        
    Returns:
        list: List of start times for random segments
    """
    random_segments = []
    max_attempts = 1000
    
    for _ in range(num_segments):
        attempts = 0
        while attempts < max_attempts:
            max_start = video_duration - segment_duration
            if max_start <= 0:
                break
            
            start_time = random.uniform(0, max_start)
            end_time = start_time + segment_duration
            
            # Check if this segment overlaps with any avoided interval
            overlap = False
            for avoid_start, avoid_end in avoided_intervals:
                if not (end_time <= avoid_start or start_time >= avoid_end):
                    overlap = True
                    break
            
            if not overlap:
                random_segments.append(start_time)
                break
            
            attempts += 1
        
        if attempts >= max_attempts:
            print(f"Warning: Could not find non-overlapping segment after {max_attempts} attempts")
    
    return random_segments

# Run the extraction
print("Multiclass Clip Extractor (MoviePy)")
print("===================================")

try:
    extract_event_clips_moviepy()
    print("\nProcessing complete!")
except ImportError:
    print("Error: MoviePy not installed. Install with: pip install moviepy")
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# Clip Limiter for Multiclass Dataset
# ==================================================
# This script will limit clips per match for:
#   - Direct_free-kick: max 2 clips per match
#   - no_event: max 2 clips per match
#   - Yellow_card: max 3 clips per match

# %%
import os
import re
from collections import defaultdict

def extract_match_name(filename):
    """
    Extract match name from filename by removing the prefix (e.g., "ng1_" or "5_").
    
    Args:
        filename (str): Filename like "ng1_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4"
    
    Returns:
        str: Match name like "2015-02-21 - 18-00 Swansea 2 - 1 Manchester United"
    """
    # Remove the prefix (e.g., "ng1_" or "5_") and file extension
    match = re.match(r'^[a-zA-Z0-9]+_(.+)\.mp4$', filename)
    if match:
        return match.group(1)
    return filename

def limit_clips_per_match(folder_path, max_clips_per_match):
    """
    Limit the number of clips per match in a folder.
    
    Args:
        folder_path (str): Path to the folder containing clips
        max_clips_per_match (int): Maximum number of clips allowed per match
    """
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        return
    
    # Get all mp4 files in the folder
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.mp4')]
    
    # Group files by match name
    match_files = defaultdict(list)
    for filename in all_files:
        match_name = extract_match_name(filename)
        match_files[match_name].append(filename)
    
    # Track statistics
    total_files = len(all_files)
    deleted_files = 0
    
    print(f"\nProcessing folder: {os.path.basename(folder_path)}")
    print(f"Total files before processing: {total_files}")
    print(f"Maximum clips per match: {max_clips_per_match}")
    
    # Process each match
    for match_name, files in match_files.items():
        if len(files) > max_clips_per_match:
            # Sort files to maintain consistent ordering (by prefix)
            files.sort(key=lambda x: int(re.match(r'^[a-zA-Z0-9]+', x).group(0).lstrip('ng')))
            
            # Keep only the first max_clips_per_match files
            files_to_keep = files[:max_clips_per_match]
            files_to_delete = files[max_clips_per_match:]
            
            print(f"\nMatch: {match_name}")
            print(f"  Found {len(files)} clips, keeping {len(files_to_keep)}, deleting {len(files_to_delete)}")
            
            # Delete excess files
            for file_to_delete in files_to_delete:
                file_path = os.path.join(folder_path, file_to_delete)
                try:
                    os.remove(file_path)
                    print(f"    Deleted: {file_to_delete}")
                    deleted_files += 1
                except Exception as e:
                    print(f"    Error deleting {file_to_delete}: {e}")
    
    remaining_files = total_files - deleted_files
    print(f"\nSummary for {os.path.basename(folder_path)}:")
    print(f"  Total files processed: {total_files}")
    print(f"  Files deleted: {deleted_files}")
    print(f"  Files remaining: {remaining_files}")

def main():
    """
    Main function to process all specified folders.
    """
    base_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips"
    
    # Define folder limits
    folder_limits = {
        "Direct_free-kick": 2,
        "no_event": 2,
        "Yellow_card": 3
    }
    
    print("Clip Limiter for Multiclass Dataset")
    print("=" * 50)
    print("This script will limit clips per match for:")
    for folder, limit in folder_limits.items():
        print(f"  - {folder}: max {limit} clips per match")
    
    # Ask for confirmation
    response = input("\nDo you want to proceed? (y/n): ").lower()
    if response != 'y':
        print("Operation cancelled.")
        return
    
    # Process each folder
    for folder_name, max_clips in folder_limits.items():
        folder_path = os.path.join(base_path, folder_name)
        limit_clips_per_match(folder_path, max_clips)
    
    print("\n" + "=" * 50)
    print("Processing complete!")

if __name__ == "__main__":
    main()
# Out:
# Clip Limiter for Multiclass Dataset
# ==================================================
# This script will limit clips per match for:
#   - Direct_free-kick: max 2 clips per match
#   - no_event: max 2 clips per match
#   - Yellow_card: max 3 clips per match
#
# Processing folder: Direct_free-kick
# Total files before processing: 40
# Maximum clips per match: 2
#
# Summary for Direct_free-kick:
#   Total files processed: 40
#   Files deleted: 0
#   Files remaining: 40
#
# Processing folder: no_event
# Total files before processing: 169
# Maximum clips per match: 2
#
# Match: 2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
#   Found 6 clips, keeping 2, deleting 4
#     Deleted: ng98_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Deleted: ng99_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Deleted: ng100_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Deleted: ng101_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#
# Match: 2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
#   Found 6 clips, keeping 2, deleting 4
#     Deleted: ng104_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Deleted: ng105_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Deleted: ng106_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#     Deleted: ng107_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
#
# Match: 2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
#   Found 7 clips, keeping 2, deleting 5
#     Deleted: ng12_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Deleted: ng13_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Deleted: ng14_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Deleted: ng15_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Deleted: ng16_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#
# Match: 2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
#   Found 12 clips, keeping 2, deleting 10
#     Deleted: ng112_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng113_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng114_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng115_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng116_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng117_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng118_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng119_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng120_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Deleted: ng121_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#
# Match: 2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
#   Found 5 clips, keeping 2, deleting 3
#     Deleted: ng124_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Deleted: ng125_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#     Deleted: ng126_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
#
# Match: 2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng129_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Deleted: ng130_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Deleted: ng131_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Deleted: ng132_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Deleted: ng133_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Deleted: ng134_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#
# Match: 2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
#   Found 10 clips, keeping 2, deleting 8
#     Deleted: ng137_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng138_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng139_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng140_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng141_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng142_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng143_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Deleted: ng144_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#
# Match: 2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng147_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Deleted: ng148_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Deleted: ng149_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Deleted: ng150_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Deleted: ng151_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Deleted: ng152_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#
# Match: 2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
#   Found 12 clips, keeping 2, deleting 10
#     Deleted: ng155_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng156_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng157_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng158_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng159_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng160_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng161_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng162_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng163_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Deleted: ng164_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#
# Match: 2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
#   Found 5 clips, keeping 2, deleting 3
#     Deleted: ng167_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Deleted: ng168_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Deleted: ng169_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#
# Match: 2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng19_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Deleted: ng20_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Deleted: ng21_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Deleted: ng22_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Deleted: ng23_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Deleted: ng24_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#
# Match: 2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
#   Found 5 clips, keeping 2, deleting 3
#     Deleted: ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Deleted: ng4_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Deleted: ng5_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#
# Match: 2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
#   Found 9 clips, keeping 2, deleting 7
#     Deleted: ng27_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng28_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng29_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng30_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng31_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng32_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Deleted: ng33_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#
# Match: 2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
#   Found 9 clips, keeping 2, deleting 7
#     Deleted: ng36_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng37_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng38_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng39_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng40_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng41_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Deleted: ng42_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#
# Match: 2015-08-29 - 17-00 Manchester City 2 - 0 Watford
#   Found 6 clips, keeping 2, deleting 4
#     Deleted: ng45_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Deleted: ng46_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Deleted: ng47_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Deleted: ng48_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#
# Match: 2015-09-12 - 14-45 Everton 3 - 1 Chelsea
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng51_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Deleted: ng52_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Deleted: ng53_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Deleted: ng54_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Deleted: ng55_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Deleted: ng56_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#
# Match: 2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
#   Found 6 clips, keeping 2, deleting 4
#     Deleted: ng59_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Deleted: ng60_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Deleted: ng61_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Deleted: ng62_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#
# Match: 2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
#   Found 7 clips, keeping 2, deleting 5
#     Deleted: ng66_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Deleted: ng67_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Deleted: ng68_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Deleted: ng69_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Deleted: ng70_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#
# Match: 2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
#   Found 4 clips, keeping 2, deleting 2
#     Deleted: ng8_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Deleted: ng9_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#
# Match: 2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng73_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Deleted: ng74_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Deleted: ng75_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Deleted: ng76_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Deleted: ng77_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Deleted: ng78_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#
# Match: 2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
#   Found 9 clips, keeping 2, deleting 7
#     Deleted: ng81_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng82_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng83_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng84_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng85_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng86_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Deleted: ng87_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#
# Match: 2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
#   Found 8 clips, keeping 2, deleting 6
#     Deleted: ng90_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Deleted: ng91_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Deleted: ng92_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Deleted: ng93_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Deleted: ng94_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Deleted: ng95_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#
# Summary for no_event:
#   Total files processed: 169
#   Files deleted: 122
#   Files remaining: 47
#
# Processing folder: Yellow_card
# Total files before processing: 52
# Maximum clips per match: 3
#
# Summary for Yellow_card:
#   Total files processed: 52
#   Files deleted: 0
#   Files remaining: 52
#
# ==================================================
# Processing complete!

# %%
import os
import cv2
import numpy as np

def process_video(input_path, output_path):
    """
    Process the video to:
    1. Convert to grayscale.
    2. Remove grass and audience areas while preserving the ball.
    """
    # Load video
    cap = cv2.VideoCapture(input_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Changed to mp4v for better compatibility
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height), isColor=False)
    
    print(f"Processing {total_frames} frames from {input_path}...")
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % 100 == 0:
            print(f"Processed {frame_count}/{total_frames} frames")

        # Convert to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Convert original frame to HSV for better color detection
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

        # Define green grass color range in HSV (more specific range)
        lower_green = np.array([35, 40, 40])
        upper_green = np.array([85, 255, 255])
        grass_mask = cv2.inRange(hsv, lower_green, upper_green)

        # Define ball detection (white/light colored ball)
        lower_ball_hsv = np.array([0, 0, 200])
        upper_ball_hsv = np.array([180, 30, 255])
        ball_mask_hsv = cv2.inRange(hsv, lower_ball_hsv, upper_ball_hsv)
        
        _, ball_mask_gray = cv2.threshold(gray_frame, 200, 255, cv2.THRESH_BINARY)
        ball_mask = cv2.bitwise_or(ball_mask_hsv, ball_mask_gray)
        
        kernel = np.ones((3, 3), np.uint8)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_CLOSE, kernel)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_OPEN, kernel)

        lower_audience = np.array([0, 100, 150])
        upper_audience = np.array([180, 255, 255])
        audience_mask = cv2.inRange(hsv, lower_audience, upper_audience)
        audience_mask = cv2.bitwise_and(audience_mask, cv2.bitwise_not(ball_mask))

        combined_mask = cv2.bitwise_or(grass_mask, audience_mask)
        keep_mask = cv2.bitwise_not(combined_mask)
        keep_mask = cv2.bitwise_or(keep_mask, ball_mask)

        processed_frame = cv2.bitwise_and(gray_frame, gray_frame, mask=keep_mask)
        out.write(processed_frame)
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Processed video saved as: {output_path}")

def process_all_videos(input_folder, output_folder):
    """
    Process all videos in the input folder and save them to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to the folder to save processed videos.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for video_file in os.listdir(input_folder):
        input_path = os.path.join(input_folder, video_file)
        output_path = os.path.join(output_folder, video_file)
        
        if os.path.isfile(input_path) and video_file.endswith(".mp4"):
            process_video(input_path, output_path)

def process_all_events(base_input_path, base_output_path, event_types):
    """
    Process all event folders and save processed videos to respective folders.
    
    Args:
        base_input_path (str): Path to the base input folder containing event folders.
        base_output_path (str): Path to the base output folder to save processed videos.
        event_types (list): List of event types to process.
    """
    for event in event_types:
        input_folder = os.path.join(base_input_path, event.replace(" ", "_"))
        output_folder = os.path.join(base_output_path, event.replace(" ", "_"))
        
        if os.path.exists(input_folder):
            print(f"Processing videos for event: {event}")
            process_all_videos(input_folder, output_folder)
        else:
            print(f"Input folder not found for event: {event}")

if __name__ == "__main__":
    # Define input and output base paths
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed"
    
    # List of event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty", "no_event"]
    
    # Process all events
    process_all_events(base_input_path, base_output_path, event_types)
# Out:
# Processing videos for event: Goal
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing videos for event: Red card
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing videos for event: Yellow card
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 100 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/100 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing videos for event: Direct free-kick
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\40_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\45_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\46_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Direct_free-kick\8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Direct_free-kick\8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing videos for event: Penalty
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Penalty\3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Penalty\3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Penalty\4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Penalty\4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing videos for event: no_event
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng102_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng102_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng103_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng103_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng108_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng108_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng109_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng109_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng10_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng10_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng110_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng110_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng111_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng111_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng122_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng122_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng123_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng123_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng127_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng127_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng128_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng128_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng135_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng135_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 174 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng145_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/174 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng145_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng96_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng96_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips\no_event\ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\no_event\ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4

# %%
import os
import shutil
import random

def split_videos(base_path, event_types, train_ratio=0.8, test_ratio=0.2):
    """
    Split videos into train and test subfolders for each event type based on unequal sample sizes.
    
    Args:
        base_path (str): Path to the base folder containing event folders.
        event_types (list): List of event types to process.
        train_ratio (float): Proportion of videos to place in the train folder.
        test_ratio (float): Proportion of videos to place in the test folder.
    """
    for event in event_types:
        event_folder = os.path.join(base_path, event.replace(" ", "_"))
        train_folder = os.path.join(event_folder, "train")
        test_folder = os.path.join(event_folder, "test")
        
        # Create train and test subfolders if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)
        
        # Get all video files in the event folder
        video_files = [f for f in os.listdir(event_folder) if f.endswith(".mp4")]
        
        # Shuffle the video files to ensure randomness
        random.shuffle(video_files)
        
        # Calculate the number of train and test videos
        total_videos = len(video_files)
        num_train_videos = int(total_videos * train_ratio)
        num_test_videos = total_videos - num_train_videos
        
        # Split videos into train and test sets
        train_videos = video_files[:num_train_videos]
        test_videos = video_files[num_train_videos:]
        
        # Move videos to train folder
        for video in train_videos:
            src_path = os.path.join(event_folder, video)
            dest_path = os.path.join(train_folder, video)
            shutil.move(src_path, dest_path)
        
        # Move videos to test folder
        for video in test_videos:
            src_path = os.path.join(event_folder, video)
            dest_path = os.path.join(test_folder, video)
            shutil.move(src_path, dest_path)
        
        print(f"Event: {event}")
        print(f"  Total videos: {total_videos}")
        print(f"  Train videos: {len(train_videos)}")
        print(f"  Test videos: {len(test_videos)}")

if __name__ == "__main__":
    # Define base paths for Clips and Features-processed
    base_paths = [
        "F:/AIM Lab/Experiment/Multiclass-unequal samples/Clips",
        "F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed"
    ]
    
    # Split videos in both base paths
    for base_path in base_paths:
        split_videos(base_path, event_types)
# Out:
# Event: Goal
#   Total videos: 37
#   Train videos: 29
#   Test videos: 8
# Event: Red card
#   Total videos: 3
#   Train videos: 2
#   Test videos: 1
# Event: Yellow card
#   Total videos: 52
#   Train videos: 41
#   Test videos: 11
# Event: Direct free-kick
#   Total videos: 40
#   Train videos: 32
#   Test videos: 8
# Event: Penalty
#   Total videos: 5
#   Train videos: 4
#   Test videos: 1
# Event: no_event
#   Total videos: 47
#   Train videos: 37
#   Test videos: 10
# Event: Goal
#   Total videos: 37
#   Train videos: 29
#   Test videos: 8
# Event: Red card
#   Total videos: 3
#   Train videos: 2
#   Test videos: 1
# Event: Yellow card
#   Total videos: 52
#   Train videos: 41
#   Test videos: 11
# Event: Direct free-kick
#   Total videos: 40
#   Train videos: 32
#   Test videos: 8
# Event: Penalty
#   Total videos: 5
#   Train videos: 4
#   Test videos: 1
# Event: no_event
#   Total videos: 47
#   Train videos: 37
#   Test videos: 10

# %%
import os
import cv2
import numpy as np
import torch
import torchvision
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
# Load ResNet-50 model
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Identity()  # Remove the final classifier to get 2048-d features
model.eval()  # Set the model to evaluation mode

# Preprocessing pipeline for frames
preprocess = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),                    # H×W×C → C×H×W, [0,1]
    torchvision.transforms.Normalize(mean=[.485, .456, .406], std=[.229, .224, .225]),
    torchvision.transforms.Resize((224, 224)),
])

def embed_clip(frames: List[np.ndarray]):
    """
    Generate ResNet-50 embeddings for a list of frames.
    
    Args:
        frames (List[np.ndarray]): List of frames (H×W×C, BGR format).
    
    Returns:
        np.ndarray: N×2048 array of frame embeddings.
    """
    feats = []
    for frame in frames:
        # Convert BGR (OpenCV) to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        x = preprocess(frame_rgb).unsqueeze(0)  # 1×3×224×224
        with torch.no_grad():
            f = model(x)  # 1×2048
        feats.append(f.squeeze(0).cpu().numpy())
    return np.stack(feats, axis=0)  # N×2048

def sample_frames_from_video(video_path, num_samples=16):
    """
    Uniformly sample num_samples frames from the video at video_path.
    Returns a list of BGR frames (as numpy arrays).
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        # If fewer frames than samples, just read them all
        indices = list(range(total_frames))
    else:
        # Uniformly spaced frame indices
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    cap.release()

    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    return frames

def process_folder(input_folder, output_folder, num_samples=16):
    """
    Process videos in a folder, generate mean-pooled ResNet-50 embeddings for sampled frames,
    and save the embeddings to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to save embeddings.
        num_samples (int): Number of frames to sample per video.
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        frames = sample_frames_from_video(video_path, num_samples=num_samples)
        if frames:
            # Generate embeddings and mean-pool them
            embeddings = embed_clip(frames)
            clip_vec = np.mean(embeddings, axis=0)  # Mean-pool → (2048,)
            
            # Save the embedding as a .npy file
            output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
            np.save(output_path, clip_vec)
            print(f"Saved embedding to {output_path}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes(embeddings_base_path, event_classes):
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary of prototypes for each event class.
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

# Replace the existing function with this updated version
def evaluate_multiclass_classification(embeddings_base_path, prototypes, event_classes):
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with ResNet-50")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Red_card", "Yellow_card", "Direct_free-kick", "Penalty", "no_event"]
    
    # Step 1: Generate embeddings for all videos
    print("\nStep 1: Generating ResNet-50 embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, num_samples=16)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data
    print("\nStep 3: Evaluating classification performance...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")

    print(f"\n{'='*50}")
    print("FINAL RESULTS")
    print(f"{'='*50}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Multiclass Few-Shot Learning with ResNet-50
# ==================================================
#
# Step 1: Generating ResNet-50 embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#
# Processing Red_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#
# Processing Red_card - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings\Yellow_card\Train\45_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\48_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# ...
#   Loaded ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (2048,))
#   Loaded ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (2048,))
#   Loaded ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (2048,))
#   Loaded ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (2048,))
#   Loaded ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (2048,))
#   Loaded ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (2048,))
#   Loaded ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (2048,))
#   Loaded ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (2048,))
#   Loaded ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (2048,))
#   Loaded ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (2048,))
#   Loaded ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (2048,))
#   Loaded ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (2048,))
#   Loaded ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (2048,))
#   Loaded ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (2048,))
#   Loaded ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (2048,))
#   Loaded ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (2048,))
#   Loaded ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (2048,))
#   Loaded ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (2048,))
#   Loaded ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (2048,))
#   Loaded ng96_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (2048,))
# Built prototype for no_event from 37 samples
# Successfully built prototypes for 6 classes:
#   Goal: shape (2048,)
#   Red_card: shape (2048,)
#   Yellow_card: shape (2048,)
#   Direct_free-kick: shape (2048,)
#   Penalty: shape (2048,)
#   no_event: shape (2048,)
#
# Step 3: Evaluating classification performance...
#
# ============================================================
# EVALUATING MULTICLASS CLASSIFICATION
# ============================================================
#
# Testing Goal clips...
#   File: 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9414301, 'Red_card': 0.83261275, 'Yellow_card': 0.87184256, 'Direct_free-kick': 0.9411083, 'Penalty': 0.92460483, 'no_event': 0.9228785}
#   File: 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9511739, 'Red_card': 0.92187715, 'Yellow_card': 0.94288564, 'Direct_free-kick': 0.9515319, 'Penalty': 0.9502869, 'no_event': 0.9581006}
#   File: 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9638778, 'Red_card': 0.8601091, 'Yellow_card': 0.89837176, 'Direct_free-kick': 0.9690573, 'Penalty': 0.95470977, 'no_event': 0.9417396}
#   File: 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.9540303, 'Red_card': 0.9107765, 'Yellow_card': 0.93955636, 'Direct_free-kick': 0.94566715, 'Penalty': 0.9738515, 'no_event': 0.94125795}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9444045, 'Red_card': 0.8179349, 'Yellow_card': 0.8616642, 'Direct_free-kick': 0.946476, 'Penalty': 0.9199248, 'no_event': 0.9242792}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.96562517, 'Red_card': 0.9325227, 'Yellow_card': 0.95379555, 'Direct_free-kick': 0.9564594, 'Penalty': 0.9783654, 'no_event': 0.9556755}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.96113086, 'Red_card': 0.9129565, 'Yellow_card': 0.94727546, 'Direct_free-kick': 0.9542873, 'Penalty': 0.9590361, 'no_event': 0.9615973}
#   File: 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.97186804, 'Red_card': 0.9109962, 'Yellow_card': 0.942912, 'Direct_free-kick': 0.9631349, 'Penalty': 0.9685254, 'no_event': 0.9614601}
#
# Testing Red_card clips...
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.88166237, 'Red_card': 0.9250594, 'Yellow_card': 0.9332009, 'Direct_free-kick': 0.8735199, 'Penalty': 0.8953124, 'no_event': 0.8913075}
#
# Testing Yellow_card clips...
#   File: 24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.91391015, 'Red_card': 0.933842, 'Yellow_card': 0.95599246, 'Direct_free-kick': 0.90209186, 'Penalty': 0.9209399, 'no_event': 0.9403388}
#   File: 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8852607, 'Red_card': 0.959294, 'Yellow_card': 0.9647393, 'Direct_free-kick': 0.8632107, 'Penalty': 0.9070972, 'no_event': 0.8925754}
#   File: 2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Red_card, Correct: False
#     Similarities: {'Goal': 0.85795665, 'Red_card': 0.94504493, 'Yellow_card': 0.9432479, 'Direct_free-kick': 0.84070665, 'Penalty': 0.8864989, 'no_event': 0.8676882}
#   File: 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.87884355, 'Red_card': 0.9585053, 'Yellow_card': 0.96409595, 'Direct_free-kick': 0.86223423, 'Penalty': 0.89582324, 'no_event': 0.90510505}
#   File: 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.88763916, 'Red_card': 0.92880636, 'Yellow_card': 0.937735, 'Direct_free-kick': 0.8676071, 'Penalty': 0.9024302, 'no_event': 0.898932}
#   File: 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.87293863, 'Red_card': 0.94325364, 'Yellow_card': 0.9566065, 'Direct_free-kick': 0.8600894, 'Penalty': 0.8912069, 'no_event': 0.89770246}
#   File: 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.95615184, 'Red_card': 0.9381109, 'Yellow_card': 0.9609949, 'Direct_free-kick': 0.94385725, 'Penalty': 0.95646715, 'no_event': 0.96336454}
#   File: 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8909762, 'Red_card': 0.9596502, 'Yellow_card': 0.96841025, 'Direct_free-kick': 0.87369734, 'Penalty': 0.91663784, 'no_event': 0.91035295}
#   File: 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9362159, 'Red_card': 0.95010936, 'Yellow_card': 0.9721661, 'Direct_free-kick': 0.9223417, 'Penalty': 0.9444997, 'no_event': 0.9512852}
#   File: 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8967539, 'Red_card': 0.94926155, 'Yellow_card': 0.96244645, 'Direct_free-kick': 0.8790417, 'Penalty': 0.9172011, 'no_event': 0.90197027}
#   File: 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.92230713, 'Red_card': 0.9259484, 'Yellow_card': 0.9474083, 'Direct_free-kick': 0.9187819, 'Penalty': 0.9325776, 'no_event': 0.9459802}
#
# Testing Direct_free-kick clips...
#   File: 18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9246906, 'Red_card': 0.7932241, 'Yellow_card': 0.83513737, 'Direct_free-kick': 0.9464501, 'Penalty': 0.8970394, 'no_event': 0.9205594}
#   File: 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.93526804, 'Red_card': 0.8208257, 'Yellow_card': 0.8620703, 'Direct_free-kick': 0.9311292, 'Penalty': 0.9185951, 'no_event': 0.9078356}
#   File: 26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9535572, 'Red_card': 0.86639535, 'Yellow_card': 0.9033619, 'Direct_free-kick': 0.96254206, 'Penalty': 0.9394115, 'no_event': 0.9476622}
#   File: 32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.94823277, 'Red_card': 0.8183119, 'Yellow_card': 0.8625976, 'Direct_free-kick': 0.9616283, 'Penalty': 0.92911077, 'no_event': 0.9391079}
#   File: 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9558416, 'Red_card': 0.9100175, 'Yellow_card': 0.9406969, 'Direct_free-kick': 0.9440157, 'Penalty': 0.95190704, 'no_event': 0.95445526}
#   File: 39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9514028, 'Red_card': 0.8338964, 'Yellow_card': 0.87408185, 'Direct_free-kick': 0.9624996, 'Penalty': 0.94093037, 'no_event': 0.9347168}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9308063, 'Red_card': 0.7771994, 'Yellow_card': 0.8233248, 'Direct_free-kick': 0.9465208, 'Penalty': 0.90129054, 'no_event': 0.90313494}
#   File: 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.86485124, 'Red_card': 0.7759947, 'Yellow_card': 0.8032832, 'Direct_free-kick': 0.86745155, 'Penalty': 0.8407304, 'no_event': 0.87151283}
#
# Testing Penalty clips...
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Penalty, Predicted: Penalty, Correct: True
#     Similarities: {'Goal': 0.9614372, 'Red_card': 0.91442895, 'Yellow_card': 0.938588, 'Direct_free-kick': 0.94651866, 'Penalty': 0.96161354, 'no_event': 0.94794834}
#
# Testing no_event clips...
#   File: ng109_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9161885, 'Red_card': 0.8039297, 'Yellow_card': 0.8479934, 'Direct_free-kick': 0.92885196, 'Penalty': 0.8986226, 'no_event': 0.9220728}
#   File: ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.88152075, 'Red_card': 0.8762196, 'Yellow_card': 0.8978895, 'Direct_free-kick': 0.86776567, 'Penalty': 0.88583577, 'no_event': 0.8742494}
#   File: ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.95853686, 'Red_card': 0.92442435, 'Yellow_card': 0.95003426, 'Direct_free-kick': 0.9515854, 'Penalty': 0.9587134, 'no_event': 0.9613686}
#   File: ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.92186797, 'Red_card': 0.83577013, 'Yellow_card': 0.87731224, 'Direct_free-kick': 0.92663646, 'Penalty': 0.9066311, 'no_event': 0.9478321}
#   File: ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8918135, 'Red_card': 0.90632594, 'Yellow_card': 0.92271817, 'Direct_free-kick': 0.87924325, 'Penalty': 0.89464736, 'no_event': 0.8940079}
#   File: ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91830206, 'Red_card': 0.81016326, 'Yellow_card': 0.85152996, 'Direct_free-kick': 0.91408134, 'Penalty': 0.9071053, 'no_event': 0.9111431}
#   File: ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8998216, 'Red_card': 0.9113874, 'Yellow_card': 0.9414722, 'Direct_free-kick': 0.88355964, 'Penalty': 0.9163995, 'no_event': 0.90480417}
#   File: ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9493032, 'Red_card': 0.93581915, 'Yellow_card': 0.95907056, 'Direct_free-kick': 0.93393975, 'Penalty': 0.9427486, 'no_event': 0.95710665}
#   File: ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.94896126, 'Red_card': 0.836833, 'Yellow_card': 0.8765322, 'Direct_free-kick': 0.9519737, 'Penalty': 0.9258028, 'no_event': 0.93323934}
#   File: ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9086697, 'Red_card': 0.93618655, 'Yellow_card': 0.95348513, 'Direct_free-kick': 0.8994489, 'Penalty': 0.92515194, 'no_event': 0.93165964}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.4872
# Weighted Precision: 0.4593
# Weighted Recall: 0.4872
# Weighted F₁ Score: 0.4560
#
# Per-class Accuracy:
#   Goal: 0.2500 (2/8)
#   Red_card: 0.0000 (0/1)
#   Yellow_card: 0.8182 (9/11)
#   Direct_free-kick: 0.6250 (5/8)
#   Penalty: 1.0000 (1/1)
#   no_event: 0.2000 (2/10)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Red_card', 'Yellow_card', 'Direct_free-kick', 'Penalty', 'no_event']
# [[2 0 0 2 2 2]
#  [0 0 1 0 0 0]
#  [0 1 9 0 0 1]
#  [2 0 0 5 0 1]
#  [0 0 0 0 1 0]
#  [1 0 5 2 0 2]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.40      0.25      0.31         8
#         Red_card       0.00      0.00      0.00         1
#      Yellow_card       0.60      0.82      0.69        11
# Direct_free-kick       0.56      0.62      0.59         8
#          Penalty       0.33      1.00      0.50         1
#         no_event       0.33      0.20      0.25        10
#
#         accuracy                           0.49        39
#        macro avg       0.37      0.48      0.39        39
#     weighted avg       0.46      0.49      0.46        39
#
#
# Step 4: Additional Analysis...
# Total test samples: 39
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 2 times
#   Goal → Penalty: 2 times
#   Goal → no_event: 2 times
#   Red_card → Yellow_card: 1 times
#   Yellow_card → Red_card: 1 times
#   Yellow_card → no_event: 1 times
#   Direct_free-kick → Goal: 2 times
#   Direct_free-kick → no_event: 1 times
#   no_event → Goal: 1 times
#   no_event → Yellow_card: 5 times
#   no_event → Direct_free-kick: 2 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.4872
# Weighted Precision: 0.4593
# Weighted Recall: 0.4872
# Weighted F₁ Score: 0.4560
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms
from torchvision.models.video import r2plus1d_18
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

class R2Plus1DFeatureExtractor:
    def __init__(self, device='cuda' if torch.cuda.is_available() else 'cpu'):
        """
        Initialize R(2+1)D model for feature extraction.
        
        Args:
            device: Device to run the model on
        """
        self.device = device
        
        # Initialize R(2+1)D model
        self.model = r2plus1d_18(pretrained=True)
        
        # Remove the final classification layer to get features
        self.model.fc = torch.nn.Identity()
        self.model.to(device)
        self.model.eval()
        
        # Preprocessing transforms
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((112, 112)),  # R(2+1)D typically uses 112x112
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.43216, 0.394666, 0.37645], 
                               std=[0.22803, 0.22145, 0.216989])  # Kinetics normalization
        ])
    
    def preprocess_frames(self, frames: List[np.ndarray], num_frames: int = 16) -> torch.Tensor:
        """
        Preprocess frames for R(2+1)D input.
        
        Args:
            frames: List of frames (H×W×C, BGR format)
            num_frames: Number of frames to use for R(2+1)D
            
        Returns:
            Preprocessed tensor of shape (1, 3, num_frames, H, W)
        """
        # Sample frames uniformly if we have more than needed
        if len(frames) > num_frames:
            indices = np.linspace(0, len(frames) - 1, num_frames, dtype=int)
            frames = [frames[i] for i in indices]
        elif len(frames) < num_frames:
            # Repeat last frame if we don't have enough
            while len(frames) < num_frames:
                frames.append(frames[-1])
        
        # Convert frames and apply transforms
        processed_frames = []
        for frame in frames:
            # Convert BGR to RGB
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Apply transforms
            frame_tensor = self.transform(frame_rgb)
            processed_frames.append(frame_tensor)
        
        # Stack frames: (num_frames, 3, H, W) -> (3, num_frames, H, W)
        video_tensor = torch.stack(processed_frames, dim=1)  # (3, num_frames, H, W)
        video_tensor = video_tensor.unsqueeze(0)  # Add batch dimension
        
        return video_tensor
    
    def extract_features(self, frames: List[np.ndarray]) -> np.ndarray:
        """
        Extract R(2+1)D features from video frames.
        
        Args:
            frames: List of video frames
            
        Returns:
            Feature vector of shape (512,) for R(2+1)D-18
        """
        # Preprocess frames
        video_tensor = self.preprocess_frames(frames)
        video_tensor = video_tensor.to(self.device)
        
        # Extract features
        with torch.no_grad():
            features = self.model(video_tensor)
            # Global average pooling if needed
            if len(features.shape) > 2:
                features = F.adaptive_avg_pool3d(features, 1).squeeze()
            else:
                features = features.squeeze()
        
        return features.cpu().numpy()

def sample_frames_from_video(video_path: str, num_samples: int = 32) -> List[np.ndarray]:
    """
    Uniformly sample frames from a video.
    
    Args:
        video_path: Path to video file
        num_samples: Number of frames to sample
        
    Returns:
        List of sampled frames
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        indices = list(range(total_frames))
    else:
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    
    cap.release()
    
    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    
    return frames

def process_folder(input_folder: str, output_folder: str, 
                  feature_extractor: R2Plus1DFeatureExtractor,
                  num_frames: int = 32):
    """
    Process all videos in a folder and generate R(2+1)D embeddings.
    
    Args:
        input_folder: Folder containing input videos
        output_folder: Folder to save embeddings
        feature_extractor: R(2+1)D feature extractor instance
        num_frames: Number of frames to use for each video
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    os.makedirs(output_folder, exist_ok=True)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        
        # Sample frames from video
        frames = sample_frames_from_video(video_path, num_samples=num_frames)
        
        if frames:
            # Extract R(2+1)D features
            try:
                features = feature_extractor.extract_features(frames)
                
                # Save the embedding as a .npy file
                output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
                np.save(output_path, features)
                print(f"Saved R(2+1)D embedding to {output_path} (shape: {features.shape})")
                
            except Exception as e:
                print(f"Error processing {fname}: {e}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec: np.ndarray) -> np.ndarray:
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec: Input vector
        
    Returns:
        L2-normalized vector
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def cosine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    """
    Compute cosine similarity between two vectors.
    
    Args:
        vec1: First vector
        vec2: Second vector
        
    Returns:
        Cosine similarity value
    """
    # Normalize vectors
    vec1_norm = l2_normalize(vec1)
    vec2_norm = l2_normalize(vec2)
    
    # Compute cosine similarity
    return np.dot(vec1_norm, vec2_norm)

def build_prototypes(embeddings_base_path: str, event_classes: List[str]) -> Dict[str, np.ndarray]:
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        event_classes: List of event class names
        
    Returns:
        Dictionary of prototypes for each event class
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding: np.ndarray, prototypes: Dict[str, np.ndarray]) -> tuple:
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding: Embedding vector of the clip
        prototypes: Dictionary of prototypes for each event class
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = cosine_similarity(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_multiclass_classification(embeddings_base_path: str, 
                                     prototypes: Dict[str, np.ndarray], 
                                     event_classes: List[str],
                                     threshold: float = 0.0) -> dict:
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        prototypes: Dictionary of prototypes for each event class
        event_classes: List of event class names
        threshold: Decision threshold (not used in multiclass, kept for compatibility)
    
    Returns:
        Dictionary containing evaluation results
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run R(2+1)D-based multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with R(2+1)D")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings"
    
    # Event classes (using underscores to match folder names)
    event_classes = ["Goal", "Red_card", "Yellow_card", "Direct_free-kick", "Penalty", "no_event"]
    
    # Initialize R(2+1)D feature extractor
    print("Initializing R(2+1)D feature extractor...")
    feature_extractor = R2Plus1DFeatureExtractor()
    
    # Step 1: Generate R(2+1)D embeddings for all videos
    print("\nStep 1: Generating R(2+1)D embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, feature_extractor, num_frames=32)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data with threshold 0.0
    print("\nStep 3: Evaluating classification performance with threshold 0.0...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes, threshold=0.0)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*50}")
    print("FINAL RESULTS")
    print(f"{'='*50}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# Multiclass Few-Shot Learning with R(2+1)D
# ==================================================
# Initializing R(2+1)D feature extractor...
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R2Plus1D_18_Weights.KINETICS400_V1`. You can also use `weights=R2Plus1D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Step 1: Generating R(2+1)D embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\28_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\30_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Train\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Goal\Test\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#
# Processing Red_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Red_card\Train\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Red_card\Train\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
#
# Processing Red_card - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Red_card\Test\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\40_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\41_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\42_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-unequal samples/Features-processed\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings\Yellow_card\Train\43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy (shape: (512,))
# ...
#   Loaded ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
#   Loaded ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
#   Loaded ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
#   Loaded ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
#   Loaded ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
#   Loaded ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#   Loaded ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#   Loaded ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#   Loaded ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
#   Loaded ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
#   Loaded ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
#   Loaded ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
#   Loaded ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy (shape: (512,))
#   Loaded ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
#   Loaded ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
#   Loaded ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
#   Loaded ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
#   Loaded ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
#   Loaded ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
#   Loaded ng96_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Built prototype for no_event from 37 samples
# Successfully built prototypes for 6 classes:
#   Goal: shape (512,)
#   Red_card: shape (512,)
#   Yellow_card: shape (512,)
#   Direct_free-kick: shape (512,)
#   Penalty: shape (512,)
#   no_event: shape (512,)
#
# Step 3: Evaluating classification performance with threshold 0.0...
#
# ============================================================
# EVALUATING MULTICLASS CLASSIFICATION
# ============================================================
#
# Testing Goal clips...
#   File: 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.8851817, 'Red_card': 0.6733608, 'Yellow_card': 0.7564815, 'Direct_free-kick': 0.88258564, 'Penalty': 0.8076889, 'no_event': 0.86729145}
#   File: 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.92824554, 'Red_card': 0.7377881, 'Yellow_card': 0.831606, 'Direct_free-kick': 0.92082185, 'Penalty': 0.86795783, 'no_event': 0.91842014}
#   File: 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9143373, 'Red_card': 0.6959337, 'Yellow_card': 0.78231764, 'Direct_free-kick': 0.91929567, 'Penalty': 0.8288381, 'no_event': 0.89914846}
#   File: 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.9176031, 'Red_card': 0.8122579, 'Yellow_card': 0.88817656, 'Direct_free-kick': 0.8974153, 'Penalty': 0.9520507, 'no_event': 0.9059968}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.90455264, 'Red_card': 0.7141747, 'Yellow_card': 0.81465465, 'Direct_free-kick': 0.90096104, 'Penalty': 0.84512043, 'no_event': 0.89621437}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Goal, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8034141, 'Red_card': 0.9040487, 'Yellow_card': 0.9211732, 'Direct_free-kick': 0.79497135, 'Penalty': 0.9171506, 'no_event': 0.83534336}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.93078035, 'Red_card': 0.74297076, 'Yellow_card': 0.8402578, 'Direct_free-kick': 0.91676223, 'Penalty': 0.8823219, 'no_event': 0.9170858}
#   File: 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.911366, 'Red_card': 0.83795446, 'Yellow_card': 0.9106733, 'Direct_free-kick': 0.895115, 'Penalty': 0.9428009, 'no_event': 0.91002953}
#
# Testing Red_card clips...
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Red_card, Predicted: Red_card, Correct: True
#     Similarities: {'Goal': 0.75919527, 'Red_card': 0.90364504, 'Yellow_card': 0.901742, 'Direct_free-kick': 0.76042426, 'Penalty': 0.81594235, 'no_event': 0.79743457}
#
# Testing Yellow_card clips...
#   File: 24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.82643735, 'Red_card': 0.8821027, 'Yellow_card': 0.90985215, 'Direct_free-kick': 0.817533, 'Penalty': 0.88401675, 'no_event': 0.86782205}
#   File: 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7804542, 'Red_card': 0.8745116, 'Yellow_card': 0.91104424, 'Direct_free-kick': 0.7776294, 'Penalty': 0.86481214, 'no_event': 0.8078111}
#   File: 2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Red_card, Correct: False
#     Similarities: {'Goal': 0.7452814, 'Red_card': 0.92671627, 'Yellow_card': 0.9200693, 'Direct_free-kick': 0.7401161, 'Penalty': 0.83949983, 'no_event': 0.78539777}
#   File: 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.738456, 'Red_card': 0.8670875, 'Yellow_card': 0.88777435, 'Direct_free-kick': 0.7305981, 'Penalty': 0.8023351, 'no_event': 0.7652339}
#   File: 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.78552085, 'Red_card': 0.9074053, 'Yellow_card': 0.9229739, 'Direct_free-kick': 0.7678102, 'Penalty': 0.8577286, 'no_event': 0.81632304}
#   File: 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8246871, 'Red_card': 0.8509947, 'Yellow_card': 0.9052219, 'Direct_free-kick': 0.82659185, 'Penalty': 0.8882191, 'no_event': 0.8451631}
#   File: 49_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9062549, 'Red_card': 0.7566908, 'Yellow_card': 0.8453558, 'Direct_free-kick': 0.8845705, 'Penalty': 0.88477045, 'no_event': 0.89082754}
#   File: 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.77718496, 'Red_card': 0.9046392, 'Yellow_card': 0.9265884, 'Direct_free-kick': 0.76506364, 'Penalty': 0.8740227, 'no_event': 0.8158911}
#   File: 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.892344, 'Red_card': 0.8152246, 'Yellow_card': 0.88433945, 'Direct_free-kick': 0.87607527, 'Penalty': 0.86152375, 'no_event': 0.9003095}
#   File: 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7577448, 'Red_card': 0.9011609, 'Yellow_card': 0.9162329, 'Direct_free-kick': 0.74525344, 'Penalty': 0.8483579, 'no_event': 0.78518087}
#   File: 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.75494707, 'Red_card': 0.89124024, 'Yellow_card': 0.9081538, 'Direct_free-kick': 0.74877965, 'Penalty': 0.87500864, 'no_event': 0.8018059}
#
# Testing Direct_free-kick clips...
#   File: 18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8922602, 'Red_card': 0.6614736, 'Yellow_card': 0.75803435, 'Direct_free-kick': 0.91644657, 'Penalty': 0.7782479, 'no_event': 0.9028797}
#   File: 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91088295, 'Red_card': 0.69943213, 'Yellow_card': 0.79714566, 'Direct_free-kick': 0.8961647, 'Penalty': 0.84212375, 'no_event': 0.89426124}
#   File: 26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9286082, 'Red_card': 0.69336855, 'Yellow_card': 0.7867605, 'Direct_free-kick': 0.9447677, 'Penalty': 0.8244442, 'no_event': 0.9173056}
#   File: 32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.878454, 'Red_card': 0.63240635, 'Yellow_card': 0.72993726, 'Direct_free-kick': 0.8967633, 'Penalty': 0.7870718, 'no_event': 0.8815739}
#   File: 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.852882, 'Red_card': 0.77472687, 'Yellow_card': 0.8348189, 'Direct_free-kick': 0.84434086, 'Penalty': 0.83167565, 'no_event': 0.862162}
#   File: 39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9203352, 'Red_card': 0.6564015, 'Yellow_card': 0.7519051, 'Direct_free-kick': 0.9387046, 'Penalty': 0.8253259, 'no_event': 0.9075508}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.86898476, 'Red_card': 0.6090938, 'Yellow_card': 0.695296, 'Direct_free-kick': 0.89067084, 'Penalty': 0.7490696, 'no_event': 0.8673515}
#   File: 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.867608, 'Red_card': 0.6355388, 'Yellow_card': 0.7276357, 'Direct_free-kick': 0.8766029, 'Penalty': 0.7619015, 'no_event': 0.8670594}
#
# Testing Penalty clips...
#   File: 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.89588046, 'Red_card': 0.7636707, 'Yellow_card': 0.84684837, 'Direct_free-kick': 0.89239836, 'Penalty': 0.8812754, 'no_event': 0.88744086}
#
# Testing no_event clips...
#   File: ng109_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8575881, 'Red_card': 0.64790064, 'Yellow_card': 0.7439108, 'Direct_free-kick': 0.8696853, 'Penalty': 0.79776394, 'no_event': 0.86342514}
#   File: ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8311657, 'Red_card': 0.8131033, 'Yellow_card': 0.8676188, 'Direct_free-kick': 0.8285637, 'Penalty': 0.86644155, 'no_event': 0.84045154}
#   File: ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.86904144, 'Red_card': 0.8403509, 'Yellow_card': 0.89276874, 'Direct_free-kick': 0.8491567, 'Penalty': 0.8898879, 'no_event': 0.873622}
#   File: ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9269451, 'Red_card': 0.6728767, 'Yellow_card': 0.78023803, 'Direct_free-kick': 0.92957044, 'Penalty': 0.8396139, 'no_event': 0.931661}
#   File: ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.85657513, 'Red_card': 0.8234283, 'Yellow_card': 0.88580436, 'Direct_free-kick': 0.8505144, 'Penalty': 0.90436476, 'no_event': 0.8674083}
#   File: ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9144676, 'Red_card': 0.72803617, 'Yellow_card': 0.80332214, 'Direct_free-kick': 0.9065166, 'Penalty': 0.8568783, 'no_event': 0.9057914}
#   File: ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8212021, 'Red_card': 0.8566433, 'Yellow_card': 0.8977767, 'Direct_free-kick': 0.813023, 'Penalty': 0.87933886, 'no_event': 0.83591425}
#   File: ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8875158, 'Red_card': 0.8040769, 'Yellow_card': 0.872416, 'Direct_free-kick': 0.87181795, 'Penalty': 0.8405814, 'no_event': 0.88645595}
#   File: ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.88814354, 'Red_card': 0.6461091, 'Yellow_card': 0.74078363, 'Direct_free-kick': 0.9095801, 'Penalty': 0.77908826, 'no_event': 0.89683175}
#   File: ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8220486, 'Red_card': 0.868546, 'Yellow_card': 0.9084586, 'Direct_free-kick': 0.81876445, 'Penalty': 0.8737968, 'no_event': 0.8519983}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5128
# Weighted Precision: 0.4998
# Weighted Recall: 0.5128
# Weighted F₁ Score: 0.4859
#
# Per-class Accuracy:
#   Goal: 0.5000 (4/8)
#   Red_card: 1.0000 (1/1)
#   Yellow_card: 0.7273 (8/11)
#   Direct_free-kick: 0.7500 (6/8)
#   Penalty: 0.0000 (0/1)
#   no_event: 0.1000 (1/10)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Red_card', 'Yellow_card', 'Direct_free-kick', 'Penalty', 'no_event']
# [[4 0 1 1 2 0]
#  [0 1 0 0 0 0]
#  [1 1 8 0 0 1]
#  [1 0 0 6 0 1]
#  [1 0 0 0 0 0]
#  [2 0 4 2 1 1]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.44      0.50      0.47         8
#         Red_card       0.50      1.00      0.67         1
#      Yellow_card       0.62      0.73      0.67        11
# Direct_free-kick       0.67      0.75      0.71         8
#          Penalty       0.00      0.00      0.00         1
#         no_event       0.33      0.10      0.15        10
#
#         accuracy                           0.51        39
#        macro avg       0.43      0.51      0.44        39
#     weighted avg       0.50      0.51      0.49        39
#
#
# Step 4: Additional Analysis...
# Total test samples: 39
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Yellow_card: 1 times
#   Goal → Direct_free-kick: 1 times
#   Goal → Penalty: 2 times
#   Yellow_card → Goal: 1 times
#   Yellow_card → Red_card: 1 times
#   Yellow_card → no_event: 1 times
#   Direct_free-kick → Goal: 1 times
#   Direct_free-kick → no_event: 1 times
#   Penalty → Goal: 1 times
#   no_event → Goal: 2 times
#   no_event → Yellow_card: 4 times
#   no_event → Direct_free-kick: 2 times
#   no_event → Penalty: 1 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.5128
# Weighted Precision: 0.4998
# Weighted Recall: 0.5128
# Weighted F₁ Score: 0.4859
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %% [markdown]
# ## 5 samples for prototype and 12 for evaluation

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, num_prototype_samples=5):
    """
    Build prototypes for each event class from randomly selected test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        num_prototype_samples (int): Number of random samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_prototype_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for prototype")
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, num_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} random test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples=12):
    """
    Evaluate classification performance on a random subset of training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        num_eval_samples (int): Number of random samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON {num_eval_samples} RANDOM TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_eval_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for evaluation")
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, num_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from random 5 test samples,
    and evaluates on 12 random training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Random Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event", "Red_card", "Penalty"]
    
    # Number of test samples to use for prototype creation
    num_prototype_samples = 5
    
    # Number of training samples to evaluate per class
    num_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from random subset of test embeddings
    print(f"\nStep 1: Building prototypes from {num_prototype_samples} random test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, num_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on random training samples
    print(f"\nStep 2: Evaluating classification performance on {num_eval_samples} random training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Random Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 29 embeddings in Goal/Train
#   Found 8 embeddings in Goal/Test
#   Found 32 embeddings in Direct_free-kick/Train
#   Found 8 embeddings in Direct_free-kick/Test
#   Found 41 embeddings in Yellow_card/Train
#   Found 11 embeddings in Yellow_card/Test
#   Found 37 embeddings in no_event/Train
#   Found 10 embeddings in no_event/Test
#   Found 2 embeddings in Red_card/Train
#   Found 1 embeddings in Red_card/Test
#   Found 4 embeddings in Penalty/Train
#   Found 1 embeddings in Penalty/Test
#
# Step 1: Building prototypes from 5 random test samples per class...
# Loading 5 random test embeddings for Goal prototype...
#   Selected 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy for prototype (shape: (2048,))
#   Selected 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (2048,))
#   Selected 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
#   Selected 25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy for prototype (shape: (2048,))
# Built prototype for Goal from 5 test samples
# Loading 5 random test embeddings for Direct_free-kick prototype...
#   Selected 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy for prototype (shape: (2048,))
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (2048,))
#   Selected 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy for prototype (shape: (2048,))
#   Selected 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy for prototype (shape: (2048,))
# Built prototype for Direct_free-kick from 5 test samples
# Loading 5 random test embeddings for Yellow_card prototype...
#   Selected 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy for prototype (shape: (2048,))
#   Selected 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (2048,))
#   Selected 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (2048,))
#   Selected 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
#   Selected 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
# Built prototype for Yellow_card from 5 test samples
# Loading 5 random test embeddings for no_event prototype...
#   Selected ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
#   Selected ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy for prototype (shape: (2048,))
#   Selected ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy for prototype (shape: (2048,))
#   Selected ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (2048,))
#   Selected ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
# Built prototype for no_event from 5 test samples
# Warning: Only 1 files available for Red_card, using all of them for prototype
# Loading 1 random test embeddings for Red_card prototype...
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy for prototype (shape: (2048,))
# Built prototype for Red_card from 1 test samples
# Warning: Only 1 files available for Penalty, using all of them for prototype
# Loading 1 random test embeddings for Penalty prototype...
#   Selected 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy for prototype (shape: (2048,))
# Built prototype for Penalty from 1 test samples
#
# Successfully built prototypes for 6 classes:
#   Goal: shape (2048,)
#   Direct_free-kick: shape (2048,)
#   Yellow_card: shape (2048,)
#   no_event: shape (2048,)
#   Red_card: shape (2048,)
#   Penalty: shape (2048,)
#
# Files used for prototype creation:
#   Goal: ['34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy', '22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', '4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', '7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '25_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy']
#   Direct_free-kick: ['62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy', '4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', '36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy', '23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '39_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy']
#   Yellow_card: ['46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy', '35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', '27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy', '39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', '51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy']
#   no_event: ['ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', 'ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy', 'ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy', 'ng97_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', 'ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy']
#   Red_card: ['1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy']
#   Penalty: ['4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy']
#
# Step 2: Evaluating classification performance on 12 random training samples per class...
#
# ============================================================
# EVALUATING ON 12 RANDOM TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 26_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9619957, 'Direct_free-kick': 0.94716096, 'Yellow_card': 0.90483236, 'no_event': 0.9442409, 'Red_card': 0.8494484, 'Penalty': 0.9506147}
#   File: 36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9686154, 'Direct_free-kick': 0.9484472, 'Yellow_card': 0.8792674, 'no_event': 0.93161964, 'Red_card': 0.8479767, 'Penalty': 0.9436611}
#   File: 37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9416387, 'Direct_free-kick': 0.95116013, 'Yellow_card': 0.8744859, 'no_event': 0.9334731, 'Red_card': 0.81168157, 'Penalty': 0.89856994}
#   File: 18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.96438944, 'Direct_free-kick': 0.9593506, 'Yellow_card': 0.8980993, 'no_event': 0.9484606, 'Red_card': 0.8684834, 'Penalty': 0.9269687}
#   File: 31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9708982, 'Direct_free-kick': 0.9679289, 'Yellow_card': 0.8954257, 'no_event': 0.9527685, 'Red_card': 0.87133706, 'Penalty': 0.9354188}
#   File: 24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.95867646, 'Direct_free-kick': 0.9460782, 'Yellow_card': 0.89746964, 'no_event': 0.9503845, 'Red_card': 0.86357194, 'Penalty': 0.92496294}
#   File: 23_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9423815, 'Direct_free-kick': 0.93542254, 'Yellow_card': 0.8548684, 'no_event': 0.92815435, 'Red_card': 0.88468534, 'Penalty': 0.9326334}
#   File: 9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.95919245, 'Direct_free-kick': 0.9454233, 'Yellow_card': 0.8816059, 'no_event': 0.9351971, 'Red_card': 0.841259, 'Penalty': 0.9337545}
#   File: 10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9637343, 'Direct_free-kick': 0.9491972, 'Yellow_card': 0.8807157, 'no_event': 0.937463, 'Red_card': 0.85948306, 'Penalty': 0.93826973}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9673929, 'Direct_free-kick': 0.9543997, 'Yellow_card': 0.88738793, 'no_event': 0.95686865, 'Red_card': 0.861397, 'Penalty': 0.92906713}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.94595844, 'Direct_free-kick': 0.95250624, 'Yellow_card': 0.8249644, 'no_event': 0.92383546, 'Red_card': 0.82082796, 'Penalty': 0.9065881}
#   File: 29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.95685625, 'Direct_free-kick': 0.9498304, 'Yellow_card': 0.8947427, 'no_event': 0.94714, 'Red_card': 0.87649584, 'Penalty': 0.9218945}
#
# Testing Direct_free-kick training clips...
#   File: 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.95206654, 'Direct_free-kick': 0.9383915, 'Yellow_card': 0.9096869, 'no_event': 0.9480901, 'Red_card': 0.8844681, 'Penalty': 0.93219906}
#   File: 47_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.94450617, 'Direct_free-kick': 0.9563022, 'Yellow_card': 0.83599395, 'no_event': 0.921204, 'Red_card': 0.8135436, 'Penalty': 0.8895831}
#   File: 11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9527503, 'Direct_free-kick': 0.9497553, 'Yellow_card': 0.8630537, 'no_event': 0.9385875, 'Red_card': 0.82958007, 'Penalty': 0.88863504}
#   File: 44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9686408, 'Direct_free-kick': 0.94503963, 'Yellow_card': 0.9063013, 'no_event': 0.94877875, 'Red_card': 0.8914465, 'Penalty': 0.96032494}
#   File: 16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9382094, 'Direct_free-kick': 0.9255521, 'Yellow_card': 0.8452017, 'no_event': 0.9035642, 'Red_card': 0.821864, 'Penalty': 0.9149281}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9376345, 'Direct_free-kick': 0.94897443, 'Yellow_card': 0.7947023, 'no_event': 0.90397197, 'Red_card': 0.8074773, 'Penalty': 0.88268095}
#   File: 24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.97104466, 'Direct_free-kick': 0.9718321, 'Yellow_card': 0.8941089, 'no_event': 0.9529563, 'Red_card': 0.84846723, 'Penalty': 0.9241152}
#   File: 50_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.94868267, 'Direct_free-kick': 0.9597784, 'Yellow_card': 0.8652226, 'no_event': 0.9268663, 'Red_card': 0.81755376, 'Penalty': 0.8967686}
#   File: 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9391961, 'Direct_free-kick': 0.94445544, 'Yellow_card': 0.8549874, 'no_event': 0.9262437, 'Red_card': 0.82508767, 'Penalty': 0.9051106}
#   File: 5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9543044, 'Direct_free-kick': 0.95976317, 'Yellow_card': 0.8696816, 'no_event': 0.9260473, 'Red_card': 0.815138, 'Penalty': 0.8970239}
#   File: 33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9482714, 'Direct_free-kick': 0.9514065, 'Yellow_card': 0.8294696, 'no_event': 0.91158414, 'Red_card': 0.7850125, 'Penalty': 0.9076648}
#   File: 34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.96066743, 'Direct_free-kick': 0.9409534, 'Yellow_card': 0.88233364, 'no_event': 0.93439454, 'Red_card': 0.9017731, 'Penalty': 0.9356388}
#
# Testing Yellow_card training clips...
#   File: 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.93570304, 'Direct_free-kick': 0.91598594, 'Yellow_card': 0.92620856, 'no_event': 0.9464036, 'Red_card': 0.88788414, 'Penalty': 0.90869963}
#   File: 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8826562, 'Direct_free-kick': 0.8390974, 'Yellow_card': 0.96935594, 'no_event': 0.89657354, 'Red_card': 0.8638104, 'Penalty': 0.8771247}
#   File: 44_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9439753, 'Direct_free-kick': 0.9216016, 'Yellow_card': 0.92457795, 'no_event': 0.95637, 'Red_card': 0.8758613, 'Penalty': 0.91849095}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.91390306, 'Direct_free-kick': 0.87893105, 'Yellow_card': 0.9426222, 'no_event': 0.93024755, 'Red_card': 0.90068984, 'Penalty': 0.8901559}
#   File: 29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9206072, 'Direct_free-kick': 0.9303874, 'Yellow_card': 0.8084531, 'no_event': 0.8859973, 'Red_card': 0.78534883, 'Penalty': 0.8623254}
#   File: 14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.90477043, 'Direct_free-kick': 0.8907492, 'Yellow_card': 0.87236047, 'no_event': 0.9174681, 'Red_card': 0.8436415, 'Penalty': 0.8713153}
#   File: 18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8889874, 'Direct_free-kick': 0.8332997, 'Yellow_card': 0.95923424, 'no_event': 0.909848, 'Red_card': 0.9243134, 'Penalty': 0.880882}
#   File: 52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8682648, 'Direct_free-kick': 0.82562673, 'Yellow_card': 0.93349135, 'no_event': 0.88374686, 'Red_card': 0.8957009, 'Penalty': 0.86665213}
#   File: 56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.88395137, 'Direct_free-kick': 0.84310496, 'Yellow_card': 0.93298703, 'no_event': 0.91655445, 'Red_card': 0.8793272, 'Penalty': 0.8997407}
#   File: 17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8676661, 'Direct_free-kick': 0.8146329, 'Yellow_card': 0.9553193, 'no_event': 0.8746444, 'Red_card': 0.86858296, 'Penalty': 0.85268396}
#   File: 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.90032256, 'Direct_free-kick': 0.87623423, 'Yellow_card': 0.84327066, 'no_event': 0.8910566, 'Red_card': 0.80811924, 'Penalty': 0.881546}
#   File: 37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9058008, 'Direct_free-kick': 0.8611351, 'Yellow_card': 0.97516656, 'no_event': 0.9261435, 'Red_card': 0.90573686, 'Penalty': 0.9057188}
#
# Testing no_event training clips...
#   File: ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.90271395, 'Direct_free-kick': 0.90720165, 'Yellow_card': 0.8394271, 'no_event': 0.90952384, 'Red_card': 0.7835568, 'Penalty': 0.87203884}
#   File: ng145_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.91904193, 'Direct_free-kick': 0.91629964, 'Yellow_card': 0.8598456, 'no_event': 0.92996097, 'Red_card': 0.8498212, 'Penalty': 0.8898065}
#   File: ng127_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.94916284, 'Direct_free-kick': 0.949445, 'Yellow_card': 0.8730421, 'no_event': 0.94649476, 'Red_card': 0.86935306, 'Penalty': 0.9168452}
#   File: ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8770138, 'Direct_free-kick': 0.88424796, 'Yellow_card': 0.8105446, 'no_event': 0.87727356, 'Red_card': 0.76035285, 'Penalty': 0.81662834}
#   File: ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: no_event, Predicted: Penalty, Correct: False
#     Similarities: {'Goal': 0.87961257, 'Direct_free-kick': 0.8413361, 'Yellow_card': 0.8968429, 'no_event': 0.8993599, 'Red_card': 0.8418139, 'Penalty': 0.9024614}
#   File: ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.902292, 'Direct_free-kick': 0.89803684, 'Yellow_card': 0.8166199, 'no_event': 0.8994902, 'Red_card': 0.8132858, 'Penalty': 0.86724126}
#   File: ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9347325, 'Direct_free-kick': 0.9198948, 'Yellow_card': 0.91022587, 'no_event': 0.93779707, 'Red_card': 0.8485265, 'Penalty': 0.91402775}
#   File: ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9689982, 'Direct_free-kick': 0.9642147, 'Yellow_card': 0.90233314, 'no_event': 0.95393836, 'Red_card': 0.8719081, 'Penalty': 0.92987657}
#   File: ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9210154, 'Direct_free-kick': 0.88238335, 'Yellow_card': 0.90285826, 'no_event': 0.9228418, 'Red_card': 0.8744546, 'Penalty': 0.9030329}
#   File: ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.922354, 'Direct_free-kick': 0.9389192, 'Yellow_card': 0.8381319, 'no_event': 0.93204707, 'Red_card': 0.79681516, 'Penalty': 0.8790029}
#   File: ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.84582067, 'Direct_free-kick': 0.8814076, 'Yellow_card': 0.7878444, 'no_event': 0.8577505, 'Red_card': 0.72873193, 'Penalty': 0.8143997}
#   File: ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8130789, 'Direct_free-kick': 0.79168755, 'Yellow_card': 0.8719436, 'no_event': 0.84466386, 'Red_card': 0.7594859, 'Penalty': 0.80635566}
#
# Testing Red_card training clips...
# Warning: Only 2 files available for Red_card, using all of them for evaluation
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.90598536, 'Direct_free-kick': 0.86331177, 'Yellow_card': 0.9629205, 'no_event': 0.92170364, 'Red_card': 0.91063344, 'Penalty': 0.90186286}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8893529, 'Direct_free-kick': 0.8445072, 'Yellow_card': 0.9557822, 'no_event': 0.9074132, 'Red_card': 0.89822865, 'Penalty': 0.8863624}
#
# Testing Penalty training clips...
# Warning: Only 4 files available for Penalty, using all of them for evaluation
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.95524955, 'Direct_free-kick': 0.9319354, 'Yellow_card': 0.9358891, 'no_event': 0.94942194, 'Red_card': 0.8973948, 'Penalty': 0.92900103}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9633107, 'Direct_free-kick': 0.94961816, 'Yellow_card': 0.8999971, 'no_event': 0.9506579, 'Red_card': 0.87295574, 'Penalty': 0.9412253}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9587087, 'Direct_free-kick': 0.9474024, 'Yellow_card': 0.8906808, 'no_event': 0.9465555, 'Red_card': 0.86339825, 'Penalty': 0.9217742}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.97174835, 'Direct_free-kick': 0.9384645, 'Yellow_card': 0.91081154, 'no_event': 0.9437114, 'Red_card': 0.85814464, 'Penalty': 0.9545006}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5185
# Weighted Precision: 0.4947
# Weighted Recall: 0.5185
# Weighted F₁ Score: 0.4854
#
# Per-class Accuracy:
#   Goal: 0.8333 (10/12)
#   Direct_free-kick: 0.5833 (7/12)
#   Yellow_card: 0.5833 (7/12)
#   no_event: 0.3333 (4/12)
#   Red_card: 0.0000 (0/2)
#   Penalty: 0.0000 (0/4)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event', 'Red_card', 'Penalty']
# [[10  2  0  0  0  0]
#  [ 5  7  0  0  0  0]
#  [ 1  1  7  3  0  0]
#  [ 2  4  1  4  0  1]
#  [ 0  0  2  0  0  0]
#  [ 4  0  0  0  0  0]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.45      0.83      0.59        12
# Direct_free-kick       0.50      0.58      0.54        12
#      Yellow_card       0.70      0.58      0.64        12
#         no_event       0.57      0.33      0.42        12
#         Red_card       0.00      0.00      0.00         2
#          Penalty       0.00      0.00      0.00         4
#
#         accuracy                           0.52        54
#        macro avg       0.37      0.39      0.36        54
#     weighted avg       0.49      0.52      0.49        54
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 54
# Training samples: 54
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 2 times
#   Direct_free-kick → Goal: 5 times
#   Yellow_card → Goal: 1 times
#   Yellow_card → Direct_free-kick: 1 times
#   Yellow_card → no_event: 3 times
#   no_event → Goal: 2 times
#   no_event → Direct_free-kick: 4 times
#   no_event → Yellow_card: 1 times
#   no_event → Penalty: 1 times
#   Red_card → Yellow_card: 2 times
#   Penalty → Goal: 4 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.5185
# Training Set Accuracy: 0.5185
# Weighted Precision: 0.4947
# Weighted Recall: 0.5185
# Weighted F₁ Score: 0.4854
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, num_prototype_samples=5):
    """
    Build prototypes for each event class from randomly selected test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        num_prototype_samples (int): Number of random samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_prototype_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for prototype")
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, num_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} random test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples=12):
    """
    Evaluate classification performance on a random subset of training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        num_eval_samples (int): Number of random samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON {num_eval_samples} RANDOM TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_eval_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for evaluation")
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, num_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from random 5 test samples,
    and evaluates on 12 random training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Random Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/Multiclass-unequal samples/R(2+1)D embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event", "Red_card", "Penalty"]
    
    # Number of test samples to use for prototype creation
    num_prototype_samples = 5
    
    # Number of training samples to evaluate per class
    num_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from random subset of test embeddings
    print(f"\nStep 1: Building prototypes from {num_prototype_samples} random test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, num_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on random training samples
    print(f"\nStep 2: Evaluating classification performance on {num_eval_samples} random training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Random Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 29 embeddings in Goal/Train
#   Found 8 embeddings in Goal/Test
#   Found 32 embeddings in Direct_free-kick/Train
#   Found 8 embeddings in Direct_free-kick/Test
#   Found 41 embeddings in Yellow_card/Train
#   Found 11 embeddings in Yellow_card/Test
#   Found 37 embeddings in no_event/Train
#   Found 10 embeddings in no_event/Test
#   Found 2 embeddings in Red_card/Train
#   Found 1 embeddings in Red_card/Test
#   Found 4 embeddings in Penalty/Train
#   Found 1 embeddings in Penalty/Test
#
# Step 1: Building prototypes from 5 random test samples per class...
# Loading 5 random test embeddings for Goal prototype...
#   Selected 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (512,))
#   Selected 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy for prototype (shape: (512,))
#   Selected 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (512,))
# Built prototype for Goal from 5 test samples
# Loading 5 random test embeddings for Direct_free-kick prototype...
#   Selected 32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (512,))
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (512,))
#   Selected 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy for prototype (shape: (512,))
#   Selected 36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy for prototype (shape: (512,))
#   Selected 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
# Built prototype for Direct_free-kick from 5 test samples
# Loading 5 random test embeddings for Yellow_card prototype...
#   Selected 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (512,))
#   Selected 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (512,))
#   Selected 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
#   Selected 46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy for prototype (shape: (512,))
#   Selected 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (512,))
# Built prototype for Yellow_card from 5 test samples
# Loading 5 random test embeddings for no_event prototype...
#   Selected ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy for prototype (shape: (512,))
#   Selected ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
#   Selected ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy for prototype (shape: (512,))
#   Selected ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (512,))
# Built prototype for no_event from 5 test samples
# Warning: Only 1 files available for Red_card, using all of them for prototype
# Loading 1 random test embeddings for Red_card prototype...
#   Selected 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy for prototype (shape: (512,))
# Built prototype for Red_card from 1 test samples
# Warning: Only 1 files available for Penalty, using all of them for prototype
# Loading 1 random test embeddings for Penalty prototype...
#   Selected 4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy for prototype (shape: (512,))
# Built prototype for Penalty from 1 test samples
#
# Successfully built prototypes for 6 classes:
#   Goal: shape (512,)
#   Direct_free-kick: shape (512,)
#   Yellow_card: shape (512,)
#   no_event: shape (512,)
#   Red_card: shape (512,)
#   Penalty: shape (512,)
#
# Files used for prototype creation:
#   Goal: ['7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy', '22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy', '15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', '4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy']
#   Direct_free-kick: ['32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', '4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', '62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy', '36_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy', '23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy']
#   Yellow_card: ['7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy', '35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', '51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', '46_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy', '27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy']
#   no_event: ['ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy', 'ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', 'ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', 'ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.npy', 'ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy']
#   Red_card: ['1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy']
#   Penalty: ['4_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy']
#
# Step 2: Evaluating classification performance on 12 random training samples per class...
#
# ============================================================
# EVALUATING ON 12 RANDOM TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9065964, 'Direct_free-kick': 0.91177, 'Yellow_card': 0.73894817, 'no_event': 0.8540815, 'Red_card': 0.6844178, 'Penalty': 0.8537626}
#   File: 20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.91837084, 'Direct_free-kick': 0.9107206, 'Yellow_card': 0.7454541, 'no_event': 0.8615004, 'Red_card': 0.67428136, 'Penalty': 0.84632635}
#   File: 17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9062816, 'Direct_free-kick': 0.9283322, 'Yellow_card': 0.7558174, 'no_event': 0.89287364, 'Red_card': 0.7316949, 'Penalty': 0.8346628}
#   File: 27_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.88873744, 'Direct_free-kick': 0.8928293, 'Yellow_card': 0.79792, 'no_event': 0.866107, 'Red_card': 0.7423459, 'Penalty': 0.8781785}
#   File: 32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.8735733, 'Direct_free-kick': 0.8654419, 'Yellow_card': 0.75931567, 'no_event': 0.86894095, 'Red_card': 0.71625805, 'Penalty': 0.8215463}
#   File: 19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.89002645, 'Direct_free-kick': 0.8789481, 'Yellow_card': 0.7852304, 'no_event': 0.8908695, 'Red_card': 0.7180608, 'Penalty': 0.8370571}
#   File: 31_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.88510793, 'Direct_free-kick': 0.8891186, 'Yellow_card': 0.7861724, 'no_event': 0.856338, 'Red_card': 0.7150106, 'Penalty': 0.8123677}
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8458521, 'Direct_free-kick': 0.86763567, 'Yellow_card': 0.68439406, 'no_event': 0.82462966, 'Red_card': 0.6232164, 'Penalty': 0.7836346}
#   File: 16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.90389216, 'Direct_free-kick': 0.8517924, 'Yellow_card': 0.81633353, 'no_event': 0.8832839, 'Red_card': 0.6845218, 'Penalty': 0.8272842}
#   File: 24_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9095531, 'Direct_free-kick': 0.8887464, 'Yellow_card': 0.82039684, 'no_event': 0.8872671, 'Red_card': 0.74237955, 'Penalty': 0.8724363}
#   File: 29_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9041927, 'Direct_free-kick': 0.83642054, 'Yellow_card': 0.8770931, 'no_event': 0.91690576, 'Red_card': 0.766593, 'Penalty': 0.8492197}
#   File: 18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9035295, 'Direct_free-kick': 0.919246, 'Yellow_card': 0.752933, 'no_event': 0.8857728, 'Red_card': 0.69694746, 'Penalty': 0.8435433}
#
# Testing Direct_free-kick training clips...
#   File: 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8280581, 'Direct_free-kick': 0.89070415, 'Yellow_card': 0.66218394, 'no_event': 0.77292824, 'Red_card': 0.58482707, 'Penalty': 0.77037245}
#   File: 37_2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8543109, 'Direct_free-kick': 0.8671218, 'Yellow_card': 0.7468717, 'no_event': 0.8675916, 'Red_card': 0.6994981, 'Penalty': 0.7627974}
#   File: 7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8762017, 'Direct_free-kick': 0.9020686, 'Yellow_card': 0.72460145, 'no_event': 0.8691752, 'Red_card': 0.6685194, 'Penalty': 0.800719}
#   File: 44_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8052451, 'Direct_free-kick': 0.7847396, 'Yellow_card': 0.77123165, 'no_event': 0.8132624, 'Red_card': 0.7917646, 'Penalty': 0.78726935}
#   File: 34_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8627224, 'Direct_free-kick': 0.86298895, 'Yellow_card': 0.76636237, 'no_event': 0.84949565, 'Red_card': 0.75781024, 'Penalty': 0.81341004}
#   File: 33_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.86960495, 'Direct_free-kick': 0.9171571, 'Yellow_card': 0.6962556, 'no_event': 0.81956756, 'Red_card': 0.64372003, 'Penalty': 0.7799317}
#   File: 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.86223745, 'Direct_free-kick': 0.8321537, 'Yellow_card': 0.81054, 'no_event': 0.88953966, 'Red_card': 0.77901757, 'Penalty': 0.8357656}
#   File: 22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8468288, 'Direct_free-kick': 0.86264795, 'Yellow_card': 0.69221306, 'no_event': 0.8340826, 'Red_card': 0.64746857, 'Penalty': 0.7346637}
#   File: 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8724385, 'Direct_free-kick': 0.8508915, 'Yellow_card': 0.8098551, 'no_event': 0.8913282, 'Red_card': 0.75856733, 'Penalty': 0.8368962}
#   File: 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.89198387, 'Direct_free-kick': 0.8662586, 'Yellow_card': 0.829121, 'no_event': 0.90151966, 'Red_card': 0.75642395, 'Penalty': 0.8852314}
#   File: 21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8808694, 'Direct_free-kick': 0.9161584, 'Yellow_card': 0.71947193, 'no_event': 0.8682822, 'Red_card': 0.6522143, 'Penalty': 0.8105235}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8883971, 'Direct_free-kick': 0.9174502, 'Yellow_card': 0.692352, 'no_event': 0.83581555, 'Red_card': 0.62095106, 'Penalty': 0.8051605}
#
# Testing Yellow_card training clips...
#   File: 43_2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.7799376, 'Direct_free-kick': 0.71204954, 'Yellow_card': 0.84026027, 'no_event': 0.8480136, 'Red_card': 0.832263, 'Penalty': 0.72469246}
#   File: 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8166628, 'Direct_free-kick': 0.7179527, 'Yellow_card': 0.90193474, 'no_event': 0.85965455, 'Red_card': 0.8703555, 'Penalty': 0.7529543}
#   File: 12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.84336996, 'Direct_free-kick': 0.73997843, 'Yellow_card': 0.9305254, 'no_event': 0.87169856, 'Red_card': 0.8650462, 'Penalty': 0.77453864}
#   File: 18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8033165, 'Direct_free-kick': 0.716334, 'Yellow_card': 0.92755145, 'no_event': 0.84249544, 'Red_card': 0.8979832, 'Penalty': 0.73051167}
#   File: 16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7571298, 'Direct_free-kick': 0.667367, 'Yellow_card': 0.92601764, 'no_event': 0.7985335, 'Red_card': 0.82517314, 'Penalty': 0.70431614}
#   File: 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8434441, 'Direct_free-kick': 0.87798303, 'Yellow_card': 0.7162994, 'no_event': 0.8263073, 'Red_card': 0.65254843, 'Penalty': 0.77822757}
#   File: 14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.86113656, 'Direct_free-kick': 0.80777705, 'Yellow_card': 0.8263777, 'no_event': 0.87388575, 'Red_card': 0.71364516, 'Penalty': 0.80437815}
#   File: 3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9071087, 'Direct_free-kick': 0.8312501, 'Yellow_card': 0.84663194, 'no_event': 0.87941474, 'Red_card': 0.7013166, 'Penalty': 0.83758724}
#   File: 29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8399347, 'Direct_free-kick': 0.8891089, 'Yellow_card': 0.69420934, 'no_event': 0.8013735, 'Red_card': 0.63017654, 'Penalty': 0.7738923}
#   File: 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8924285, 'Direct_free-kick': 0.8577587, 'Yellow_card': 0.86359537, 'no_event': 0.918939, 'Red_card': 0.8039177, 'Penalty': 0.8179387}
#   File: 15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.840707, 'Direct_free-kick': 0.7572253, 'Yellow_card': 0.90363646, 'no_event': 0.8984082, 'Red_card': 0.86426234, 'Penalty': 0.785614}
#   File: 21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.77510685, 'Direct_free-kick': 0.69310474, 'Yellow_card': 0.8906811, 'no_event': 0.7772527, 'Red_card': 0.7501799, 'Penalty': 0.7437598}
#
# Testing no_event training clips...
#   File: ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7369773, 'Direct_free-kick': 0.6678252, 'Yellow_card': 0.83914185, 'no_event': 0.79397124, 'Red_card': 0.77985895, 'Penalty': 0.66114676}
#   File: ng96_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.86038697, 'Direct_free-kick': 0.7931746, 'Yellow_card': 0.84916854, 'no_event': 0.86648756, 'Red_card': 0.7844571, 'Penalty': 0.81066805}
#   File: ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8608203, 'Direct_free-kick': 0.9180093, 'Yellow_card': 0.6676636, 'no_event': 0.80624145, 'Red_card': 0.61626315, 'Penalty': 0.801899}
#   File: ng128_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.79629505, 'Direct_free-kick': 0.7214663, 'Yellow_card': 0.9089803, 'no_event': 0.81949466, 'Red_card': 0.8805362, 'Penalty': 0.77384025}
#   File: ng122_2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.88132894, 'Direct_free-kick': 0.8729268, 'Yellow_card': 0.7816987, 'no_event': 0.87035936, 'Red_card': 0.7570095, 'Penalty': 0.84900725}
#   File: ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91284704, 'Direct_free-kick': 0.8899176, 'Yellow_card': 0.78918755, 'no_event': 0.8929999, 'Red_card': 0.72234917, 'Penalty': 0.84390604}
#   File: ng127_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.884382, 'Direct_free-kick': 0.89486015, 'Yellow_card': 0.7029486, 'no_event': 0.84642947, 'Red_card': 0.62262464, 'Penalty': 0.79873824}
#   File: ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8542344, 'Direct_free-kick': 0.88815284, 'Yellow_card': 0.6960616, 'no_event': 0.81310946, 'Red_card': 0.6224359, 'Penalty': 0.807453}
#   File: ng111_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8646291, 'Direct_free-kick': 0.9028584, 'Yellow_card': 0.71585864, 'no_event': 0.81376207, 'Red_card': 0.6413193, 'Penalty': 0.7975583}
#   File: ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8636024, 'Direct_free-kick': 0.8575041, 'Yellow_card': 0.7411634, 'no_event': 0.85064673, 'Red_card': 0.6893071, 'Penalty': 0.76856804}
#   File: ng110_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8642392, 'Direct_free-kick': 0.80826265, 'Yellow_card': 0.8814136, 'no_event': 0.8920288, 'Red_card': 0.82735103, 'Penalty': 0.77283996}
#   File: ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8639946, 'Direct_free-kick': 0.90217936, 'Yellow_card': 0.69142234, 'no_event': 0.8267635, 'Red_card': 0.6420783, 'Penalty': 0.79602605}
#
# Testing Red_card training clips...
# Warning: Only 2 files available for Red_card, using all of them for evaluation
#   File: 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.79118234, 'Direct_free-kick': 0.699769, 'Yellow_card': 0.903568, 'no_event': 0.8343456, 'Red_card': 0.87841195, 'Penalty': 0.736416}
#   File: 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Red_card, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8089228, 'Direct_free-kick': 0.7205019, 'Yellow_card': 0.91018623, 'no_event': 0.86438465, 'Red_card': 0.8652833, 'Penalty': 0.7377807}
#
# Testing Penalty training clips...
# Warning: Only 4 files available for Penalty, using all of them for evaluation
#   File: 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Penalty, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8597965, 'Direct_free-kick': 0.7496271, 'Yellow_card': 0.91432905, 'no_event': 0.8855914, 'Red_card': 0.8297782, 'Penalty': 0.7829553}
#   File: 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Penalty, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8654555, 'Direct_free-kick': 0.78785133, 'Yellow_card': 0.8274046, 'no_event': 0.8890164, 'Red_card': 0.7136982, 'Penalty': 0.817146}
#   File: 3_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.901108, 'Direct_free-kick': 0.88408965, 'Yellow_card': 0.8120631, 'no_event': 0.88554746, 'Red_card': 0.74046445, 'Penalty': 0.8573134}
#   File: 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Penalty, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.88617474, 'Direct_free-kick': 0.83059365, 'Yellow_card': 0.85141546, 'no_event': 0.87347233, 'Red_card': 0.74542516, 'Penalty': 0.82440454}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.3519
# Weighted Precision: 0.3221
# Weighted Recall: 0.3519
# Weighted F₁ Score: 0.3295
#
# Per-class Accuracy:
#   Goal: 0.3333 (4/12)
#   Direct_free-kick: 0.5833 (7/12)
#   Yellow_card: 0.5000 (6/12)
#   no_event: 0.1667 (2/12)
#   Red_card: 0.0000 (0/2)
#   Penalty: 0.0000 (0/4)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event', 'Red_card', 'Penalty']
# [[4 6 0 2 0 0]
#  [0 7 0 5 0 0]
#  [1 2 6 3 0 0]
#  [3 5 2 2 0 0]
#  [0 0 2 0 0 0]
#  [2 0 1 1 0 0]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.40      0.33      0.36        12
# Direct_free-kick       0.35      0.58      0.44        12
#      Yellow_card       0.55      0.50      0.52        12
#         no_event       0.15      0.17      0.16        12
#         Red_card       0.00      0.00      0.00         2
#          Penalty       0.00      0.00      0.00         4
#
#         accuracy                           0.35        54
#        macro avg       0.24      0.26      0.25        54
#     weighted avg       0.32      0.35      0.33        54
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 54
# Training samples: 54
# Number of classes: 6
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 6 times
#   Goal → no_event: 2 times
#   Direct_free-kick → no_event: 5 times
#   Yellow_card → Goal: 1 times
#   Yellow_card → Direct_free-kick: 2 times
#   Yellow_card → no_event: 3 times
#   no_event → Goal: 3 times
#   no_event → Direct_free-kick: 5 times
#   no_event → Yellow_card: 2 times
#   Red_card → Yellow_card: 2 times
#   Penalty → Goal: 2 times
#   Penalty → Yellow_card: 1 times
#   Penalty → no_event: 1 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.3519
# Training Set Accuracy: 0.3519
# Weighted Precision: 0.3221
# Weighted Recall: 0.3519
# Weighted F₁ Score: 0.3295
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================
