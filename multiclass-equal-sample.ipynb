# %%
import os
import json
from moviepy import VideoFileClip
import random
import warnings
warnings.filterwarnings('ignore')

def extract_event_clips_moviepy():
    """
    Extract clips for multiple events ("Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty")
    and generate random non-event clips without enforcing min_clips per match.
    """
    # Base directory containing season folders
    base_dir = "F:/AIM Lab/Experiment"
    clips_base_dir = os.path.join(base_dir, "Multiclass-equal sizes", "Clips")
    
    # Create base clips directory if it doesn't exist
    os.makedirs(clips_base_dir, exist_ok=True)
    
    # Event types to process
    event_types = ["Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty"]
    event_dirs = {event: os.path.join(clips_base_dir, event.replace(" ", "_")) for event in event_types}
    random_clips_dir = os.path.join(clips_base_dir, "no_event")
    
    # Create directories for each event and random clips
    for event_dir in event_dirs.values():
        os.makedirs(event_dir, exist_ok=True)
    os.makedirs(random_clips_dir, exist_ok=True)
    
    # Counters for clips
    event_counters = {event: 1 for event in event_types}
    random_counter = 1
    
    # Iterate through season folders (e.g., 2014-2015, 2015-2014)
    for season_folder in os.listdir(base_dir):
        season_path = os.path.join(base_dir, season_folder)
        if os.path.isdir(season_path) and season_folder.startswith("20"):
            print(f"Processing season: {season_folder}")
            
            # Iterate through match folders
            for match_folder in os.listdir(season_path):
                match_path = os.path.join(season_path, match_folder)
                if os.path.isdir(match_path):
                    print(f"  Processing match: {match_folder}")
                    
                    # Look for Labels-v2.json file
                    labels_file = os.path.join(match_path, "Labels-v2.json")
                    video_file = os.path.join(match_path, "2_720p.mkv")
                    
                    if os.path.exists(labels_file) and os.path.exists(video_file):
                        # Extract events from second half
                        event_timestamps = extract_event_timestamps(labels_file, event_types)
                        
                        # Load video once for all clips from this match
                        try:
                            video = VideoFileClip(video_file)
                            video_duration = video.duration
                            
                            # Create clips for each event
                            for event, timestamps in event_timestamps.items():
                                for timestamp in timestamps:
                                    create_event_clip_moviepy(
                                        video, 
                                        timestamp, 
                                        event_dirs[event], 
                                        f"{event_counters[event]}_{match_folder}",
                                        event
                                    )
                                    event_counters[event] += 1
                            
                            # Generate random non-event clips
                            avoided_intervals = generate_avoided_intervals(event_timestamps)
                            num_random_clips = sum(len(timestamps) for timestamps in event_timestamps.values())
                            random_start_times = generate_random_segments(video_duration, avoided_intervals, num_random_clips, 7.0)
                            
                            for start_time in random_start_times:
                                create_random_clip_moviepy(
                                    video, 
                                    start_time, 
                                    random_clips_dir, 
                                    f"ng{random_counter}_{match_folder}"
                                )
                                random_counter += 1
                            
                            # Close video to free memory
                            video.close()
                            
                        except Exception as e:
                            print(f"    Error loading video: {e}")
                    else:
                        if not os.path.exists(labels_file):
                            print(f"    Labels-v2.json not found")
                        if not os.path.exists(video_file):
                            print(f"    2_720p.mkv not found")

def extract_event_timestamps(labels_file, event_types):
    """
    Extract timestamps for specified events from the second half of the match.
    
    Args:
        labels_file (str): Path to the Labels-v2.json file
        event_types (list): List of event types to extract
        
    Returns:
        dict: Dictionary with event types as keys and lists of timestamps as values
    """
    try:
        with open(labels_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event_timestamps = {event: [] for event in event_types}
        
        for annotation in data.get('annotations', []):
            label = annotation.get('label')
            game_time = annotation.get('gameTime', '')
            
            if label in event_types and game_time.startswith('2 -'):
                position = int(annotation.get('position', 0))
                event_timestamps[label].append(position)
        
        return event_timestamps
        
    except Exception as e:
        print(f"    Error reading labels file: {e}")
        return {event: [] for event in event_types}

def create_event_clip_moviepy(video_clip, position_ms, output_dir, clip_name, event):
    """
    Create a 7-second video clip around the event time using MoviePy.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        position_ms (int): Event position in milliseconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
        event (str): Event type for logging
    """
    try:
        # Calculate start and end times (3 seconds before and after)
        start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before, but not negative
        end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after (total 7 seconds)
        
        # Make sure we don't exceed video duration
        end_seconds = min(end_seconds, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating clip {clip_name} for {event} at {start_seconds:.2f}s")
        
        # Extract the clip
        event_clip = video_clip.subclipped(start_seconds, end_seconds)
        
        # Write the clip to file
        event_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        event_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating clip {clip_name}: {e}")

def create_random_clip_moviepy(video_clip, start_time, output_dir, clip_name):
    """
    Create a random 7-second video clip.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        start_time (float): Start time in seconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
    """
    try:
        # Calculate end time
        end_time = start_time + 7.0  # 7 seconds duration
        
        # Make sure we don't exceed video duration
        end_time = min(end_time, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating random clip {clip_name}")
        
        # Extract the clip
        random_clip = video_clip.subclipped(start_time, end_time)
        
        # Write the clip to file
        random_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        random_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating random clip {clip_name}: {e}")

def generate_avoided_intervals(event_timestamps):
    """
    Generate avoided intervals for random clip generation based on event timestamps.
    
    Args:
        event_timestamps (dict): Dictionary of event timestamps
        
    Returns:
        list: List of avoided intervals (start, end) in seconds
    """
    avoided_intervals = []
    for timestamps in event_timestamps.values():
        for position_ms in timestamps:
            start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before
            end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after
            avoided_intervals.append((start_seconds, end_seconds))
    return avoided_intervals

def generate_random_segments(video_duration, avoided_intervals, num_segments, segment_duration):
    """
    Generate random segments avoiding specified intervals.
    
    Args:
        video_duration (float): Total duration of the video
        avoided_intervals (list): List of (start, end) intervals to avoid
        num_segments (int): Number of segments to generate
        segment_duration (float): Duration of each segment
        
    Returns:
        list: List of start times for random segments
    """
    random_segments = []
    max_attempts = 1000
    
    for _ in range(num_segments):
        attempts = 0
        while attempts < max_attempts:
            max_start = video_duration - segment_duration
            if max_start <= 0:
                break
            
            start_time = random.uniform(0, max_start)
            end_time = start_time + segment_duration
            
            # Check if this segment overlaps with any avoided interval
            overlap = False
            for avoid_start, avoid_end in avoided_intervals:
                if not (end_time <= avoid_start or start_time >= avoid_end):
                    overlap = True
                    break
            
            if not overlap:
                random_segments.append(start_time)
                break
            
            attempts += 1
        
        if attempts >= max_attempts:
            print(f"Warning: Could not find non-overlapping segment after {max_attempts} attempts")
    
    return random_segments

# Run the extraction
print("Multiclass Clip Extractor (MoviePy)")
print("===================================")

try:
    extract_event_clips_moviepy()
    print("\nProcessing complete!")
except ImportError:
    print("Error: MoviePy not installed. Install with: pip install moviepy")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Multiclass Clip Extractor (MoviePy)
# ===================================
# Processing season: 2014-2015
#   Processing match: 2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Goal at 2118.49s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Red card at 1462.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Red_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Yellow card at 1018.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Yellow card at 1502.67s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Direct free-kick at 618.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng2_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng3_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng4_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng4_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng5_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng5_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#   Processing match: 2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Goal at 2910.95s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Yellow card at 621.99s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\3_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Yellow card at 2344.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\4_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Direct free-kick at 1748.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng6_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng7_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng8_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng8_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng9_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng9_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#   Processing match: 2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Goal at 1624.79s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 161.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\5_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2324.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\6_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2518.73s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\7_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2561.38s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\8_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 2714.45s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\9_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Direct free-kick at 2547.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng10_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng10_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng11_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng12_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng12_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng13_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng13_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng14_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng14_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng15_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng15_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng16_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng16_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#   Processing match: 2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Goal at 1666.53s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 1071.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\10_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 1919.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\11_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 2340.82s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\12_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 2742.72s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\13_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 1443.21s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 1976.67s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\5_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 6_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 2656.39s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\6_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng17_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng18_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng19_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng19_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng20_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng20_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng21_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng21_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng22_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng22_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng23_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng23_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng24_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng24_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing season: 2015-2014
#   Processing match: 2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
#     Creating clip 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Goal at 541.39s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Red card at 403.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Red_card\2_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Yellow card at 478.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\14_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Yellow card at 2851.43s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\15_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 72.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\7_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 1237.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\8_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 9_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 2304.39s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\9_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 2359.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\10_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Penalty at 541.02s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Penalty\1_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng25_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng26_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng27_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng27_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng28_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng28_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng29_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng29_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng30_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng30_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng31_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng31_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng32_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng32_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng33_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng33_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#   Processing match: 2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
#     Creating clip 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 1170.28s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 2019.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 2127.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\8_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1541.16s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\16_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1622.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\17_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 827.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\11_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 871.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\12_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 962.36s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\13_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 1594.93s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\14_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng34_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng35_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng36_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng36_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng37_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng37_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng38_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng38_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng39_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng39_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng40_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng40_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng41_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng41_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng42_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng42_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#   Processing match: 2015-08-29 - 17-00 Manchester City 2 - 0 Watford
#     Creating clip 9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Goal at 85.44s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\9_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Goal at 606.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\10_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Yellow card at 1066.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\18_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 490.69s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\15_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 599.99s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\16_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 1117.37s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\17_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng43_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng44_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng45_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng45_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng46_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng46_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng47_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng47_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng48_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng48_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#   Processing match: 2015-09-12 - 14-45 Everton 3 - 1 Chelsea
#     Creating clip 11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Goal at 2212.88s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\11_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 1155.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2459.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2537.34s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\21_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 2820.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\22_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2419.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\18_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2492.37s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\19_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2858.52s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\20_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng49_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng50_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng51_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng51_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng52_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng52_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng53_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng53_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng54_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng54_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng55_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng55_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng56_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng56_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#   Processing match: 2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
#     Creating clip 12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Goal at 2670.32s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\12_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 1418.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\23_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 1530.95s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\24_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 2113.80s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\25_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Direct free-kick at 1853.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\21_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Direct free-kick at 2086.52s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\22_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng57_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng58_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng59_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng59_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng60_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng60_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng61_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng61_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng62_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng62_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#   Processing match: 2015-09-19 - 19-30 Manchester City 1 - 2 West Ham
#     Creating clip 26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham for Yellow card at 485.32s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\26_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
#     Creating random clip ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng63_2015-09-19 - 19-30 Manchester City 1 - 2 West Ham.mp4
#   Processing match: 2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
#     Creating clip 13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 775.58s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\13_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1207.98s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\14_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1275.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\15_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Goal at 1496.60s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\16_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 502.03s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\23_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 1677.10s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\24_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating clip 25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa for Direct free-kick at 1971.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\25_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng64_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng65_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng66_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng66_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng67_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng67_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng68_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng68_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng69_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng69_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#     Creating random clip ng70_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng70_2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa.mp4
#   Processing match: 2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
#     Creating clip 17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Goal at 481.00s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\17_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 185.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 985.12s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 1713.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\29_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 2394.44s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\30_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 788.11s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\26_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 1531.66s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\27_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 1722.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\28_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng71_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng72_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng73_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng73_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng74_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng74_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng75_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng75_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng76_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng76_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng77_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng77_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng78_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng78_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#   Processing match: 2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
#     Creating clip 18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 1713.32s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\18_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 2224.80s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\19_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 755.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 1138.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\32_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 1242.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\33_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 2440.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\34_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 346.63s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\29_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 1180.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\30_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 2176.45s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\31_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng79_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng80_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng81_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng81_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng82_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng82_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng83_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng83_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng84_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng84_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng85_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng85_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng86_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng86_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng87_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng87_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#   Processing match: 2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
#     Creating clip 20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Goal at 384.77s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\20_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Goal at 2750.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\21_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Red card at 2702.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Red_card\3_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 861.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\35_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 900.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\36_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 1173.18s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\37_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Direct free-kick at 1597.27s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\32_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Penalty at 2749.53s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Penalty\2_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng88_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng89_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng90_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng90_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng91_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng91_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng92_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng92_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng93_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng93_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng94_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng94_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng95_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng95_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#   Processing match: 2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
#     Creating clip 22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Goal at 2137.40s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\22_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Yellow card at 91.59s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\38_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 39_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Yellow card at 2374.97s
# ...
#     Creating clip 51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 1408.65s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\51_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 1974.30s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\52_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 2638.30s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\53_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng135_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng135_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng136_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng137_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng137_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng138_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng138_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng139_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng139_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng140_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng140_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng141_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng141_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng142_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng142_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng143_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng143_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng144_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng144_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#   Processing match: 2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
#     Creating clip 32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 900.64s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\32_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 2741.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\33_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 1054.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 2016.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 2223.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2262.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\54_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2616.91s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\55_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2890.70s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\56_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng145_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng145_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng146_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng147_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng147_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng148_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng148_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng149_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng149_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng150_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng150_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng151_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng151_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng152_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng152_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#   Processing match: 2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
#     Creating clip 34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 473.40s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\34_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 1715.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\35_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 2259.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\36_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 0.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 50.47s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 610.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 1820.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 191.17s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\57_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 654.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\58_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 1175.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\59_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 2502.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\60_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Penalty at 473.04s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Penalty\5_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng153_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng154_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng155_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng155_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng156_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng156_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng157_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng157_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng158_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng158_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng159_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng159_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng160_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng160_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng161_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng161_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng162_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng162_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng163_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng163_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng164_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng164_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#   Processing match: 2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
#     Creating clip 37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Goal at 698.96s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\37_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Yellow card at 1318.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 1779.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\61_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 2260.96s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\62_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 2337.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\63_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng165_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng166_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng167_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng167_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng168_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng168_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng169_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng169_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#
# Processing complete!

# %% [markdown]
# ### Events extraction (goal, direct free-kick, no event, yellow card)

# %%
import os
import json
from moviepy import VideoFileClip
import random
import warnings
warnings.filterwarnings('ignore')

def extract_event_clips_moviepy():
    """
    Extract clips for multiple events ("Goal", "Red card", "Yellow card", "Direct free-kick", "Penalty")
    and generate equal-sized random non-event clips.
    """
    # Base directory containing season folders
    base_dir = "F:/AIM Lab/Experiment"
    clips_base_dir = os.path.join(base_dir, "Multiclass-equal sizes", "Clips")
    
    # Create base clips directory if it doesn't exist
    os.makedirs(clips_base_dir, exist_ok=True)
    
    # Event types to process
    event_types = ["Goal", "Yellow card", "Direct free-kick"]
    event_dirs = {event: os.path.join(clips_base_dir, event.replace(" ", "_")) for event in event_types}
    random_clips_dir = os.path.join(clips_base_dir, "no_event")
    
    # Create directories for each event and random clips
    for event_dir in event_dirs.values():
        os.makedirs(event_dir, exist_ok=True)
    os.makedirs(random_clips_dir, exist_ok=True)
    
    # Counters for clips
    event_counters = {event: 1 for event in event_types}
    random_counter = 1
    
    # Iterate through season folders (e.g., 2014-2015, 2015-2014)
    for season_folder in os.listdir(base_dir):
        season_path = os.path.join(base_dir, season_folder)
        if os.path.isdir(season_path) and season_folder.startswith("20"):
            print(f"Processing season: {season_folder}")
            
            # Iterate through match folders
            for match_folder in os.listdir(season_path):
                match_path = os.path.join(season_path, match_folder)
                if os.path.isdir(match_path):
                    print(f"  Processing match: {match_folder}")
                    
                    # Look for Labels-v2.json file
                    labels_file = os.path.join(match_path, "Labels-v2.json")
                    video_file = os.path.join(match_path, "2_720p.mkv")
                    
                    if os.path.exists(labels_file) and os.path.exists(video_file):
                        # Extract events from second half
                        event_timestamps = extract_event_timestamps(labels_file, event_types)
                        
                        # Find the minimum number of timestamps across all events
                        min_clips = min(len(timestamps) for timestamps in event_timestamps.values())
                        print(f"    Minimum clips per event: {min_clips}")
                        
                        # Load video once for all clips from this match
                        try:
                            video = VideoFileClip(video_file)
                            video_duration = video.duration
                            
                            # Create clips for each event
                            for event, timestamps in event_timestamps.items():
                                for timestamp in timestamps[:min_clips]:
                                    create_event_clip_moviepy(
                                        video, 
                                        timestamp, 
                                        event_dirs[event], 
                                        f"{event_counters[event]}_{match_folder}",
                                        event
                                    )
                                    event_counters[event] += 1
                            
                            # Generate random non-event clips
                            avoided_intervals = generate_avoided_intervals(event_timestamps, min_clips)
                            random_start_times = generate_random_segments(video_duration, avoided_intervals, min_clips, 7.0)
                            
                            for start_time in random_start_times:
                                create_random_clip_moviepy(
                                    video, 
                                    start_time, 
                                    random_clips_dir, 
                                    f"ng{random_counter}_{match_folder}"
                                )
                                random_counter += 1
                            
                            # Close video to free memory
                            video.close()
                            
                        except Exception as e:
                            print(f"    Error loading video: {e}")
                    else:
                        if not os.path.exists(labels_file):
                            print(f"    Labels-v2.json not found")
                        if not os.path.exists(video_file):
                            print(f"    2_720p.mkv not found")

def extract_event_timestamps(labels_file, event_types):
    """
    Extract timestamps for specified events from the second half of the match.
    
    Args:
        labels_file (str): Path to the Labels-v2.json file
        event_types (list): List of event types to extract
        
    Returns:
        dict: Dictionary with event types as keys and lists of timestamps as values
    """
    try:
        with open(labels_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        event_timestamps = {event: [] for event in event_types}
        
        for annotation in data.get('annotations', []):
            label = annotation.get('label')
            game_time = annotation.get('gameTime', '')
            
            if label in event_types and game_time.startswith('2 -'):
                position = int(annotation.get('position', 0))
                event_timestamps[label].append(position)
        
        return event_timestamps
        
    except Exception as e:
        print(f"    Error reading labels file: {e}")
        return {event: [] for event in event_types}

def create_event_clip_moviepy(video_clip, position_ms, output_dir, clip_name, event):
    """
    Create a 7-second video clip around the event time using MoviePy.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        position_ms (int): Event position in milliseconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
        event (str): Event type for logging
    """
    try:
        # Calculate start and end times (3 seconds before and after)
        start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before, but not negative
        end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after (total 7 seconds)
        
        # Make sure we don't exceed video duration
        end_seconds = min(end_seconds, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating clip {clip_name} for {event} at {start_seconds:.2f}s")
        
        # Extract the clip
        event_clip = video_clip.subclipped(start_seconds, end_seconds)
        
        # Write the clip to file
        event_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        event_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating clip {clip_name}: {e}")

def create_random_clip_moviepy(video_clip, start_time, output_dir, clip_name):
    """
    Create a random 7-second video clip.
    
    Args:
        video_clip (VideoFileClip): Loaded video clip
        start_time (float): Start time in seconds
        output_dir (str): Directory to save the clip
        clip_name (str): Name for the output clip
    """
    try:
        # Calculate end time
        end_time = start_time + 7.0  # 7 seconds duration
        
        # Make sure we don't exceed video duration
        end_time = min(end_time, video_clip.duration)
        
        # Output file path
        output_file = os.path.join(output_dir, f"{clip_name}.mp4")
        
        print(f"    Creating random clip {clip_name}")
        
        # Extract the clip
        random_clip = video_clip.subclipped(start_time, end_time)
        
        # Write the clip to file
        random_clip.write_videofile(
            output_file, 
            audio_codec='aac',
            codec='libx264',
            logger=None  # Suppress moviepy logs
        )
        
        # Close the clip to free memory
        random_clip.close()
        
        print(f"    Successfully created {output_file}")
            
    except Exception as e:
        print(f"    Error creating random clip {clip_name}: {e}")

def generate_avoided_intervals(event_timestamps, min_clips):
    """
    Generate avoided intervals for random clip generation based on event timestamps.
    
    Args:
        event_timestamps (dict): Dictionary of event timestamps
        min_clips (int): Minimum number of clips per event
        
    Returns:
        list: List of avoided intervals (start, end) in seconds
    """
    avoided_intervals = []
    for timestamps in event_timestamps.values():
        for position_ms in timestamps[:min_clips]:
            start_seconds = max(0, (position_ms - 3000) / 1000.0)  # 3 seconds before
            end_seconds = (position_ms + 4000) / 1000.0  # 4 seconds after
            avoided_intervals.append((start_seconds, end_seconds))
    return avoided_intervals

def generate_random_segments(video_duration, avoided_intervals, num_segments, segment_duration):
    """
    Generate random segments avoiding specified intervals.
    
    Args:
        video_duration (float): Total duration of the video
        avoided_intervals (list): List of (start, end) intervals to avoid
        num_segments (int): Number of segments to generate
        segment_duration (float): Duration of each segment
        
    Returns:
        list: List of start times for random segments
    """
    random_segments = []
    max_attempts = 1000
    
    for _ in range(num_segments):
        attempts = 0
        while attempts < max_attempts:
            max_start = video_duration - segment_duration
            if max_start <= 0:
                break
            
            start_time = random.uniform(0, max_start)
            end_time = start_time + segment_duration
            
            # Check if this segment overlaps with any avoided interval
            overlap = False
            for avoid_start, avoid_end in avoided_intervals:
                if not (end_time <= avoid_start or start_time >= avoid_end):
                    overlap = True
                    break
            
            if not overlap:
                random_segments.append(start_time)
                break
            
            attempts += 1
        
        if attempts >= max_attempts:
            print(f"Warning: Could not find non-overlapping segment after {max_attempts} attempts")
    
    return random_segments

# Run the extraction
print("Multiclass Clip Extractor (MoviePy)")
print("===================================")

try:
    extract_event_clips_moviepy()
    print("\nProcessing complete!")
except ImportError:
    print("Error: MoviePy not installed. Install with: pip install moviepy")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Multiclass Clip Extractor (MoviePy)
# ===================================
# Processing season: 2014-2015
#   Processing match: 2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
#     Minimum clips per event: 1
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Goal at 2118.49s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Yellow card at 1018.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating clip 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley for Direct free-kick at 618.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#     Creating random clip ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
#   Processing match: 2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
#     Minimum clips per event: 1
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Goal at 2910.95s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Yellow card at 621.99s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating clip 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal for Direct free-kick at 1748.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#     Creating random clip ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
#   Processing match: 2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
#     Minimum clips per event: 1
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Goal at 1624.79s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Yellow card at 161.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating clip 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United for Direct free-kick at 2547.58s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#     Creating random clip ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
#   Processing match: 2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
#     Minimum clips per event: 1
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Goal at 1666.53s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Yellow card at 1071.78s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating clip 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool for Direct free-kick at 1443.21s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
#     Creating random clip ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing season: 2015-2014
#   Processing match: 2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
#     Minimum clips per event: 1
#     Creating clip 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Goal at 541.39s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Yellow card at 478.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating clip 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea for Direct free-kick at 72.79s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#     Creating random clip ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
#   Processing match: 2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
#     Minimum clips per event: 2
#     Creating clip 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 1170.28s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Goal at 2019.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1541.16s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Yellow card at 1622.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 827.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating clip 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace for Direct free-kick at 871.05s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#     Creating random clip ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
#   Processing match: 2015-08-29 - 17-00 Manchester City 2 - 0 Watford
#     Minimum clips per event: 1
#     Creating clip 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Goal at 85.44s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Yellow card at 1066.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating clip 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford for Direct free-kick at 490.69s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#     Creating random clip ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
#   Processing match: 2015-09-12 - 14-45 Everton 3 - 1 Chelsea
#     Minimum clips per event: 1
#     Creating clip 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Goal at 2212.88s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Yellow card at 1155.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating clip 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea for Direct free-kick at 2419.74s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#     Creating random clip ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
#   Processing match: 2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
#     Minimum clips per event: 1
#     Creating clip 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Goal at 2670.32s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Yellow card at 1418.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating clip 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City for Direct free-kick at 1853.24s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#     Creating random clip ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
#   Processing match: 2015-09-19 - 19-30 Manchester City 1 - 2 West Ham
#     Minimum clips per event: 0
#   Processing match: 2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa
#     Minimum clips per event: 0
#   Processing match: 2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
#     Minimum clips per event: 1
#     Creating clip 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Goal at 481.00s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Yellow card at 185.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating clip 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa for Direct free-kick at 788.11s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#     Creating random clip ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
#   Processing match: 2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
#     Minimum clips per event: 2
#     Creating clip 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 1713.32s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Goal at 2224.80s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 755.40s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Yellow card at 1138.76s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 346.63s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating clip 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool for Direct free-kick at 1180.92s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#     Creating random clip ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
#   Processing match: 2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
#     Minimum clips per event: 1
#     Creating clip 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Goal at 384.77s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Yellow card at 861.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating clip 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom for Direct free-kick at 1597.27s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#     Creating random clip ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
#   Processing match: 2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
#     Minimum clips per event: 1
#     Creating clip 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Goal at 2137.40s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Yellow card at 91.59s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating clip 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool for Direct free-kick at 389.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#     Creating random clip ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
#   Processing match: 2015-11-29 - 15-00 Tottenham 0 - 0 Chelsea
#     Minimum clips per event: 0
#   Processing match: 2015-12-05 - 20-30 Chelsea 0 - 1 Bournemouth
#     Minimum clips per event: 0
#   Processing match: 2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
#     Minimum clips per event: 2
#     Creating clip 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Goal at 252.44s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Goal at 415.32s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 159.68s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Yellow card at 978.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 412.75s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating clip 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland for Direct free-kick at 1014.65s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating random clip ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#     Creating random clip ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
#   Processing match: 2015-12-26 - 18-00 Manchester City 4 - 1 Sunderland
#     Minimum clips per event: 0
#   Processing match: 2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
#     Minimum clips per event: 2
#     Creating clip 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Goal at 885.68s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Goal at 1237.12s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Yellow card at 666.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Yellow card at 2053.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 441.18s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating clip 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea for Direct free-kick at 555.25s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating random clip ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#     Creating random clip ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
#   Processing match: 2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
#     Minimum clips per event: 2
#     Creating clip 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Goal at 1673.00s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Goal at 2395.68s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 217.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Yellow card at 1339.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 793.55s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating clip 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom for Direct free-kick at 1408.65s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#     Creating random clip ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
#   Processing match: 2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
#     Minimum clips per event: 2
#     Creating clip 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 900.64s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Goal at 2741.88s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 1054.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Yellow card at 2016.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2262.08s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating clip 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United for Direct free-kick at 2616.91s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#     Creating random clip ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
#   Processing match: 2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
#     Minimum clips per event: 3
#     Creating clip 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 473.40s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 1715.48s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Goal at 2259.20s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 0.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 50.47s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Yellow card at 610.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 191.17s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 654.84s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating clip 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham for Direct free-kick at 1175.56s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#     Creating random clip ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
#   Processing match: 2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
#     Minimum clips per event: 1
#     Creating clip 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Goal at 698.96s
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Goal\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Yellow card at 1318.00s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Yellow_card\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating clip 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City for Direct free-kick at 1779.23s
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\Direct_free-kick\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#     Creating random clip ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City
# Proc not detected
#     Successfully created F:/AIM Lab/Experiment\Multiclass-equal sizes\Clips\no_event\ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
#
# Processing complete!

# %% [markdown]
# ### Frame level Preprocessing

# %%
import os
import cv2
import numpy as np

def process_video(input_path, output_path):
    """
    Process the video to:
    1. Convert to grayscale.
    2. Remove grass and audience areas while preserving the ball.
    """
    # Load video
    cap = cv2.VideoCapture(input_path)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Changed to mp4v for better compatibility
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height), isColor=False)
    
    print(f"Processing {total_frames} frames from {input_path}...")
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % 100 == 0:
            print(f"Processed {frame_count}/{total_frames} frames")

        # Convert to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Convert original frame to HSV for better color detection
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

        # Define green grass color range in HSV (more specific range)
        lower_green = np.array([35, 40, 40])
        upper_green = np.array([85, 255, 255])
        grass_mask = cv2.inRange(hsv, lower_green, upper_green)

        # Define ball detection (white/light colored ball)
        lower_ball_hsv = np.array([0, 0, 200])
        upper_ball_hsv = np.array([180, 30, 255])
        ball_mask_hsv = cv2.inRange(hsv, lower_ball_hsv, upper_ball_hsv)
        
        _, ball_mask_gray = cv2.threshold(gray_frame, 200, 255, cv2.THRESH_BINARY)
        ball_mask = cv2.bitwise_or(ball_mask_hsv, ball_mask_gray)
        
        kernel = np.ones((3, 3), np.uint8)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_CLOSE, kernel)
        ball_mask = cv2.morphologyEx(ball_mask, cv2.MORPH_OPEN, kernel)

        lower_audience = np.array([0, 100, 150])
        upper_audience = np.array([180, 255, 255])
        audience_mask = cv2.inRange(hsv, lower_audience, upper_audience)
        audience_mask = cv2.bitwise_and(audience_mask, cv2.bitwise_not(ball_mask))

        combined_mask = cv2.bitwise_or(grass_mask, audience_mask)
        keep_mask = cv2.bitwise_not(combined_mask)
        keep_mask = cv2.bitwise_or(keep_mask, ball_mask)

        processed_frame = cv2.bitwise_and(gray_frame, gray_frame, mask=keep_mask)
        out.write(processed_frame)
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Processed video saved as: {output_path}")

def process_all_videos(input_folder, output_folder):
    """
    Process all videos in the input folder and save them to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to the folder to save processed videos.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for video_file in os.listdir(input_folder):
        input_path = os.path.join(input_folder, video_file)
        output_path = os.path.join(output_folder, video_file)
        
        if os.path.isfile(input_path) and video_file.endswith(".mp4"):
            process_video(input_path, output_path)

def process_all_events(base_input_path, base_output_path, event_types):
    """
    Process all event folders and save processed videos to respective folders.
    
    Args:
        base_input_path (str): Path to the base input folder containing event folders.
        base_output_path (str): Path to the base output folder to save processed videos.
        event_types (list): List of event types to process.
    """
    for event in event_types:
        input_folder = os.path.join(base_input_path, event.replace(" ", "_"))
        output_folder = os.path.join(base_output_path, event.replace(" ", "_"))
        
        if os.path.exists(input_folder):
            print(f"Processing videos for event: {event}")
            process_all_videos(input_folder, output_folder)
        else:
            print(f"Input folder not found for event: {event}")

if __name__ == "__main__":
    # Define input and output base paths
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed"
    
    # List of event types to process
    event_types = ["Goal", "Yellow card", "Direct free-kick", "no_event"]
    
    # Process all events
    process_all_events(base_input_path, base_output_path, event_types)
# Out:
# Processing videos for event: Goal
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Goal\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing videos for event: Yellow card
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 100 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/100 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Yellow_card\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing videos for event: Direct free-kick
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\Direct_free-kick\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Processing videos for event: no_event
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Processing 175 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips\no_event\ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4...
# Processed 100/175 frames
# Processed video saved as: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\no_event\ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4

# %% [markdown]
# ### splitting into train and test folders

# %%
import os
import shutil
import random

def split_videos(base_path, event_types, train_ratio=20, test_ratio=7):
    """
    Split videos into train and test subfolders for each event type.
    
    Args:
        base_path (str): Path to the base folder containing event folders.
        event_types (list): List of event types to process.
        train_ratio (int): Number of videos to place in the train folder.
        test_ratio (int): Number of videos to place in the test folder.
    """
    for event in event_types:
        event_folder = os.path.join(base_path, event.replace(" ", "_"))
        train_folder = os.path.join(event_folder, "train")
        test_folder = os.path.join(event_folder, "test")
        
        # Create train and test subfolders if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)
        
        # Get all video files in the event folder
        video_files = [f for f in os.listdir(event_folder) if f.endswith(".mp4")]
        
        # Shuffle the video files to ensure randomness
        random.shuffle(video_files)
        
        # Split videos into train and test sets
        train_videos = video_files[:train_ratio]
        test_videos = video_files[train_ratio:train_ratio + test_ratio]
        
        # Move videos to train folder
        for video in train_videos:
            src_path = os.path.join(event_folder, video)
            dest_path = os.path.join(train_folder, video)
            shutil.move(src_path, dest_path)
        
        # Move videos to test folder
        for video in test_videos:
            src_path = os.path.join(event_folder, video)
            dest_path = os.path.join(test_folder, video)
            shutil.move(src_path, dest_path)
        
        print(f"Event: {event}")
        print(f"  Train videos: {len(train_videos)}")
        print(f"  Test videos: {len(test_videos)}")

if __name__ == "__main__":
    # Define base paths for Clips and Features-processed
    base_paths = [
        "F:/AIM Lab/Experiment/Multiclass-equal sizes/Clips",
        "F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed"
    ]
    
    # List of event types
    event_types = ["Goal", "Direct free-kick", "no_event", "Yellow card"]
    
    # Split videos in both base paths
    for base_path in base_paths:
        split_videos(base_path, event_types)
# Out:
# Event: Goal
#   Train videos: 20
#   Test videos: 7
# Event: Direct free-kick
#   Train videos: 20
#   Test videos: 7
# Event: no_event
#   Train videos: 20
#   Test videos: 7
# Event: Yellow card
#   Train videos: 20
#   Test videos: 7
# Event: Goal
#   Train videos: 20
#   Test videos: 7
# Event: Direct free-kick
#   Train videos: 20
#   Test videos: 7
# Event: no_event
#   Train videos: 20
#   Test videos: 7
# Event: Yellow card
#   Train videos: 20
#   Test videos: 7

# %%
import os
import cv2
import numpy as np
import torch
import torchvision
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# Load ResNet-50 model
model = torchvision.models.resnet50(pretrained=True)
model.fc = torch.nn.Identity()  # Remove the final classifier to get 2048-d features
model.eval()  # Set the model to evaluation mode

# Preprocessing pipeline for frames
preprocess = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),                    # H×W×C → C×H×W, [0,1]
    torchvision.transforms.Normalize(mean=[.485, .456, .406], std=[.229, .224, .225]),
    torchvision.transforms.Resize((224, 224)),
])

def embed_clip(frames: List[np.ndarray]):
    """
    Generate ResNet-50 embeddings for a list of frames.
    
    Args:
        frames (List[np.ndarray]): List of frames (H×W×C, BGR format).
    
    Returns:
        np.ndarray: N×2048 array of frame embeddings.
    """
    feats = []
    for frame in frames:
        # Convert BGR (OpenCV) to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        x = preprocess(frame_rgb).unsqueeze(0)  # 1×3×224×224
        with torch.no_grad():
            f = model(x)  # 1×2048
        feats.append(f.squeeze(0).cpu().numpy())
    return np.stack(feats, axis=0)  # N×2048

def sample_frames_from_video(video_path, num_samples=16):
    """
    Uniformly sample num_samples frames from the video at video_path.
    Returns a list of BGR frames (as numpy arrays).
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        # If fewer frames than samples, just read them all
        indices = list(range(total_frames))
    else:
        # Uniformly spaced frame indices
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    cap.release()

    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    return frames

def process_folder(input_folder, output_folder, num_samples=16):
    """
    Process videos in a folder, generate mean-pooled ResNet-50 embeddings for sampled frames,
    and save the embeddings to the output folder.
    
    Args:
        input_folder (str): Path to the folder containing input videos.
        output_folder (str): Path to save embeddings.
        num_samples (int): Number of frames to sample per video.
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        frames = sample_frames_from_video(video_path, num_samples=num_samples)
        if frames:
            # Generate embeddings and mean-pool them
            embeddings = embed_clip(frames)
            clip_vec = np.mean(embeddings, axis=0)  # Mean-pool → (2048,)
            
            # Save the embedding as a .npy file
            output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
            np.save(output_path, clip_vec)
            print(f"Saved embedding to {output_path}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes(embeddings_base_path, event_classes):
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary of prototypes for each event class.
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_multiclass_classification(embeddings_base_path, prototypes, event_classes):
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with ResNet-50")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event"]
    
    # Step 1: Generate embeddings for all videos
    print("\nStep 1: Generating ResNet-50 embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, num_samples=16)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data
    print("\nStep 3: Evaluating classification performance...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*50}")
    print("FINAL RESULTS")
    print(f"{'='*50}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Multiclass Few-Shot Learning with ResNet-50
# ==================================================
#
# Step 1: Generating ResNet-50 embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#
# Processing Direct_free-kick - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#
# Processing Direct_free-kick - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 100
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\Yellow_card\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 16 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# ...
# Saved embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings\no_event\Test\ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#
# Step 2: Building prototypes from training data...
# Loading training embeddings for Goal...
#   Loaded 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (2048,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (2048,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (2048,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (2048,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (2048,))
#   Loaded 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (2048,))
#   Loaded 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (2048,))
#   Loaded 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (2048,))
#   Loaded 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (2048,))
# Built prototype for Goal from 20 samples
# Loading training embeddings for Direct_free-kick...
#   Loaded 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (2048,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (2048,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (2048,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (2048,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (2048,))
#   Loaded 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (2048,))
#   Loaded 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (2048,))
#   Loaded 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (2048,))
# Built prototype for Direct_free-kick from 20 samples
# Loading training embeddings for Yellow_card...
#   Loaded 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (2048,))
#   Loaded 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (2048,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (2048,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (2048,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (2048,))
#   Loaded 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (2048,))
#   Loaded 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (2048,))
#   Loaded 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (2048,))
#   Loaded 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (2048,))
# Built prototype for Yellow_card from 20 samples
# Loading training embeddings for no_event...
#   Loaded ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (2048,))
#   Loaded ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (2048,))
#   Loaded ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (2048,))
#   Loaded ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (2048,))
#   Loaded ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (2048,))
#   Loaded ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (2048,))
#   Loaded ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (2048,))
#   Loaded ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (2048,))
#   Loaded ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (2048,))
#   Loaded ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (2048,))
#   Loaded ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (2048,))
#   Loaded ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (2048,))
#   Loaded ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (2048,))
#   Loaded ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (2048,))
#   Loaded ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (2048,))
# Built prototype for no_event from 20 samples
# Successfully built prototypes for 4 classes:
#   Goal: shape (2048,)
#   Direct_free-kick: shape (2048,)
#   Yellow_card: shape (2048,)
#   no_event: shape (2048,)
#
# Step 3: Evaluating classification performance...
#
# ============================================================
# EVALUATING MULTICLASS CLASSIFICATION
# ============================================================
#
# Testing Goal clips...
#   File: 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9517135, 'Direct_free-kick': 0.9470072, 'Yellow_card': 0.9064804, 'no_event': 0.94152045}
#   File: 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.97315633, 'Direct_free-kick': 0.9586269, 'Yellow_card': 0.9321983, 'no_event': 0.96533155}
#   File: 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.96695113, 'Direct_free-kick': 0.9483927, 'Yellow_card': 0.93048805, 'no_event': 0.9576084}
#   File: 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9409866, 'Direct_free-kick': 0.9415263, 'Yellow_card': 0.90821314, 'no_event': 0.9360132}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.94926155, 'Direct_free-kick': 0.94500065, 'Yellow_card': 0.8943733, 'no_event': 0.9307959}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.93361735, 'Direct_free-kick': 0.94710356, 'Yellow_card': 0.87053907, 'no_event': 0.9134517}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.97288084, 'Direct_free-kick': 0.9581177, 'Yellow_card': 0.92453146, 'no_event': 0.95904064}
#
# Testing Direct_free-kick clips...
#   File: 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9401752, 'Direct_free-kick': 0.94976133, 'Yellow_card': 0.8604833, 'no_event': 0.90771484}
#   File: 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9181441, 'Direct_free-kick': 0.9514823, 'Yellow_card': 0.8405962, 'no_event': 0.90045714}
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9508764, 'Direct_free-kick': 0.91736686, 'Yellow_card': 0.9167892, 'no_event': 0.93513644}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9656009, 'Direct_free-kick': 0.9609878, 'Yellow_card': 0.9274661, 'no_event': 0.9529201}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9405335, 'Direct_free-kick': 0.9465157, 'Yellow_card': 0.86165774, 'no_event': 0.9088673}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9483204, 'Direct_free-kick': 0.9397536, 'Yellow_card': 0.9344612, 'no_event': 0.94882023}
#   File: 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.959533, 'Direct_free-kick': 0.95934325, 'Yellow_card': 0.9242923, 'no_event': 0.95211405}
#
# Testing Yellow_card clips...
#   File: 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8861003, 'Direct_free-kick': 0.84957325, 'Yellow_card': 0.96254647, 'no_event': 0.9210603}
#   File: 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.9311464, 'Direct_free-kick': 0.8985745, 'Yellow_card': 0.95508444, 'no_event': 0.95318127}
#   File: 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.90590096, 'Direct_free-kick': 0.8540091, 'Yellow_card': 0.95978284, 'no_event': 0.9309373}
#   File: 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8776187, 'Direct_free-kick': 0.8271664, 'Yellow_card': 0.9180014, 'no_event': 0.90038455}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.90496933, 'Direct_free-kick': 0.8524826, 'Yellow_card': 0.9562835, 'no_event': 0.93485653}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8568642, 'Direct_free-kick': 0.8087856, 'Yellow_card': 0.93738395, 'no_event': 0.89152634}
#   File: 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.88344103, 'Direct_free-kick': 0.8344188, 'Yellow_card': 0.946733, 'no_event': 0.90771633}
#
# Testing no_event clips...
#   File: ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9247285, 'Direct_free-kick': 0.92517257, 'Yellow_card': 0.9149401, 'no_event': 0.9477016}
#   File: ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9192424, 'Direct_free-kick': 0.9302308, 'Yellow_card': 0.8799952, 'no_event': 0.92624426}
#   File: ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8690948, 'Direct_free-kick': 0.82265383, 'Yellow_card': 0.92141026, 'no_event': 0.8927181}
#   File: ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.93371844, 'Direct_free-kick': 0.9022331, 'Yellow_card': 0.9517, 'no_event': 0.9455178}
#   File: ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9455639, 'Direct_free-kick': 0.9165976, 'Yellow_card': 0.9603639, 'no_event': 0.9568354}
#   File: ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8660438, 'Direct_free-kick': 0.8158488, 'Yellow_card': 0.88128096, 'no_event': 0.88284636}
#   File: ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9132301, 'Direct_free-kick': 0.91832185, 'Yellow_card': 0.8771496, 'no_event': 0.91098094}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.6071
# Weighted Precision: 0.6051
# Weighted Recall: 0.6071
# Weighted F₁ Score: 0.5797
#
# Per-class Accuracy:
#   Goal: 0.7143 (5/7)
#   Direct_free-kick: 0.4286 (3/7)
#   Yellow_card: 1.0000 (7/7)
#   no_event: 0.2857 (2/7)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event']
# [[5 2 0 0]
#  [3 3 0 1]
#  [0 0 7 0]
#  [0 2 3 2]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.62      0.71      0.67         7
# Direct_free-kick       0.43      0.43      0.43         7
#      Yellow_card       0.70      1.00      0.82         7
#         no_event       0.67      0.29      0.40         7
#
#         accuracy                           0.61        28
#        macro avg       0.61      0.61      0.58        28
#     weighted avg       0.61      0.61      0.58        28
#
#
# Step 4: Additional Analysis...
# Total test samples: 28
# Number of classes: 4
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 2 times
#   Direct_free-kick → Goal: 3 times
#   Direct_free-kick → no_event: 1 times
#   no_event → Direct_free-kick: 2 times
#   no_event → Yellow_card: 3 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.6071
# Weighted Precision: 0.6051
# Weighted Recall: 0.6071
# Weighted F₁ Score: 0.5797
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms
from torchvision.models.video import r2plus1d_18
from typing import List, Dict
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

class R2Plus1DFeatureExtractor:
    def __init__(self, device='cuda' if torch.cuda.is_available() else 'cpu'):
        """
        Initialize R(2+1)D model for feature extraction.
        
        Args:
            device: Device to run the model on
        """
        self.device = device
        
        # Initialize R(2+1)D model
        self.model = r2plus1d_18(pretrained=True)
        
        # Remove the final classification layer to get features
        self.model.fc = torch.nn.Identity()
        self.model.to(device)
        self.model.eval()
        
        # Preprocessing transforms
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((112, 112)),  # R(2+1)D typically uses 112x112
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.43216, 0.394666, 0.37645], 
                               std=[0.22803, 0.22145, 0.216989])  # Kinetics normalization
        ])
    
    def preprocess_frames(self, frames: List[np.ndarray], num_frames: int = 16) -> torch.Tensor:
        """
        Preprocess frames for R(2+1)D input.
        
        Args:
            frames: List of frames (H×W×C, BGR format)
            num_frames: Number of frames to use for R(2+1)D
            
        Returns:
            Preprocessed tensor of shape (1, 3, num_frames, H, W)
        """
        # Sample frames uniformly if we have more than needed
        if len(frames) > num_frames:
            indices = np.linspace(0, len(frames) - 1, num_frames, dtype=int)
            frames = [frames[i] for i in indices]
        elif len(frames) < num_frames:
            # Repeat last frame if we don't have enough
            while len(frames) < num_frames:
                frames.append(frames[-1])
        
        # Convert frames and apply transforms
        processed_frames = []
        for frame in frames:
            # Convert BGR to RGB
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Apply transforms
            frame_tensor = self.transform(frame_rgb)
            processed_frames.append(frame_tensor)
        
        # Stack frames: (num_frames, 3, H, W) -> (3, num_frames, H, W)
        video_tensor = torch.stack(processed_frames, dim=1)  # (3, num_frames, H, W)
        video_tensor = video_tensor.unsqueeze(0)  # Add batch dimension
        
        return video_tensor
    
    def extract_features(self, frames: List[np.ndarray]) -> np.ndarray:
        """
        Extract R(2+1)D features from video frames.
        
        Args:
            frames: List of video frames
            
        Returns:
            Feature vector of shape (512,) for R(2+1)D-18
        """
        # Preprocess frames
        video_tensor = self.preprocess_frames(frames)
        video_tensor = video_tensor.to(self.device)
        
        # Extract features
        with torch.no_grad():
            features = self.model(video_tensor)
            # Global average pooling if needed
            if len(features.shape) > 2:
                features = F.adaptive_avg_pool3d(features, 1).squeeze()
            else:
                features = features.squeeze()
        
        return features.cpu().numpy()

def sample_frames_from_video(video_path: str, num_samples: int = 32) -> List[np.ndarray]:
    """
    Uniformly sample frames from a video.
    
    Args:
        video_path: Path to video file
        num_samples: Number of frames to sample
        
    Returns:
        List of sampled frames
    """
    print(f"Opening video: {video_path}")
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {video_path}")
        return []

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in video: {total_frames}")
    
    if total_frames == 0:
        print(f"Error: No frames found in video {video_path}")
        return []

    if total_frames < num_samples:
        indices = list(range(total_frames))
    else:
        indices = np.linspace(0, total_frames - 1, num=num_samples, dtype=int)

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if not ret:
            print(f"Warning: Failed to read frame {idx} from {video_path}")
            continue
        frames.append(frame)
    
    cap.release()
    
    if not frames:
        print(f"Error: No frames sampled from video {video_path}")
    else:
        print(f"Successfully sampled {len(frames)} frames from {video_path}")
    
    return frames

def process_folder(input_folder: str, output_folder: str, 
                  feature_extractor: R2Plus1DFeatureExtractor,
                  num_frames: int = 32):
    """
    Process all videos in a folder and generate R(2+1)D embeddings.
    
    Args:
        input_folder: Folder containing input videos
        output_folder: Folder to save embeddings
        feature_extractor: R(2+1)D feature extractor instance
        num_frames: Number of frames to use for each video
    """
    print(f"Processing folder: {input_folder}")
    if not os.path.exists(input_folder):
        print(f"Error: Folder does not exist: {input_folder}")
        return

    os.makedirs(output_folder, exist_ok=True)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.mp4'):
            print(f"Skipping non-video file: {fname}")
            continue
        
        video_path = os.path.join(input_folder, fname)
        print(f"Processing video: {video_path}")
        
        # Sample frames from video
        frames = sample_frames_from_video(video_path, num_samples=num_frames)
        
        if frames:
            # Extract R(2+1)D features
            try:
                features = feature_extractor.extract_features(frames)
                
                # Save the embedding as a .npy file
                output_path = os.path.join(output_folder, f"{os.path.splitext(fname)[0]}.npy")
                np.save(output_path, features)
                print(f"Saved R(2+1)D embedding to {output_path} (shape: {features.shape})")
                
            except Exception as e:
                print(f"Error processing {fname}: {e}")
        else:
            print(f"Error: No frames sampled from {fname}")

def l2_normalize(vec: np.ndarray) -> np.ndarray:
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec: Input vector
        
    Returns:
        L2-normalized vector
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def cosine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    """
    Compute cosine similarity between two vectors.
    
    Args:
        vec1: First vector
        vec2: Second vector
        
    Returns:
        Cosine similarity value
    """
    # Normalize vectors
    vec1_norm = l2_normalize(vec1)
    vec2_norm = l2_normalize(vec2)
    
    # Compute cosine similarity
    return np.dot(vec1_norm, vec2_norm)

def build_prototypes(embeddings_base_path: str, event_classes: List[str]) -> Dict[str, np.ndarray]:
    """
    Build prototypes for each event class from training embeddings.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        event_classes: List of event class names
        
    Returns:
        Dictionary of prototypes for each event class
    """
    prototypes = {}
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Training folder not found for {event}")
            continue
            
        event_vecs = []
        print(f"Loading training embeddings for {event}...")
        
        # Load embeddings for the event
        for fname in os.listdir(event_train_folder):
            if fname.endswith(".npy"):
                vec = np.load(os.path.join(event_train_folder, fname))
                event_vecs.append(vec)
                print(f"  Loaded {fname} (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes

def classify_clip(clip_embedding: np.ndarray, prototypes: Dict[str, np.ndarray]) -> tuple:
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding: Embedding vector of the clip
        prototypes: Dictionary of prototypes for each event class
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = cosine_similarity(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_multiclass_classification(embeddings_base_path: str, 
                                     prototypes: Dict[str, np.ndarray], 
                                     event_classes: List[str],
                                     threshold: float = 0.0) -> dict:
    """
    Evaluate multiclass classification performance on test data.
    
    Args:
        embeddings_base_path: Base path to embeddings folders
        prototypes: Dictionary of prototypes for each event class
        event_classes: List of event class names
        threshold: Decision threshold (not used in multiclass, kept for compatibility)
    
    Returns:
        Dictionary containing evaluation results
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes}
    }
    
    print("\n" + "="*60)
    print("EVALUATING MULTICLASS CLASSIFICATION")
    print("="*60)
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        print(f"\nTesting {event} clips...")
        
        for fname in os.listdir(event_test_folder):
            if fname.endswith(".npy"):
                test_embedding = np.load(os.path.join(event_test_folder, fname))
                predicted_label, similarities = classify_clip(test_embedding, prototypes)
                
                is_correct = predicted_label == event
                results['class_counts'][event]['total'] += 1
                
                if is_correct:
                    results['class_counts'][event]['correct'] += 1
                
                # Store for sklearn metrics
                y_true.append(event)
                y_pred.append(predicted_label)
                
                # Store detailed results
                result_entry = {
                    'file': fname,
                    'true_label': event,
                    'predicted_label': predicted_label,
                    'correct': is_correct,
                    'similarities': similarities
                }
                results['predictions'].append(result_entry)
                
                # Print results
                print(f"  File: {fname}")
                print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
                print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred
    })
    
    return results

def main():
    """
    Main function to run R(2+1)D-based multiclass few-shot learning classification.
    """
    print("Multiclass Few-Shot Learning with R(2+1)D")
    print("="*50)
    
    # Configuration
    base_input_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed"
    base_output_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings"
    
    # Event classes (using underscores to match folder names)
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event"]
    
    # Initialize R(2+1)D feature extractor
    print("Initializing R(2+1)D feature extractor...")
    feature_extractor = R2Plus1DFeatureExtractor()
    
    # Step 1: Generate R(2+1)D embeddings for all videos
    print("\nStep 1: Generating R(2+1)D embeddings...")
    for event in event_classes:
        for split in ["Train", "Test"]:
            input_folder = os.path.join(base_input_path, event, split)
            output_folder = os.path.join(base_output_path, event, split)
            
            print(f"\nProcessing {event} - {split}...")
            process_folder(input_folder, output_folder, feature_extractor, num_frames=32)
    
    # Step 2: Build prototypes from training embeddings
    print("\nStep 2: Building prototypes from training data...")
    prototypes = build_prototypes(base_output_path, event_classes)
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"Successfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    # Step 3: Evaluate on test data with threshold 0.0
    print("\nStep 3: Evaluating classification performance with threshold 0.0...")
    results = evaluate_multiclass_classification(base_output_path, prototypes, event_classes, threshold=0.0)
    
    # Step 4: Additional analysis
    print(f"\nStep 4: Additional Analysis...")
    print(f"Total test samples: {len(results['y_true'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*50}")
    print("FINAL RESULTS")
    print(f"{'='*50}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*50}")
    print("MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*50}")

if __name__ == "__main__":
    main()
# Out:
# Multiclass Few-Shot Learning with R(2+1)D
# ==================================================
# Initializing R(2+1)D feature extractor...
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R2Plus1D_18_Weights.KINETICS400_V1`. You can also use `weights=R2Plus1D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Step 1: Generating R(2+1)D embeddings...
#
# Processing Goal - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
#
# Processing Goal - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Goal\Test\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#
# Processing Direct_free-kick - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Train\9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
#
# Processing Direct_free-kick - Test...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Direct_free-kick\Test\8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#
# Processing Yellow_card - Train...
# Processing folder: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Opening video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Total frames in video: 175
# Successfully sampled 32 frames from F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.mp4
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\Yellow_card\Train\23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
# Processing video: F:/AIM Lab/Experiment/Multiclass-equal sizes/Features-processed\Yellow_card\Train\24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.mp4
# ...
# Saved R(2+1)D embedding to F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings\no_event\Test\ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#
# Step 2: Building prototypes from training data...
# Loading training embeddings for Goal...
#   Loaded 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
#   Loaded 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
#   Loaded 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#   Loaded 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
#   Loaded 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Built prototype for Goal from 20 samples
# Loading training embeddings for Direct_free-kick...
#   Loaded 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy (shape: (512,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
#   Loaded 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
#   Loaded 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#   Loaded 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Built prototype for Direct_free-kick from 20 samples
# Loading training embeddings for Yellow_card...
#   Loaded 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy (shape: (512,))
#   Loaded 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
#   Loaded 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
#   Loaded 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#   Loaded 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy (shape: (512,))
#   Loaded 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
#   Loaded 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy (shape: (512,))
#   Loaded 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#   Loaded 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy (shape: (512,))
# Built prototype for Yellow_card from 20 samples
# Loading training embeddings for no_event...
#   Loaded ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy (shape: (512,))
#   Loaded ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy (shape: (512,))
#   Loaded ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy (shape: (512,))
#   Loaded ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy (shape: (512,))
#   Loaded ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy (shape: (512,))
#   Loaded ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy (shape: (512,))
#   Loaded ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy (shape: (512,))
#   Loaded ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded ng23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy (shape: (512,))
#   Loaded ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy (shape: (512,))
#   Loaded ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy (shape: (512,))
#   Loaded ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy (shape: (512,))
#   Loaded ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy (shape: (512,))
#   Loaded ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#   Loaded ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy (shape: (512,))
#   Loaded ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy (shape: (512,))
# Built prototype for no_event from 20 samples
# Successfully built prototypes for 4 classes:
#   Goal: shape (512,)
#   Direct_free-kick: shape (512,)
#   Yellow_card: shape (512,)
#   no_event: shape (512,)
#
# Step 3: Evaluating classification performance with threshold 0.0...
#
# ============================================================
# EVALUATING MULTICLASS CLASSIFICATION
# ============================================================
#
# Testing Goal clips...
#   File: 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9486758, 'Direct_free-kick': 0.9358238, 'Yellow_card': 0.8483639, 'no_event': 0.9165994}
#   File: 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9150181, 'Direct_free-kick': 0.8954091, 'Yellow_card': 0.86630344, 'no_event': 0.917127}
#   File: 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9120594, 'Direct_free-kick': 0.8561755, 'Yellow_card': 0.9209038, 'no_event': 0.9228271}
#   File: 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.8986625, 'Direct_free-kick': 0.8892395, 'Yellow_card': 0.80529165, 'no_event': 0.8616938}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9311066, 'Direct_free-kick': 0.9129294, 'Yellow_card': 0.8448575, 'no_event': 0.9017532}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8996966, 'Direct_free-kick': 0.9071175, 'Yellow_card': 0.84074175, 'no_event': 0.8798152}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9553309, 'Direct_free-kick': 0.9257604, 'Yellow_card': 0.88934326, 'no_event': 0.9381536}
#
# Testing Direct_free-kick clips...
#   File: 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9220407, 'Direct_free-kick': 0.93445015, 'Yellow_card': 0.8115033, 'no_event': 0.87998044}
#   File: 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.88715994, 'Direct_free-kick': 0.91840875, 'Yellow_card': 0.7906108, 'no_event': 0.8595185}
#   File: 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.8840506, 'Direct_free-kick': 0.84361655, 'Yellow_card': 0.8470186, 'no_event': 0.89067686}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9176898, 'Direct_free-kick': 0.9316355, 'Yellow_card': 0.84879607, 'no_event': 0.90069866}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9139602, 'Direct_free-kick': 0.9268676, 'Yellow_card': 0.8166619, 'no_event': 0.87948155}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.869882, 'Direct_free-kick': 0.86507976, 'Yellow_card': 0.8649147, 'no_event': 0.88493055}
#   File: 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.87715816, 'Direct_free-kick': 0.8645804, 'Yellow_card': 0.87674, 'no_event': 0.8989896}
#
# Testing Yellow_card clips...
#   File: 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7467501, 'Direct_free-kick': 0.7138591, 'Yellow_card': 0.8787569, 'no_event': 0.8016789}
#   File: 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8429947, 'Direct_free-kick': 0.7880048, 'Yellow_card': 0.9262531, 'no_event': 0.89966744}
#   File: 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.76952946, 'Direct_free-kick': 0.71569955, 'Yellow_card': 0.9034202, 'no_event': 0.8429284}
#   File: 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7770355, 'Direct_free-kick': 0.73078847, 'Yellow_card': 0.85212564, 'no_event': 0.8413099}
#   File: 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.74645066, 'Direct_free-kick': 0.69705015, 'Yellow_card': 0.8627364, 'no_event': 0.8194479}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7361584, 'Direct_free-kick': 0.693738, 'Yellow_card': 0.88780254, 'no_event': 0.8158437}
#   File: 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.7411516, 'Direct_free-kick': 0.69927764, 'Yellow_card': 0.85893893, 'no_event': 0.8105439}
#
# Testing no_event clips...
#   File: ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.87807447, 'Direct_free-kick': 0.86363405, 'Yellow_card': 0.8604989, 'no_event': 0.8833646}
#   File: ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8496506, 'Direct_free-kick': 0.876769, 'Yellow_card': 0.73622435, 'no_event': 0.82535475}
#   File: ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.78072435, 'Direct_free-kick': 0.7424398, 'Yellow_card': 0.8692732, 'no_event': 0.8262139}
#   File: ng26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.87376815, 'Direct_free-kick': 0.84543157, 'Yellow_card': 0.8874516, 'no_event': 0.88686407}
#   File: ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91175246, 'Direct_free-kick': 0.8750843, 'Yellow_card': 0.8421368, 'no_event': 0.88405776}
#   File: ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8394261, 'Direct_free-kick': 0.78417933, 'Yellow_card': 0.86031425, 'no_event': 0.8780452}
#   File: ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8340713, 'Direct_free-kick': 0.8764463, 'Yellow_card': 0.74496037, 'no_event': 0.81917876}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.6071
# Weighted Precision: 0.6087
# Weighted Recall: 0.6071
# Weighted F₁ Score: 0.5997
#
# Per-class Accuracy:
#   Goal: 0.5714 (4/7)
#   Direct_free-kick: 0.5714 (4/7)
#   Yellow_card: 1.0000 (7/7)
#   no_event: 0.2857 (2/7)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event']
# [[4 1 0 2]
#  [0 4 0 3]
#  [0 0 7 0]
#  [1 2 2 2]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.80      0.57      0.67         7
# Direct_free-kick       0.57      0.57      0.57         7
#      Yellow_card       0.78      1.00      0.88         7
#         no_event       0.29      0.29      0.29         7
#
#         accuracy                           0.61        28
#        macro avg       0.61      0.61      0.60        28
#     weighted avg       0.61      0.61      0.60        28
#
#
# Step 4: Additional Analysis...
# Total test samples: 28
# Number of classes: 4
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 1 times
#   Goal → no_event: 2 times
#   Direct_free-kick → no_event: 3 times
#   no_event → Goal: 1 times
#   no_event → Direct_free-kick: 2 times
#   no_event → Yellow_card: 2 times
#
# ==================================================
# FINAL RESULTS
# ==================================================
# Overall Accuracy: 0.6071
# Weighted Precision: 0.6087
# Weighted Recall: 0.6071
# Weighted F₁ Score: 0.5997
#
# ==================================================
# MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ==================================================

# %% [markdown]
# ## 5 for prototype and 12 for evaluation

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, num_prototype_samples=5):
    """
    Build prototypes for each event class from randomly selected test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        num_prototype_samples (int): Number of random samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_prototype_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for prototype")
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, num_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} random test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples=12):
    """
    Evaluate classification performance on a random subset of training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        num_eval_samples (int): Number of random samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON {num_eval_samples} RANDOM TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_eval_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for evaluation")
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, num_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from random 5 test samples,
    and evaluates on 12 random training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Random Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/Resnet-50 embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event"]
    
    # Number of test samples to use for prototype creation
    num_prototype_samples = 5
    
    # Number of training samples to evaluate per class
    num_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from random subset of test embeddings
    print(f"\nStep 1: Building prototypes from {num_prototype_samples} random test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, num_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on random training samples
    print(f"\nStep 2: Evaluating classification performance on {num_eval_samples} random training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Random Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 20 embeddings in Goal/Train
#   Found 7 embeddings in Goal/Test
#   Found 20 embeddings in Direct_free-kick/Train
#   Found 7 embeddings in Direct_free-kick/Test
#   Found 20 embeddings in Yellow_card/Train
#   Found 7 embeddings in Yellow_card/Test
#   Found 20 embeddings in no_event/Train
#   Found 7 embeddings in no_event/Test
#
# Step 1: Building prototypes from 5 random test samples per class...
# Loading 5 random test embeddings for Goal prototype...
#   Selected 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (2048,))
#   Selected 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (2048,))
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (2048,))
#   Selected 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
#   Selected 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (2048,))
# Built prototype for Goal from 5 test samples
# Loading 5 random test embeddings for Direct_free-kick prototype...
#   Selected 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (2048,))
#   Selected 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
#   Selected 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (2048,))
#   Selected 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (2048,))
#   Selected 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy for prototype (shape: (2048,))
# Built prototype for Direct_free-kick from 5 test samples
# Loading 5 random test embeddings for Yellow_card prototype...
#   Selected 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (2048,))
#   Selected 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy for prototype (shape: (2048,))
#   Selected 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (2048,))
#   Selected 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy for prototype (shape: (2048,))
#   Selected 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (2048,))
# Built prototype for Yellow_card from 5 test samples
# Loading 5 random test embeddings for no_event prototype...
#   Selected ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (2048,))
#   Selected ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (2048,))
#   Selected ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (2048,))
#   Selected ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (2048,))
#   Selected ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy for prototype (shape: (2048,))
# Built prototype for no_event from 5 test samples
#
# Successfully built prototypes for 4 classes:
#   Goal: shape (2048,)
#   Direct_free-kick: shape (2048,)
#   Yellow_card: shape (2048,)
#   no_event: shape (2048,)
#
# Files used for prototype creation:
#   Goal: ['13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', '6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy']
#   Direct_free-kick: ['2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy', '7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy', '13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy']
#   Yellow_card: ['7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy', '9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy', '27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy', '3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy']
#   no_event: ['ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy', 'ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy', 'ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy', 'ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', 'ng8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy']
#
# Step 2: Evaluating classification performance on 12 random training samples per class...
#
# ============================================================
# EVALUATING ON 12 RANDOM TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9612973, 'Direct_free-kick': 0.9530822, 'Yellow_card': 0.90556407, 'no_event': 0.95275795}
#   File: 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9787804, 'Direct_free-kick': 0.9622824, 'Yellow_card': 0.8983309, 'no_event': 0.945362}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9651737, 'Direct_free-kick': 0.9542217, 'Yellow_card': 0.8340727, 'no_event': 0.9163998}
#   File: 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9570903, 'Direct_free-kick': 0.96346396, 'Yellow_card': 0.8759416, 'no_event': 0.92205286}
#   File: 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9532666, 'Direct_free-kick': 0.9567883, 'Yellow_card': 0.9026608, 'no_event': 0.92664135}
#   File: 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9663528, 'Direct_free-kick': 0.94544905, 'Yellow_card': 0.88600105, 'no_event': 0.9515028}
#   File: 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9437704, 'Direct_free-kick': 0.9509048, 'Yellow_card': 0.90138924, 'no_event': 0.9347874}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9622762, 'Direct_free-kick': 0.9563446, 'Yellow_card': 0.93899477, 'no_event': 0.9544285}
#   File: 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9330245, 'Direct_free-kick': 0.94243634, 'Yellow_card': 0.91862744, 'no_event': 0.9385388}
#   File: 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9696839, 'Direct_free-kick': 0.9679194, 'Yellow_card': 0.89422464, 'no_event': 0.9449639}
#   File: 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9507987, 'Direct_free-kick': 0.9616351, 'Yellow_card': 0.8727026, 'no_event': 0.9171639}
#   File: 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9537623, 'Direct_free-kick': 0.9432547, 'Yellow_card': 0.90593195, 'no_event': 0.9416652}
#
# Testing Direct_free-kick training clips...
#   File: 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.93471396, 'Direct_free-kick': 0.94038785, 'Yellow_card': 0.8701924, 'no_event': 0.9244813}
#   File: 23_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9572902, 'Direct_free-kick': 0.9494666, 'Yellow_card': 0.8492881, 'no_event': 0.91022325}
#   File: 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9139983, 'Direct_free-kick': 0.9418187, 'Yellow_card': 0.81628454, 'no_event': 0.8705234}
#   File: 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9425813, 'Direct_free-kick': 0.9476577, 'Yellow_card': 0.84238416, 'no_event': 0.911664}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9532852, 'Direct_free-kick': 0.94948477, 'Yellow_card': 0.8023423, 'no_event': 0.89613414}
#   File: 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9358079, 'Direct_free-kick': 0.95264244, 'Yellow_card': 0.8281303, 'no_event': 0.8902567}
#   File: 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9280887, 'Direct_free-kick': 0.9445975, 'Yellow_card': 0.8319974, 'no_event': 0.8983025}
#   File: 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.95667624, 'Direct_free-kick': 0.94925934, 'Yellow_card': 0.86858964, 'no_event': 0.9224782}
#   File: 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.91998374, 'Direct_free-kick': 0.9354074, 'Yellow_card': 0.79197955, 'no_event': 0.86792135}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.93264604, 'Direct_free-kick': 0.96050423, 'Yellow_card': 0.86830425, 'no_event': 0.89550614}
#   File: 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.89957446, 'Direct_free-kick': 0.91033703, 'Yellow_card': 0.81691027, 'no_event': 0.8693867}
#   File: 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9655752, 'Direct_free-kick': 0.955986, 'Yellow_card': 0.8562479, 'no_event': 0.9242935}
#
# Testing Yellow_card training clips...
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8447011, 'Direct_free-kick': 0.8418643, 'Yellow_card': 0.9457743, 'no_event': 0.89752996}
#   File: 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.87665766, 'Direct_free-kick': 0.8808192, 'Yellow_card': 0.943042, 'no_event': 0.91470754}
#   File: 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8752025, 'Direct_free-kick': 0.87229097, 'Yellow_card': 0.9649875, 'no_event': 0.92977375}
#   File: 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8298117, 'Direct_free-kick': 0.8305223, 'Yellow_card': 0.92688036, 'no_event': 0.88959634}
#   File: 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.89478564, 'Direct_free-kick': 0.8810563, 'Yellow_card': 0.9501208, 'no_event': 0.93839306}
#   File: 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9482308, 'Direct_free-kick': 0.9386096, 'Yellow_card': 0.9394279, 'no_event': 0.957949}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8727604, 'Direct_free-kick': 0.8724811, 'Yellow_card': 0.95180357, 'no_event': 0.92880964}
#   File: 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.86725837, 'Direct_free-kick': 0.8661097, 'Yellow_card': 0.95851177, 'no_event': 0.91790116}
#   File: 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9245852, 'Direct_free-kick': 0.9204041, 'Yellow_card': 0.92132485, 'no_event': 0.94332314}
#   File: 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8602075, 'Direct_free-kick': 0.85751045, 'Yellow_card': 0.9493015, 'no_event': 0.9258331}
#   File: 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9293885, 'Direct_free-kick': 0.9247456, 'Yellow_card': 0.92887926, 'no_event': 0.93667}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.899245, 'Direct_free-kick': 0.89989316, 'Yellow_card': 0.9470501, 'no_event': 0.9212929}
#
# Testing no_event training clips...
#   File: ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.9066478, 'Direct_free-kick': 0.9030205, 'Yellow_card': 0.96453, 'no_event': 0.94608665}
#   File: ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.89463496, 'Direct_free-kick': 0.91051173, 'Yellow_card': 0.87147194, 'no_event': 0.8954602}
#   File: ng24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.896054, 'Direct_free-kick': 0.9012014, 'Yellow_card': 0.93498707, 'no_event': 0.9176281}
#   File: ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.922895, 'Direct_free-kick': 0.92353654, 'Yellow_card': 0.91100746, 'no_event': 0.9466585}
#   File: ng27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8943215, 'Direct_free-kick': 0.8969165, 'Yellow_card': 0.8217465, 'no_event': 0.85574836}
#   File: ng1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.87301576, 'Direct_free-kick': 0.8707945, 'Yellow_card': 0.9486737, 'no_event': 0.91132265}
#   File: ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.888799, 'Direct_free-kick': 0.8999001, 'Yellow_card': 0.8076304, 'no_event': 0.8719734}
#   File: ng3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.9487617, 'Direct_free-kick': 0.94264066, 'Yellow_card': 0.93626285, 'no_event': 0.9517689}
#   File: ng11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9284544, 'Direct_free-kick': 0.94274426, 'Yellow_card': 0.91477525, 'no_event': 0.9412191}
#   File: ng22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.93995357, 'Direct_free-kick': 0.9366741, 'Yellow_card': 0.91146505, 'no_event': 0.947144}
#   File: ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.93546486, 'Direct_free-kick': 0.9414388, 'Yellow_card': 0.90213215, 'no_event': 0.9229952}
#   File: ng4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9444476, 'Direct_free-kick': 0.93580973, 'Yellow_card': 0.88853866, 'no_event': 0.9323482}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5625
# Weighted Precision: 0.5694
# Weighted Recall: 0.5625
# Weighted F₁ Score: 0.5500
#
# Per-class Accuracy:
#   Goal: 0.5833 (7/12)
#   Direct_free-kick: 0.6667 (8/12)
#   Yellow_card: 0.7500 (9/12)
#   no_event: 0.2500 (3/12)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event']
# [[7 5 0 0]
#  [4 8 0 0]
#  [0 0 9 3]
#  [1 5 3 3]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.58      0.58      0.58        12
# Direct_free-kick       0.44      0.67      0.53        12
#      Yellow_card       0.75      0.75      0.75        12
#         no_event       0.50      0.25      0.33        12
#
#         accuracy                           0.56        48
#        macro avg       0.57      0.56      0.55        48
#     weighted avg       0.57      0.56      0.55        48
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 48
# Training samples: 48
# Number of classes: 4
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 5 times
#   Direct_free-kick → Goal: 4 times
#   Yellow_card → no_event: 3 times
#   no_event → Goal: 1 times
#   no_event → Direct_free-kick: 5 times
#   no_event → Yellow_card: 3 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.5625
# Training Set Accuracy: 0.5625
# Weighted Precision: 0.5694
# Weighted Recall: 0.5625
# Weighted F₁ Score: 0.5500
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================

# %%
import os
import numpy as np
import random
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

def l2_normalize(vec):
    """
    Perform L2 normalization on a vector.
    
    Args:
        vec (np.ndarray): Input vector.
    
    Returns:
        np.ndarray: L2-normalized vector.
    """
    norm = np.linalg.norm(vec)
    if norm == 0:
        return vec
    return vec / norm

def build_prototypes_from_test(embeddings_base_path, event_classes, num_prototype_samples=5):
    """
    Build prototypes for each event class from randomly selected test embeddings.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        event_classes (list): List of event class names.
        num_prototype_samples (int): Number of random samples to use for prototype creation.
    
    Returns:
        tuple: (prototypes dict, selected_files dict for tracking which files were used)
    """
    prototypes = {}
    selected_files = {}
    
    
    for event in event_classes:
        event_test_folder = os.path.join(embeddings_base_path, event, "Test")
        
        if not os.path.exists(event_test_folder):
            print(f"Warning: Test folder not found for {event}")
            continue
            
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_test_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_prototype_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for prototype")
            selected_files[event] = all_files
        else:
            # Randomly select files for prototype creation
            selected_files[event] = random.sample(all_files, num_prototype_samples)
        
        event_vecs = []
        print(f"Loading {len(selected_files[event])} random test embeddings for {event} prototype...")
        
        # Load selected embeddings for the event
        for fname in selected_files[event]:
            vec = np.load(os.path.join(event_test_folder, fname))
            event_vecs.append(vec)
            print(f"  Selected {fname} for prototype (shape: {vec.shape})")

        if event_vecs:
            # Compute mean vector for the event and normalize
            proto_event = np.mean(event_vecs, axis=0)
            proto_event = l2_normalize(proto_event)
            prototypes[event] = proto_event
            print(f"Built prototype for {event} from {len(event_vecs)} test samples")
        else:
            print(f"Warning: No embeddings found for {event}")

    return prototypes, selected_files

def classify_clip(clip_embedding, prototypes):
    """
    Classify a clip based on cosine similarity to prototypes.
    
    Args:
        clip_embedding (np.ndarray): Embedding vector of the clip.
        prototypes (dict): Dictionary of prototypes for each event class.
    
    Returns:
        tuple: (predicted_label, similarity_scores)
    """
    # Normalize the clip embedding
    clip_norm = l2_normalize(clip_embedding)
    
    # Compute cosine similarities
    similarities = {}
    for event, proto in prototypes.items():
        similarity = np.dot(clip_norm, proto)
        similarities[event] = similarity
    
    # Predict the class with highest similarity
    predicted_label = max(similarities, key=similarities.get)
    
    return predicted_label, similarities

def evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples=12):
    """
    Evaluate classification performance on a random subset of training data.
    
    Args:
        embeddings_base_path (str): Base path to embeddings folders.
        prototypes (dict): Dictionary of prototypes for each event class.
        event_classes (list): List of event class names.
        selected_prototype_files (dict): Files that were used for prototype creation (for reference).
        num_eval_samples (int): Number of random samples to evaluate per class.
    
    Returns:
        dict: Dictionary containing evaluation results.
    """
    y_true = []
    y_pred = []
    results = {
        'predictions': [],
        'class_counts': {event: {'correct': 0, 'total': 0} for event in event_classes},
        'train_results': []
    }
    
    print("\n" + "="*60)
    print(f"EVALUATING ON {num_eval_samples} RANDOM TRAINING SAMPLES PER CLASS")
    print("="*60)
    
    for event in event_classes:
        event_train_folder = os.path.join(embeddings_base_path, event, "Train")
        
        if not os.path.exists(event_train_folder):
            print(f"Warning: Train folder not found for {event}")
            continue
            
        print(f"\nTesting {event} training clips...")
        
        # Get all embedding files for this event
        all_files = [f for f in os.listdir(event_train_folder) if f.endswith(".npy")]
        
        if len(all_files) < num_eval_samples:
            print(f"Warning: Only {len(all_files)} files available for {event}, using all of them for evaluation")
            selected_files = all_files
        else:
            # Randomly select files for evaluation
            selected_files = random.sample(all_files, num_eval_samples)
        
        for fname in selected_files:
            test_embedding = np.load(os.path.join(event_train_folder, fname))
            predicted_label, similarities = classify_clip(test_embedding, prototypes)
            
            is_correct = predicted_label == event
            results['class_counts'][event]['total'] += 1
            
            if is_correct:
                results['class_counts'][event]['correct'] += 1
            
            # Store for sklearn metrics
            y_true.append(event)
            y_pred.append(predicted_label)
            
            # Store detailed results
            result_entry = {
                'file': fname,
                'true_label': event,
                'predicted_label': predicted_label,
                'correct': is_correct,
                'similarities': similarities,
                'split': 'train'
            }
            results['predictions'].append(result_entry)
            results['train_results'].append(result_entry)
            
            # Print results
            print(f"  File: {fname}")
            print(f"    True: {event}, Predicted: {predicted_label}, Correct: {is_correct}")
            print(f"    Similarities: {similarities}")
    
    # Calculate overall metrics
    overall_accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred, labels=event_classes)
    classification_rep = classification_report(y_true, y_pred, labels=event_classes, zero_division=0)
    
    # Calculate sklearn metrics for each class (treating as one-vs-rest)
    precision = precision_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=event_classes, average='weighted', zero_division=0)
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for event in event_classes:
        if results['class_counts'][event]['total'] > 0:
            class_accuracies[event] = results['class_counts'][event]['correct'] / results['class_counts'][event]['total']
        else:
            class_accuracies[event] = 0.0
    
    # Print results
    print(f"\n{'='*60}")
    print("EVALUATION RESULTS")
    print(f"{'='*60}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")
    print(f"Weighted Precision: {precision:.4f}")
    print(f"Weighted Recall: {recall:.4f}")
    print(f"Weighted F₁ Score: {f1:.4f}")
    
    print(f"\nPer-class Accuracy:")
    for event, acc in class_accuracies.items():
        correct = results['class_counts'][event]['correct']
        total = results['class_counts'][event]['total']
        print(f"  {event}: {acc:.4f} ({correct}/{total})")
    
    print(f"\nConfusion Matrix:")
    print("Rows: True labels, Columns: Predicted labels")
    print(f"Classes: {event_classes}")
    print(cm)
    
    print(f"\nDetailed Classification Report:")
    print(classification_rep)
    
    results.update({
        'overall_accuracy': overall_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'class_accuracies': class_accuracies,
        'confusion_matrix': cm,
        'classification_report': classification_rep,
        'y_true': y_true,
        'y_pred': y_pred,
        'train_accuracy': overall_accuracy
    })
    
    return results

def main():
    """
    Main function to run modified multiclass few-shot learning classification.
    Uses existing mean-pooled embeddings, builds prototypes from random 5 test samples,
    and evaluates on 12 random training samples per class.
    """
    print("Modified Multiclass Few-Shot Learning with Existing Embeddings")
    print("Using Test Data for Prototypes, Evaluating on Random Training Samples")
    print("="*70)
    
    # Configuration - Path to existing embeddings
    embeddings_base_path = "F:/AIM Lab/Experiment/Multiclass-equal sizes/R(2+1)D embeddings"
    
    # Event classes
    event_classes = ["Goal", "Direct_free-kick", "Yellow_card", "no_event"]
    
    # Number of test samples to use for prototype creation
    num_prototype_samples = 5
    
    # Number of training samples to evaluate per class
    num_eval_samples = 12
    
    # Check if embeddings exist
    print("\nChecking for existing embeddings...")
    embeddings_exist = True
    for event in event_classes:
        for split in ["Train", "Test"]:
            folder_path = os.path.join(embeddings_base_path, event, split)
            if not os.path.exists(folder_path):
                print(f"Warning: Embeddings folder not found: {folder_path}")
                embeddings_exist = False
            else:
                files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
                print(f"  Found {len(files)} embeddings in {event}/{split}")
    
    if not embeddings_exist:
        print("Error: Some embedding folders are missing. Please generate embeddings first.")
        return
    
    # Step 1: Build prototypes from random subset of test embeddings
    print(f"\nStep 1: Building prototypes from {num_prototype_samples} random test samples per class...")
    prototypes, selected_prototype_files = build_prototypes_from_test(
        embeddings_base_path, event_classes, num_prototype_samples
    )
    
    if not prototypes:
        print("Error: No prototypes could be built!")
        return
    
    print(f"\nSuccessfully built prototypes for {len(prototypes)} classes:")
    for event, proto in prototypes.items():
        print(f"  {event}: shape {proto.shape}")
    
    print(f"\nFiles used for prototype creation:")
    for event, files in selected_prototype_files.items():
        print(f"  {event}: {files}")
    
    # Step 2: Evaluate on random training samples
    print(f"\nStep 2: Evaluating classification performance on {num_eval_samples} random training samples per class...")
    results = evaluate_on_train_set(embeddings_base_path, prototypes, event_classes, selected_prototype_files, num_eval_samples)
    
    # Step 3: Additional analysis
    print(f"\nStep 3: Additional Analysis...")
    print(f"Total evaluation samples: {len(results['y_true'])}")
    print(f"Training samples: {len(results['train_results'])}")
    print(f"Number of classes: {len(event_classes)}")
    
    # Find most confused classes
    cm = results['confusion_matrix']
    print(f"\nMost confused class pairs:")
    for i, true_class in enumerate(event_classes):
        for j, pred_class in enumerate(event_classes):
            if i != j and cm[i, j] > 0:
                print(f"  {true_class} → {pred_class}: {cm[i, j]} times")
    
    print(f"\n{'='*70}")
    print("FINAL RESULTS")
    print(f"{'='*70}")
    print(f"Overall Accuracy: {results['overall_accuracy']:.4f}")
    print(f"Training Set Accuracy: {results['train_accuracy']:.4f}")
    print(f"Weighted Precision: {results['precision']:.4f}")
    print(f"Weighted Recall: {results['recall']:.4f}")
    print(f"Weighted F₁ Score: {results['f1_score']:.4f}")
    
    print(f"\n{'='*70}")
    print("MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!")
    print(f"{'='*70}")

if __name__ == "__main__":
    main()
# Out:
# Modified Multiclass Few-Shot Learning with Existing Embeddings
# Using Test Data for Prototypes, Evaluating on Random Training Samples
# ======================================================================
#
# Checking for existing embeddings...
#   Found 20 embeddings in Goal/Train
#   Found 7 embeddings in Goal/Test
#   Found 20 embeddings in Direct_free-kick/Train
#   Found 7 embeddings in Direct_free-kick/Test
#   Found 20 embeddings in Yellow_card/Train
#   Found 7 embeddings in Yellow_card/Test
#   Found 20 embeddings in no_event/Train
#   Found 7 embeddings in no_event/Test
#
# Step 1: Building prototypes from 5 random test samples per class...
# Loading 5 random test embeddings for Goal prototype...
#   Selected 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy for prototype (shape: (512,))
#   Selected 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy for prototype (shape: (512,))
#   Selected 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy for prototype (shape: (512,))
#   Selected 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (512,))
# Built prototype for Goal from 5 test samples
# Loading 5 random test embeddings for Direct_free-kick prototype...
#   Selected 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy for prototype (shape: (512,))
#   Selected 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy for prototype (shape: (512,))
#   Selected 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (512,))
#   Selected 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (512,))
#   Selected 2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (512,))
# Built prototype for Direct_free-kick from 5 test samples
# Loading 5 random test embeddings for Yellow_card prototype...
#   Selected 27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy for prototype (shape: (512,))
#   Selected 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (512,))
#   Selected 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy for prototype (shape: (512,))
#   Selected 3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy for prototype (shape: (512,))
#   Selected 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy for prototype (shape: (512,))
# Built prototype for Yellow_card from 5 test samples
# Loading 5 random test embeddings for no_event prototype...
#   Selected ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy for prototype (shape: (512,))
#   Selected ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy for prototype (shape: (512,))
#   Selected ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy for prototype (shape: (512,))
#   Selected ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy for prototype (shape: (512,))
#   Selected ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy for prototype (shape: (512,))
# Built prototype for no_event from 5 test samples
#
# Successfully built prototypes for 4 classes:
#   Goal: shape (512,)
#   Direct_free-kick: shape (512,)
#   Yellow_card: shape (512,)
#   no_event: shape (512,)
#
# Files used for prototype creation:
#   Goal: ['4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy', '11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy', '6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy', '3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy']
#   Direct_free-kick: ['13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy', '8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy', '10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy', '5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy', '2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy']
#   Yellow_card: ['27_2016-03-02 - 23-00 Liverpool 3 - 0 Manchester City.npy', '14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', '7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy', '3_2015-02-21 - 18-00 Swansea 2 - 1 Manchester United.npy', '9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy']
#   no_event: ['ng14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy', 'ng2_2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal.npy', 'ng5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy', 'ng10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy', 'ng20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy']
#
# Step 2: Evaluating classification performance on 12 random training samples per class...
#
# ============================================================
# EVALUATING ON 12 RANDOM TRAINING SAMPLES PER CLASS
# ============================================================
#
# Testing Goal training clips...
#   File: 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9351014, 'Direct_free-kick': 0.9276359, 'Yellow_card': 0.7355025, 'no_event': 0.90010905}
#   File: 7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.93213594, 'Direct_free-kick': 0.9001156, 'Yellow_card': 0.7708925, 'no_event': 0.89499414}
#   File: 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.92717403, 'Direct_free-kick': 0.9114746, 'Yellow_card': 0.8167386, 'no_event': 0.90858257}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.9032023, 'Direct_free-kick': 0.930417, 'Yellow_card': 0.70102966, 'no_event': 0.85603046}
#   File: 26_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9094387, 'Direct_free-kick': 0.86674863, 'Yellow_card': 0.75198376, 'no_event': 0.88478476}
#   File: 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9088637, 'Direct_free-kick': 0.8778067, 'Yellow_card': 0.7479838, 'no_event': 0.8862603}
#   File: 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.91946447, 'Direct_free-kick': 0.9068831, 'Yellow_card': 0.78307843, 'no_event': 0.891139}
#   File: 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9193261, 'Direct_free-kick': 0.8749776, 'Yellow_card': 0.81768465, 'no_event': 0.9121312}
#   File: 10_2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.927718, 'Direct_free-kick': 0.91771173, 'Yellow_card': 0.78453964, 'no_event': 0.8704426}
#   File: 14_2015-11-07 - 18-00 Manchester United 2 - 0 West Brom.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9173319, 'Direct_free-kick': 0.8901785, 'Yellow_card': 0.73318344, 'no_event': 0.87418544}
#   File: 9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: Goal, Predicted: Goal, Correct: True
#     Similarities: {'Goal': 0.9029058, 'Direct_free-kick': 0.8896495, 'Yellow_card': 0.71441036, 'no_event': 0.86798537}
#   File: 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Goal, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8921323, 'Direct_free-kick': 0.905185, 'Yellow_card': 0.7183262, 'no_event': 0.85175985}
#
# Testing Direct_free-kick training clips...
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.9000432, 'Direct_free-kick': 0.9195969, 'Yellow_card': 0.6831049, 'no_event': 0.8378106}
#   File: 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8914242, 'Direct_free-kick': 0.9210445, 'Yellow_card': 0.67998666, 'no_event': 0.8486876}
#   File: 18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9169824, 'Direct_free-kick': 0.9106926, 'Yellow_card': 0.72015786, 'no_event': 0.8643762}
#   File: 21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.9047362, 'Direct_free-kick': 0.89588845, 'Yellow_card': 0.7939728, 'no_event': 0.91422987}
#   File: 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.87177795, 'Direct_free-kick': 0.8894642, 'Yellow_card': 0.673628, 'no_event': 0.8350627}
#   File: 12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.89801025, 'Direct_free-kick': 0.8818707, 'Yellow_card': 0.7814146, 'no_event': 0.87338185}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.85656655, 'Direct_free-kick': 0.874037, 'Yellow_card': 0.6324744, 'no_event': 0.790526}
#   File: 25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.859101, 'Direct_free-kick': 0.85747945, 'Yellow_card': 0.6651104, 'no_event': 0.81601465}
#   File: 17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.89071053, 'Direct_free-kick': 0.89980745, 'Yellow_card': 0.7754657, 'no_event': 0.87143624}
#   File: 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.8758631, 'Direct_free-kick': 0.89938956, 'Yellow_card': 0.67213565, 'no_event': 0.8245423}
#   File: 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Direct_free-kick, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8799267, 'Direct_free-kick': 0.85973835, 'Yellow_card': 0.76342356, 'no_event': 0.8606411}
#   File: 6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: Direct_free-kick, Predicted: Direct_free-kick, Correct: True
#     Similarities: {'Goal': 0.87668735, 'Direct_free-kick': 0.8834654, 'Yellow_card': 0.7382617, 'no_event': 0.84088904}
#
# Testing Yellow_card training clips...
#   File: 11_2015-10-17 - 17-00 Chelsea 2 - 0 Aston Villa.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8030071, 'Direct_free-kick': 0.7734366, 'Yellow_card': 0.88789797, 'no_event': 0.80283237}
#   File: 24_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: Yellow_card, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.84998286, 'Direct_free-kick': 0.88818634, 'Yellow_card': 0.706308, 'no_event': 0.8409234}
#   File: 5_2015-08-08 - 19-30 Chelsea 2 - 2 Swansea.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8367313, 'Direct_free-kick': 0.82547796, 'Yellow_card': 0.8263776, 'no_event': 0.8202099}
#   File: 13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8895659, 'Direct_free-kick': 0.8391894, 'Yellow_card': 0.8691734, 'no_event': 0.8777066}
#   File: 22_2016-02-07 - 19-00 Chelsea 1 - 1 Manchester United.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8156443, 'Direct_free-kick': 0.8006301, 'Yellow_card': 0.86187196, 'no_event': 0.84227896}
#   File: 8_2015-08-29 - 17-00 Manchester City 2 - 0 Watford.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.79367113, 'Direct_free-kick': 0.75764, 'Yellow_card': 0.9317476, 'no_event': 0.8342657}
#   File: 19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.89803207, 'Direct_free-kick': 0.86672723, 'Yellow_card': 0.76672167, 'no_event': 0.87126684}
#   File: 15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.7976798, 'Direct_free-kick': 0.7693213, 'Yellow_card': 0.857401, 'no_event': 0.8700858}
#   File: 20_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: Yellow_card, Predicted: no_event, Correct: False
#     Similarities: {'Goal': 0.87225103, 'Direct_free-kick': 0.82873034, 'Yellow_card': 0.85151994, 'no_event': 0.8861089}
#   File: 1_2015-02-21 - 18-00 Chelsea 1 - 1 Burnley.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.8200135, 'Direct_free-kick': 0.7733983, 'Yellow_card': 0.8733885, 'no_event': 0.8347382}
#   File: 16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: Yellow_card, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8933803, 'Direct_free-kick': 0.8827739, 'Yellow_card': 0.8255926, 'no_event': 0.888973}
#   File: 4_2015-02-22 - 19-15 Southampton 0 - 2 Liverpool.npy
#     True: Yellow_card, Predicted: Yellow_card, Correct: True
#     Similarities: {'Goal': 0.77420044, 'Direct_free-kick': 0.74654627, 'Yellow_card': 0.91409564, 'no_event': 0.81279814}
#
# Testing no_event training clips...
#   File: ng13_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.8663976, 'Direct_free-kick': 0.87200475, 'Yellow_card': 0.79270685, 'no_event': 0.88101923}
#   File: ng12_2015-10-31 - 15-45 Chelsea 1 - 3 Liverpool.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8909479, 'Direct_free-kick': 0.8974387, 'Yellow_card': 0.7178883, 'no_event': 0.8666662}
#   File: ng19_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9108609, 'Direct_free-kick': 0.9100918, 'Yellow_card': 0.6964492, 'no_event': 0.8774094}
#   File: ng21_2016-01-13 - 22-45 Chelsea 2 - 2 West Brom.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.91839594, 'Direct_free-kick': 0.9010881, 'Yellow_card': 0.7692834, 'no_event': 0.89333606}
#   File: ng9_2015-09-12 - 14-45 Everton 3 - 1 Chelsea.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.8993278, 'Direct_free-kick': 0.90675, 'Yellow_card': 0.8015946, 'no_event': 0.8934992}
#   File: ng25_2016-02-14 - 19-15 Manchester City 1 - 2 Tottenham.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.8738605, 'Direct_free-kick': 0.8240088, 'Yellow_card': 0.9023156, 'no_event': 0.8948799}
#   File: ng15_2015-11-21 - 20-30 Manchester City 1 - 4 Liverpool.npy
#     True: no_event, Predicted: Yellow_card, Correct: False
#     Similarities: {'Goal': 0.7739965, 'Direct_free-kick': 0.75670135, 'Yellow_card': 0.85151863, 'no_event': 0.8169126}
#   File: ng7_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: no_event, Correct: True
#     Similarities: {'Goal': 0.80220616, 'Direct_free-kick': 0.76593816, 'Yellow_card': 0.8432918, 'no_event': 0.8441431}
#   File: ng18_2016-01-03 - 16-30 Crystal Palace 0 - 3 Chelsea.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.9077059, 'Direct_free-kick': 0.8989739, 'Yellow_card': 0.7966821, 'no_event': 0.88377404}
#   File: ng16_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: Direct_free-kick, Correct: False
#     Similarities: {'Goal': 0.84932077, 'Direct_free-kick': 0.8731759, 'Yellow_card': 0.6945965, 'no_event': 0.8281722}
#   File: ng6_2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.85520005, 'Direct_free-kick': 0.8316772, 'Yellow_card': 0.8113644, 'no_event': 0.84770364}
#   File: ng17_2015-12-19 - 18-00 Chelsea 3 - 1 Sunderland.npy
#     True: no_event, Predicted: Goal, Correct: False
#     Similarities: {'Goal': 0.8376218, 'Direct_free-kick': 0.82042706, 'Yellow_card': 0.6715029, 'no_event': 0.79653895}
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
# Overall Accuracy: 0.5000
# Weighted Precision: 0.5219
# Weighted Recall: 0.5000
# Weighted F₁ Score: 0.4733
#
# Per-class Accuracy:
#   Goal: 0.8333 (10/12)
#   Direct_free-kick: 0.5833 (7/12)
#   Yellow_card: 0.4167 (5/12)
#   no_event: 0.1667 (2/12)
#
# Confusion Matrix:
# Rows: True labels, Columns: Predicted labels
# Classes: ['Goal', 'Direct_free-kick', 'Yellow_card', 'no_event']
# [[10  2  0  0]
#  [ 4  7  0  1]
#  [ 4  1  5  2]
#  [ 5  3  2  2]]
#
# Detailed Classification Report:
#                   precision    recall  f1-score   support
#
#             Goal       0.43      0.83      0.57        12
# Direct_free-kick       0.54      0.58      0.56        12
#      Yellow_card       0.71      0.42      0.53        12
#         no_event       0.40      0.17      0.24        12
#
#         accuracy                           0.50        48
#        macro avg       0.52      0.50      0.47        48
#     weighted avg       0.52      0.50      0.47        48
#
#
# Step 3: Additional Analysis...
# Total evaluation samples: 48
# Training samples: 48
# Number of classes: 4
#
# Most confused class pairs:
#   Goal → Direct_free-kick: 2 times
#   Direct_free-kick → Goal: 4 times
#   Direct_free-kick → no_event: 1 times
#   Yellow_card → Goal: 4 times
#   Yellow_card → Direct_free-kick: 1 times
#   Yellow_card → no_event: 2 times
#   no_event → Goal: 5 times
#   no_event → Direct_free-kick: 3 times
#   no_event → Yellow_card: 2 times
#
# ======================================================================
# FINAL RESULTS
# ======================================================================
# Overall Accuracy: 0.5000
# Training Set Accuracy: 0.5000
# Weighted Precision: 0.5219
# Weighted Recall: 0.5000
# Weighted F₁ Score: 0.4733
#
# ======================================================================
# MODIFIED MULTICLASS FEW-SHOT LEARNING COMPLETE!
# ======================================================================
